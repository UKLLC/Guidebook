# %%
# define freeze number
freeze_num = 11
# import packages
import pandas as pd, sys
from IPython.display import HTML, display, Markdown
# create instance of freeze class
fp = 'S:/UKLLC - UKLLC Databank/UKLLC Systems/programs/quarterly'
sys.path.insert(0, fp)
import freeze_helper as fh
frehelp = fh.FreezeHelper(freeze_num) 
# retrive freeze name
freeze_name = frehelp.get_freeze_info()['freeze_name'][0]

# "ignores this method is deprecated in favour of `Styler.hide(axis='index')` " warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Freeze number 11 dated February 2025

# %% [markdown]
# Due to the UK LLC pooled sample being dynamic and the denominator changing over time, the UK LLC establishes a 'data freeze' of the pooled sample each quarter. Approved users are provisioned data against a set freeze which fixes their denominator at the start of their project and this remains fixed throughout the course of the project.

# %%
display(Markdown(frehelp.style_citation(freeze_name)))
# Out:
# **To cite this freeze:** UK Longitudinal Linkage Collaboration (UK LLC). (2025) *Freeze number 11 dated February 2025.* UK Longitudinal Linkage Collaboration (UKLLC). https://10.71760/ukllc-freeze-00011

# %%
display(Markdown(frehelp.style_dl_cites()))
# Out:
# Download Citation:  [Citeproc JSON](https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-freeze-00011)&nbsp;&nbsp;&nbsp;&nbsp; [BibTeX](https://api.datacite.org/application/x-bibtex/10.71760/ukllc-freeze-00011)&nbsp;&nbsp;&nbsp;&nbsp; [RIS](https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-freeze-00011)

# %% [markdown]
# ### Table 1: Participants enrolled in LPS and included in the UK LLC resource
#
# Variation in contribution rates between LPS is mostly due to differences in fair processing. UK LLC continues to work with LPS to establish the governance permissions necessary to maximise the number of enrolled participants in the UK LLC resource.

# %%
display(frehelp.style_table(frehelp.get_table('table1')))
# Out:
# <style type="text/css">
# #T_4f869 th {
#   text-align: left;
# }
# #T_4f869_row0_col0, #T_4f869_row1_col0, #T_4f869_row2_col0, #T_4f869_row3_col0, #T_4f869_row4_col0, #T_4f869_row5_col0, #T_4f869_row6_col0, #T_4f869_row7_col0, #T_4f869_row8_col0, #T_4f869_row9_col0, #T_4f869_row10_col0, #T_4f869_row11_col0, #T_4f869_row12_col0, #T_4f869_row13_col0, #T_4f869_row14_col0, #T_4f869_row15_col0, #T_4f869_row16_col0, #T_4f869_row17_col0, #T_4f869_row18_col0, #T_4f869_row19_col0, #T_4f869_row20_col1, #T_4f869_row20_col2, #T_4f869_row20_col3 {
#   text-align: left;
#   font-weight: bold;
# }
# #T_4f869_row0_col1, #T_4f869_row0_col2, #T_4f869_row0_col3, #T_4f869_row1_col1, #T_4f869_row1_col2, #T_4f869_row1_col3, #T_4f869_row2_col1, #T_4f869_row2_col2, #T_4f869_row2_col3, #T_4f869_row3_col1, #T_4f869_row3_col2, #T_4f869_row3_col3, #T_4f869_row4_col1, #T_4f869_row4_col2, #T_4f869_row4_col3, #T_4f869_row5_col1, #T_4f869_row5_col2, #T_4f869_row5_col3, #T_4f869_row6_col1, #T_4f869_row6_col2, #T_4f869_row6_col3, #T_4f869_row7_col1, #T_4f869_row7_col2, #T_4f869_row7_col3, #T_4f869_row8_col1, #T_4f869_row8_col2, #T_4f869_row8_col3, #T_4f869_row9_col1, #T_4f869_row9_col2, #T_4f869_row9_col3, #T_4f869_row10_col1, #T_4f869_row10_col2, #T_4f869_row10_col3, #T_4f869_row11_col1, #T_4f869_row11_col2, #T_4f869_row11_col3, #T_4f869_row12_col1, #T_4f869_row12_col2, #T_4f869_row12_col3, #T_4f869_row13_col1, #T_4f869_row13_col2, #T_4f869_row13_col3, #T_4f869_row14_col1, #T_4f869_row14_col2, #T_4f869_row14_col3, #T_4f869_row15_col1, #T_4f869_row15_col2, #T_4f869_row15_col3, #T_4f869_row16_col1, #T_4f869_row16_col2, #T_4f869_row16_col3, #T_4f869_row17_col1, #T_4f869_row17_col2, #T_4f869_row17_col3, #T_4f869_row18_col1, #T_4f869_row18_col2, #T_4f869_row18_col3, #T_4f869_row19_col1, #T_4f869_row19_col2, #T_4f869_row19_col3 {
#   text-align: left;
# }
# #T_4f869_row20_col0 {
#   text-align: left;
#   font-weight: bold;
#   font-weight: bold;
# }
# </style>
# <table id="T_4f869" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_4f869_level0_col0" class="col_heading level0 col0" >LPS</th>
#       <th id="T_4f869_level0_col1" class="col_heading level0 col1" >N participants enrolled in LPS</th>
#       <th id="T_4f869_level0_col2" class="col_heading level0 col2" >N (%) participants sent to UK LLC</th>
#       <th id="T_4f869_level0_col3" class="col_heading level0 col3" >N participants not sent to UK LLC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f869_row0_col0" class="data row0 col0" >ALSPAC</td>
#       <td id="T_4f869_row0_col1" class="data row0 col1" >32144</td>
#       <td id="T_4f869_row0_col2" class="data row0 col2" >6388 (19.9%)</td>
#       <td id="T_4f869_row0_col3" class="data row0 col3" >25756</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row1_col0" class="data row1 col0" >BCS70</td>
#       <td id="T_4f869_row1_col1" class="data row1 col1" >18888</td>
#       <td id="T_4f869_row1_col2" class="data row1 col2" >8753 (46.3%)</td>
#       <td id="T_4f869_row1_col3" class="data row1 col3" >10135</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row2_col0" class="data row2 col0" >BIB</td>
#       <td id="T_4f869_row2_col1" class="data row2 col1" >29664</td>
#       <td id="T_4f869_row2_col2" class="data row2 col2" >28590 (96.4%)</td>
#       <td id="T_4f869_row2_col3" class="data row2 col3" >1074</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row3_col0" class="data row3 col0" >ELSA</td>
#       <td id="T_4f869_row3_col1" class="data row3 col1" >18807</td>
#       <td id="T_4f869_row3_col2" class="data row3 col2" >9080 (48.3%)</td>
#       <td id="T_4f869_row3_col3" class="data row3 col3" >9727</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row4_col0" class="data row4 col0" >EPICN</td>
#       <td id="T_4f869_row4_col1" class="data row4 col1" >30445</td>
#       <td id="T_4f869_row4_col2" class="data row4 col2" >15755 (51.7%)</td>
#       <td id="T_4f869_row4_col3" class="data row4 col3" >14690</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row5_col0" class="data row5 col0" >EXCEED</td>
#       <td id="T_4f869_row5_col1" class="data row5 col1" >11749</td>
#       <td id="T_4f869_row5_col2" class="data row5 col2" >11141 (94.8%)</td>
#       <td id="T_4f869_row5_col3" class="data row5 col3" >608</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row6_col0" class="data row6 col0" >FENLAND</td>
#       <td id="T_4f869_row6_col1" class="data row6 col1" >12435</td>
#       <td id="T_4f869_row6_col2" class="data row6 col2" >12071 (97.1%)</td>
#       <td id="T_4f869_row6_col3" class="data row6 col3" >364</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row7_col0" class="data row7 col0" >GENSCOT</td>
#       <td id="T_4f869_row7_col1" class="data row7 col1" >25152</td>
#       <td id="T_4f869_row7_col2" class="data row7 col2" >22379 (89.0%)</td>
#       <td id="T_4f869_row7_col3" class="data row7 col3" >2773</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row8_col0" class="data row8 col0" >GLAD</td>
#       <td id="T_4f869_row8_col1" class="data row8 col1" >83880</td>
#       <td id="T_4f869_row8_col2" class="data row8 col2" >82950 (98.9%)</td>
#       <td id="T_4f869_row8_col3" class="data row8 col3" >930</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row9_col0" class="data row9 col0" >MCS</td>
#       <td id="T_4f869_row9_col1" class="data row9 col1" >40207</td>
#       <td id="T_4f869_row9_col2" class="data row9 col2" >28150 (70.0%)</td>
#       <td id="T_4f869_row9_col3" class="data row9 col3" >12057</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row10_col0" class="data row10 col0" >NCDS58</td>
#       <td id="T_4f869_row10_col1" class="data row10 col1" >18563</td>
#       <td id="T_4f869_row10_col2" class="data row10 col2" >9091 (49.0%)</td>
#       <td id="T_4f869_row10_col3" class="data row10 col3" >9472</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row11_col0" class="data row11 col0" >NEXTSTEP</td>
#       <td id="T_4f869_row11_col1" class="data row11 col1" >15629</td>
#       <td id="T_4f869_row11_col2" class="data row11 col2" >7451 (47.7%)</td>
#       <td id="T_4f869_row11_col3" class="data row11 col3" >8178</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row12_col0" class="data row12 col0" >NICOLA</td>
#       <td id="T_4f869_row12_col1" class="data row12 col1" >8739</td>
#       <td id="T_4f869_row12_col2" class="data row12 col2" >5247 (60.0%)</td>
#       <td id="T_4f869_row12_col3" class="data row12 col3" >3492</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row13_col0" class="data row13 col0" >NIHRBIO_COPING</td>
#       <td id="T_4f869_row13_col1" class="data row13 col1" >17183</td>
#       <td id="T_4f869_row13_col2" class="data row13 col2" >17159 (99.9%)</td>
#       <td id="T_4f869_row13_col3" class="data row13 col3" >24</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row14_col0" class="data row14 col0" >NSHD46</td>
#       <td id="T_4f869_row14_col1" class="data row14 col1" >5362</td>
#       <td id="T_4f869_row14_col2" class="data row14 col2" >4289 (80.0%)</td>
#       <td id="T_4f869_row14_col3" class="data row14 col3" >1073</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row15_col0" class="data row15 col0" >SABRE</td>
#       <td id="T_4f869_row15_col1" class="data row15 col1" >5251</td>
#       <td id="T_4f869_row15_col2" class="data row15 col2" >4719 (89.9%)</td>
#       <td id="T_4f869_row15_col3" class="data row15 col3" >532</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row16_col0" class="data row16 col0" >TEDS</td>
#       <td id="T_4f869_row16_col1" class="data row16 col1" >27890</td>
#       <td id="T_4f869_row16_col2" class="data row16 col2" >11018 (39.5%)</td>
#       <td id="T_4f869_row16_col3" class="data row16 col3" >16872</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row17_col0" class="data row17 col0" >TRACKC19</td>
#       <td id="T_4f869_row17_col1" class="data row17 col1" >20630</td>
#       <td id="T_4f869_row17_col2" class="data row17 col2" >19633 (95.2%)</td>
#       <td id="T_4f869_row17_col3" class="data row17 col3" >997</td>
#     </tr>
#     <tr>
#       <td id="T_4f869_row18_col0" class="data row18 col0" >TWINSUK</td>
#       <td id="T_4f869_row18_col1" class="data row18 col1" >17144</td>

# %% [markdown]
# ***Footnotes:***
# Figures for **N participants enrolled in LPS** were originally provided by the respective studies, and we are working to improve the accuracy and completness of these figures.

# %% [markdown]
# ### Table 1 exclusions: The total number of participants not sent to UK LLC with reason for exclusion

# %%
display(frehelp.style_table(frehelp.get_exclusions()))
# Out:
# <style type="text/css">
# #T_09082 th {
#   text-align: left;
# }
# #T_09082_row0_col0, #T_09082_row0_col1, #T_09082_row1_col0, #T_09082_row1_col1, #T_09082_row2_col0, #T_09082_row2_col1, #T_09082_row3_col0, #T_09082_row3_col1, #T_09082_row4_col0, #T_09082_row4_col1, #T_09082_row5_col0, #T_09082_row5_col1, #T_09082_row6_col0, #T_09082_row6_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_09082" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_09082_level0_col0" class="col_heading level0 col0" >Exclusion reason</th>
#       <th id="T_09082_level0_col1" class="col_heading level0 col1" >N participants</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_09082_row0_col0" class="data row0 col0" >(i) Excluded because they died <2020</td>
#       <td id="T_09082_row0_col1" class="data row0 col1" >16541</td>
#     </tr>
#     <tr>
#       <td id="T_09082_row1_col0" class="data row1 col0" >(ii) Excluded because they died >=2020</td>
#       <td id="T_09082_row1_col1" class="data row1 col1" >1098</td>
#     </tr>
#     <tr>
#       <td id="T_09082_row2_col0" class="data row2 col0" >(iii) Excluded because they withdrew from LPS</td>
#       <td id="T_09082_row2_col1" class="data row2 col1" >20337</td>
#     </tr>
#     <tr>
#       <td id="T_09082_row3_col0" class="data row3 col0" >(iv) Excluded because they dissented from UK LLC</td>
#       <td id="T_09082_row3_col1" class="data row3 col1" >2701</td>
#     </tr>
#     <tr>
#       <td id="T_09082_row4_col0" class="data row4 col0" >(v) Excluded because they dissented from record linkage</td>
#       <td id="T_09082_row4_col1" class="data row4 col1" >29219</td>
#     </tr>
#     <tr>
#       <td id="T_09082_row5_col0" class="data row5 col0" >(vi) Excluded because governance not established</td>
#       <td id="T_09082_row5_col1" class="data row5 col1" >30979</td>
#     </tr>
#     <tr>
#       <td id="T_09082_row6_col0" class="data row6 col0" >(vii) Excluded for other reasons</td>
#       <td id="T_09082_row6_col1" class="data row6 col1" >18665</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ***Footnotes with further details about exclusion criteria***
#
# (i) & (ii) UK LLC does not prohibit LPS from sending data for participants who have died. However, some LPS have policies which preclude these participants from inclusion in the resource. Data for participants who died on or after January 1, 2020 are particularly important for COVID-19 research, and so LPS were requested to send these data where possible.
#
# (v) Participants who have dissented from linkage can still be included in the UK LLC resource, with permission flags set accordingly. However, some LPS policies preclude participants from inclusion.
#
# Where a participant was excluded for more than one reason, LPS were asked to count participants once using the exclusion hierarchy (i-vii).
#
# Information presented in Table1 was provided by the LPS at the latest quarterly File1 update corresponding with the freeze name printed at the top of this notebook.

# %% [markdown]
# ### Table 2: Participants in the UK LLC with permission to link to NHS England and their legal basis
#
# Permission flags are set at a participant level or at an LPS level giving participants or LPS control over which linkages are established or removed. NHS England operates the National Opt Out (NOO) scheme, where individuals can request that their health record is not shared for research purposes. Where explicit and informed consent is in place, the NOO is overwritten. Where opt-out consent approaches are used in conjunction with Section 251 (s251) of the NHS Act 2006, then NOO is fully respected and no records will be accessed. The current NOO rate is 5.4% of the population; information on NOO rates can be found on the NHS England website<sup>1</sup>. For this reason, the UK LLC anticipates lower linkage rates where s251 is used.
#
# <p style='font-size: 12px;'><sup>1</sup>digital.nhs.uk/services/national-data-opt-out</p>

# %%
table2 = display(frehelp.style_table(frehelp.get_table('table2')))
# Out:
# <style type="text/css">
# #T_78105 th {
#   text-align: left;
# }
# #T_78105_row0_col0, #T_78105_row1_col0, #T_78105_row2_col0, #T_78105_row3_col0, #T_78105_row4_col0, #T_78105_row5_col0, #T_78105_row6_col0, #T_78105_row7_col0, #T_78105_row8_col0, #T_78105_row9_col0, #T_78105_row10_col0, #T_78105_row11_col0, #T_78105_row12_col0, #T_78105_row13_col0, #T_78105_row14_col0, #T_78105_row15_col0, #T_78105_row16_col0, #T_78105_row17_col1, #T_78105_row17_col2, #T_78105_row17_col3, #T_78105_row17_col4, #T_78105_row17_col5 {
#   text-align: left;
#   font-weight: bold;
# }
# #T_78105_row0_col1, #T_78105_row0_col2, #T_78105_row0_col3, #T_78105_row0_col4, #T_78105_row0_col5, #T_78105_row1_col1, #T_78105_row1_col2, #T_78105_row1_col3, #T_78105_row1_col4, #T_78105_row1_col5, #T_78105_row2_col1, #T_78105_row2_col2, #T_78105_row2_col3, #T_78105_row2_col4, #T_78105_row2_col5, #T_78105_row3_col1, #T_78105_row3_col2, #T_78105_row3_col3, #T_78105_row3_col4, #T_78105_row3_col5, #T_78105_row4_col1, #T_78105_row4_col2, #T_78105_row4_col3, #T_78105_row4_col4, #T_78105_row4_col5, #T_78105_row5_col1, #T_78105_row5_col2, #T_78105_row5_col3, #T_78105_row5_col4, #T_78105_row5_col5, #T_78105_row6_col1, #T_78105_row6_col2, #T_78105_row6_col3, #T_78105_row6_col4, #T_78105_row6_col5, #T_78105_row7_col1, #T_78105_row7_col2, #T_78105_row7_col3, #T_78105_row7_col4, #T_78105_row7_col5, #T_78105_row8_col1, #T_78105_row8_col2, #T_78105_row8_col3, #T_78105_row8_col4, #T_78105_row8_col5, #T_78105_row9_col1, #T_78105_row9_col2, #T_78105_row9_col3, #T_78105_row9_col4, #T_78105_row9_col5, #T_78105_row10_col1, #T_78105_row10_col2, #T_78105_row10_col3, #T_78105_row10_col4, #T_78105_row10_col5, #T_78105_row11_col1, #T_78105_row11_col2, #T_78105_row11_col3, #T_78105_row11_col4, #T_78105_row11_col5, #T_78105_row12_col1, #T_78105_row12_col2, #T_78105_row12_col3, #T_78105_row12_col4, #T_78105_row12_col5, #T_78105_row13_col1, #T_78105_row13_col2, #T_78105_row13_col3, #T_78105_row13_col4, #T_78105_row13_col5, #T_78105_row14_col1, #T_78105_row14_col2, #T_78105_row14_col3, #T_78105_row14_col4, #T_78105_row14_col5, #T_78105_row15_col1, #T_78105_row15_col2, #T_78105_row15_col3, #T_78105_row15_col4, #T_78105_row15_col5, #T_78105_row16_col1, #T_78105_row16_col2, #T_78105_row16_col3, #T_78105_row16_col4, #T_78105_row16_col5 {
#   text-align: left;
# }
# #T_78105_row17_col0 {
#   text-align: left;
#   font-weight: bold;
#   font-weight: bold;
# }
# </style>
# <table id="T_78105" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_78105_level0_col0" class="col_heading level0 col0" >LPS</th>
#       <th id="T_78105_level0_col1" class="col_heading level0 col1" >N participants sent to UK LLC</th>
#       <th id="T_78105_level0_col2" class="col_heading level0 col2" >N with permission to link to NHS E</th>
#       <th id="T_78105_level0_col3" class="col_heading level0 col3" >N linked s251</th>
#       <th id="T_78105_level0_col4" class="col_heading level0 col4" >N linked consent</th>
#       <th id="T_78105_level0_col5" class="col_heading level0 col5" >N linked total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_78105_row0_col0" class="data row0 col0" >ALSPAC</td>
#       <td id="T_78105_row0_col1" class="data row0 col1" >6388</td>
#       <td id="T_78105_row0_col2" class="data row0 col2" >6388 (100.0%)</td>
#       <td id="T_78105_row0_col3" class="data row0 col3" >1308 (91.4%)</td>
#       <td id="T_78105_row0_col4" class="data row0 col4" >4948 (99.8%)</td>
#       <td id="T_78105_row0_col5" class="data row0 col5" >6256 (97.9%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row1_col0" class="data row1 col0" >BCS70</td>
#       <td id="T_78105_row1_col1" class="data row1 col1" >8753</td>
#       <td id="T_78105_row1_col2" class="data row1 col2" >7191 (82.2%)</td>
#       <td id="T_78105_row1_col3" class="data row1 col3" ></td>
#       <td id="T_78105_row1_col4" class="data row1 col4" >6480 (90.1%)</td>
#       <td id="T_78105_row1_col5" class="data row1 col5" >6480 (90.1%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row2_col0" class="data row2 col0" >BIB</td>
#       <td id="T_78105_row2_col1" class="data row2 col1" >28590</td>
#       <td id="T_78105_row2_col2" class="data row2 col2" >28590 (100.0%)</td>
#       <td id="T_78105_row2_col3" class="data row2 col3" ></td>
#       <td id="T_78105_row2_col4" class="data row2 col4" >28427 (99.4%)</td>
#       <td id="T_78105_row2_col5" class="data row2 col5" >28427 (99.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row3_col0" class="data row3 col0" >ELSA</td>
#       <td id="T_78105_row3_col1" class="data row3 col1" >9080</td>
#       <td id="T_78105_row3_col2" class="data row3 col2" >7426 (81.8%)</td>
#       <td id="T_78105_row3_col3" class="data row3 col3" ></td>
#       <td id="T_78105_row3_col4" class="data row3 col4" >7097 (95.6%)</td>
#       <td id="T_78105_row3_col5" class="data row3 col5" >7097 (95.6%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row4_col0" class="data row4 col0" >EPICN</td>
#       <td id="T_78105_row4_col1" class="data row4 col1" >15755</td>
#       <td id="T_78105_row4_col2" class="data row4 col2" >15755 (100.0%)</td>
#       <td id="T_78105_row4_col3" class="data row4 col3" >15117 (96.0%)</td>
#       <td id="T_78105_row4_col4" class="data row4 col4" ></td>
#       <td id="T_78105_row4_col5" class="data row4 col5" >15117 (96.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row5_col0" class="data row5 col0" >EXCEED</td>
#       <td id="T_78105_row5_col1" class="data row5 col1" >11141</td>
#       <td id="T_78105_row5_col2" class="data row5 col2" >11127 (99.9%)</td>
#       <td id="T_78105_row5_col3" class="data row5 col3" ></td>
#       <td id="T_78105_row5_col4" class="data row5 col4" >9497 (85.4%)</td>
#       <td id="T_78105_row5_col5" class="data row5 col5" >9497 (85.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row6_col0" class="data row6 col0" >FENLAND</td>
#       <td id="T_78105_row6_col1" class="data row6 col1" >12071</td>
#       <td id="T_78105_row6_col2" class="data row6 col2" >12071 (100.0%)</td>
#       <td id="T_78105_row6_col3" class="data row6 col3" ></td>
#       <td id="T_78105_row6_col4" class="data row6 col4" >10595 (87.8%)</td>
#       <td id="T_78105_row6_col5" class="data row6 col5" >10595 (87.8%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row7_col0" class="data row7 col0" >GLAD</td>
#       <td id="T_78105_row7_col1" class="data row7 col1" >82950</td>
#       <td id="T_78105_row7_col2" class="data row7 col2" >76442 (92.2%)</td>
#       <td id="T_78105_row7_col3" class="data row7 col3" ></td>
#       <td id="T_78105_row7_col4" class="data row7 col4" >67128 (87.8%)</td>
#       <td id="T_78105_row7_col5" class="data row7 col5" >67128 (87.8%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row8_col0" class="data row8 col0" >MCS</td>
#       <td id="T_78105_row8_col1" class="data row8 col1" >28150</td>
#       <td id="T_78105_row8_col2" class="data row8 col2" >26674 (94.8%)</td>
#       <td id="T_78105_row8_col3" class="data row8 col3" ></td>
#       <td id="T_78105_row8_col4" class="data row8 col4" >21901 (82.1%)</td>
#       <td id="T_78105_row8_col5" class="data row8 col5" >21901 (82.1%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row9_col0" class="data row9 col0" >NCDS58</td>
#       <td id="T_78105_row9_col1" class="data row9 col1" >9091</td>
#       <td id="T_78105_row9_col2" class="data row9 col2" >7672 (84.4%)</td>
#       <td id="T_78105_row9_col3" class="data row9 col3" ></td>
#       <td id="T_78105_row9_col4" class="data row9 col4" >7507 (97.8%)</td>
#       <td id="T_78105_row9_col5" class="data row9 col5" >7507 (97.8%)</td>
#     </tr>
#     <tr>
#       <td id="T_78105_row10_col0" class="data row10 col0" >NEXTSTEP</td>
#       <td id="T_78105_row10_col1" class="data row10 col1" >7451</td>
#       <td id="T_78105_row10_col2" class="data row10 col2" >6401 (85.9%)</td>
#       <td id="T_78105_row10_col3" class="data row10 col3" ></td>
#       <td id="T_78105_row10_col4" class="data row10 col4" >5337 (83.4%)</td>
#       <td id="T_78105_row10_col5" class="data row10 col5" >5337 (83.4%)</td>
#     </tr>
#     <tr>
#       <td id="T_7810

# %% [markdown]
# ***Footnotes***
#
# Participants in SABRE do not currently permit linkage to NHS England and therefore do not feature in Table 2.
#
# Participants in GENSCOT and NICOLA do not currently have permission to link to NHS England due to governance issues and geographical limitations and therefore also do not feature in Table 2.
