# %% [markdown]
# # NHS England Patient Service Usage Dataset

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../scripts/'))
from data_doc_helper import UKLLCDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("nhse_patient_service_usage")
last_modified()
# Out:
# >Last modified: 28 May 2026

# %% [markdown]
# <div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC has created a summary dataset of patient service usage using NHS England data.</strong></div>

# %% [markdown]
# ## 1. Summary

# %% [markdown]
# The **NHS England patient service usage** dataset, formerly known as the **presence** dataset contains the number of appearances and the date of the most recent appearance in each NHS England dataset for each participant (if available - some NHS datasets do not include record dates). There is one exception - if a project has not been granted access to mental health datasets, data about a participant's presence in a mental health dataset will not be provided. Each project in the TRE is automatically provisioned a file named 'nhse_patient_service_usage_v0000_YYMMDD' (formerly known as 'CORE_NHSD_Presence_v0000_YYYYMMDD').
#
# The dataset includes all **NHS England** linked participants who have permissions from the LPS selected and approved as part of your project.
#
# The dataset **enables researchers to**:
# * identify a project's control group or denominator by comparing LPS participants' overall usage of **NHS England** services against the usage apparent in the data provisioned to a project. For NHS England datasets that have to be [**minimised by codelists**](../../../../linked_health_data/nhs_england/coding/codelists.md), this comparison will establish which participants appear in the dataset but are not included in the provisioned data
# * elucidate the extent to which the codelist definitions provided cover the overall participant usage of a service.

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_5c391_row0_col0, #T_5c391_row0_col1, #T_5c391_row1_col0, #T_5c391_row1_col1, #T_5c391_row2_col0, #T_5c391_row2_col1, #T_5c391_row3_col0, #T_5c391_row3_col1, #T_5c391_row4_col0, #T_5c391_row4_col1, #T_5c391_row5_col0, #T_5c391_row5_col1, #T_5c391_row6_col0, #T_5c391_row6_col1, #T_5c391_row7_col0, #T_5c391_row7_col1, #T_5c391_row8_col0, #T_5c391_row8_col1, #T_5c391_row9_col0, #T_5c391_row9_col1, #T_5c391_row10_col0, #T_5c391_row10_col1, #T_5c391_row11_col0, #T_5c391_row11_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_5c391" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_5c391_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_5c391_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5c391_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_5c391_row0_col1" class="data row0 col1" >UKLLC_nhse_patient_service_usage</td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_5c391_row1_col1" class="data row1 col1" >UK Longitudinal Linkage Collaboration. (2025). <i>UK LLC Managed: NHSE Patient Service Usage Dataset.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00439-09" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00439-09</a></td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_5c391_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00439-09" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00439-09" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00439-09" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row3_col0" class="data row3 col0" >Series</td>
#       <td id="T_5c391_row3_col1" class="data row3 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/ukllc_managed_data/ukllc_data">UK LLC Managed</a></td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row4_col0" class="data row4 col0" >Owner</td>
#       <td id="T_5c391_row4_col1" class="data row4 col1" >UK Longitudinal Linkage Collaboration, NHS England</td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_5c391_row5_col1" class="data row5 col1" >Unknown - Unknown</td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row6_col0" class="data row6 col0" >Keywords</td>
#       <td id="T_5c391_row6_col1" class="data row6 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_5c391_row7_col1" class="data row7 col1" >246456</td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row8_col0" class="data row8 col0" >Number of variables</td>
#       <td id="T_5c391_row8_col1" class="data row8 col1" >25</td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row9_col0" class="data row9 col0" >Number of observations</td>
#       <td id="T_5c391_row9_col1" class="data row9 col1" >246456</td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row10_col0" class="data row10 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_5c391_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5c391_row11_col0" class="data row11 col0" >Build a Data Request</td>
#       <td id="T_5c391_row11_col1" class="data row11 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Variables

# %%
ds.variable_table()
# Out:
# <style type="text/css">
# #T_af674_row0_col0, #T_af674_row0_col1, #T_af674_row1_col0, #T_af674_row1_col1, #T_af674_row2_col0, #T_af674_row2_col1, #T_af674_row3_col0, #T_af674_row3_col1, #T_af674_row4_col0, #T_af674_row4_col1, #T_af674_row5_col0, #T_af674_row5_col1, #T_af674_row6_col0, #T_af674_row6_col1, #T_af674_row7_col0, #T_af674_row7_col1, #T_af674_row8_col0, #T_af674_row8_col1, #T_af674_row9_col0, #T_af674_row9_col1, #T_af674_row10_col0, #T_af674_row10_col1, #T_af674_row11_col0, #T_af674_row11_col1, #T_af674_row12_col0, #T_af674_row12_col1, #T_af674_row13_col0, #T_af674_row13_col1, #T_af674_row14_col0, #T_af674_row14_col1, #T_af674_row15_col0, #T_af674_row15_col1, #T_af674_row16_col0, #T_af674_row16_col1, #T_af674_row17_col0, #T_af674_row17_col1, #T_af674_row18_col0, #T_af674_row18_col1, #T_af674_row19_col0, #T_af674_row19_col1, #T_af674_row20_col0, #T_af674_row20_col1, #T_af674_row21_col0, #T_af674_row21_col1, #T_af674_row22_col0, #T_af674_row22_col1, #T_af674_row23_col0, #T_af674_row23_col1, #T_af674_row24_col0, #T_af674_row24_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_af674" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_af674_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_af674_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_af674_row0_col0" class="data row0 col0" >avail_from_dt</td>
#       <td id="T_af674_row0_col1" class="data row0 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row1_col0" class="data row1 col0" >CANCER_count</td>
#       <td id="T_af674_row1_col1" class="data row1 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row2_col0" class="data row2 col0" >CANCER_date</td>
#       <td id="T_af674_row2_col1" class="data row2 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row3_col0" class="data row3 col0" >cohortkey_e</td>
#       <td id="T_af674_row3_col1" class="data row3 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row4_col0" class="data row4 col0" >COVIDSGSS_count</td>
#       <td id="T_af674_row4_col1" class="data row4 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row5_col0" class="data row5 col0" >COVIDSGSS_date</td>
#       <td id="T_af674_row5_col1" class="data row5 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row6_col0" class="data row6 col0" >CVAR_count</td>
#       <td id="T_af674_row6_col1" class="data row6 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row7_col0" class="data row7 col0" >CVAR_date</td>
#       <td id="T_af674_row7_col1" class="data row7 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row8_col0" class="data row8 col0" >CVS_count</td>
#       <td id="T_af674_row8_col1" class="data row8 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row9_col0" class="data row9 col0" >CVS_date</td>
#       <td id="T_af674_row9_col1" class="data row9 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row10_col0" class="data row10 col0" >GDPPR_count</td>
#       <td id="T_af674_row10_col1" class="data row10 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row11_col0" class="data row11 col0" >GDPPR_date</td>
#       <td id="T_af674_row11_col1" class="data row11 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row12_col0" class="data row12 col0" >HES_count</td>
#       <td id="T_af674_row12_col1" class="data row12 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row13_col0" class="data row13 col0" >HES_date</td>
#       <td id="T_af674_row13_col1" class="data row13 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row14_col0" class="data row14 col0" >IELISA_count</td>
#       <td id="T_af674_row14_col1" class="data row14 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row15_col0" class="data row15 col0" >IELISA_date</td>
#       <td id="T_af674_row15_col1" class="data row15 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row16_col0" class="data row16 col0" >last_seen_date</td>
#       <td id="T_af674_row16_col1" class="data row16 col1" >Date of last appearance across all NHS tables</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row17_col0" class="data row17 col0" >MHSDS_count</td>
#       <td id="T_af674_row17_col1" class="data row17 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row18_col0" class="data row18 col0" >MHSDS_date</td>
#       <td id="T_af674_row18_col1" class="data row18 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row19_col0" class="data row19 col0" >MORTALITY_count</td>
#       <td id="T_af674_row19_col1" class="data row19 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row20_col0" class="data row20 col0" >MORTALITY_date</td>
#       <td id="T_af674_row20_col1" class="data row20 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row21_col0" class="data row21 col0" >NPEX_count</td>
#       <td id="T_af674_row21_col1" class="data row21 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row22_col0" class="data row22 col0" >NPEX_date</td>
#       <td id="T_af674_row22_col1" class="data row22 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row23_col0" class="data row23 col0" >PCM_count</td>
#       <td id="T_af674_row23_col1" class="data row23 col1" >label not available</td>
#     </tr>
#     <tr>
#       <td id="T_af674_row24_col0" class="data row24 col0" >PCM_date</td>
#       <td id="T_af674_row24_col1" class="data row24 col1" >label not available</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_4f591_row0_col0, #T_4f591_row0_col1, #T_4f591_row0_col2, #T_4f591_row0_col3, #T_4f591_row0_col4, #T_4f591_row0_col5, #T_4f591_row1_col0, #T_4f591_row1_col1, #T_4f591_row1_col2, #T_4f591_row1_col3, #T_4f591_row1_col4, #T_4f591_row1_col5, #T_4f591_row2_col0, #T_4f591_row2_col1, #T_4f591_row2_col2, #T_4f591_row2_col3, #T_4f591_row2_col4, #T_4f591_row2_col5, #T_4f591_row3_col0, #T_4f591_row3_col1, #T_4f591_row3_col2, #T_4f591_row3_col3, #T_4f591_row3_col4, #T_4f591_row3_col5, #T_4f591_row4_col0, #T_4f591_row4_col1, #T_4f591_row4_col2, #T_4f591_row4_col3, #T_4f591_row4_col4, #T_4f591_row4_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_4f591" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_4f591_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_4f591_level0_col1" class="col_heading level0 col1" >5</th>
#       <th id="T_4f591_level0_col2" class="col_heading level0 col2" >6</th>
#       <th id="T_4f591_level0_col3" class="col_heading level0 col3" >7</th>
#       <th id="T_4f591_level0_col4" class="col_heading level0 col4" >8</th>
#       <th id="T_4f591_level0_col5" class="col_heading level0 col5" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f591_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_4f591_row0_col1" class="data row0 col1" >28 Oct 2022</td>
#       <td id="T_4f591_row0_col2" class="data row0 col2" >16 Dec 2022</td>
#       <td id="T_4f591_row0_col3" class="data row0 col3" >08 Dec 2023</td>
#       <td id="T_4f591_row0_col4" class="data row0 col4" >31 Jul 2024</td>
#       <td id="T_4f591_row0_col5" class="data row0 col5" >06 Aug 2025</td>
#     </tr>
#     <tr>
#       <td id="T_4f591_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_4f591_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_4f591_row1_col2" class="data row1 col2" >25</td>
#       <td id="T_4f591_row1_col3" class="data row1 col3" >25</td>
#       <td id="T_4f591_row1_col4" class="data row1 col4" >25</td>
#       <td id="T_4f591_row1_col5" class="data row1 col5" >25</td>
#     </tr>
#     <tr>
#       <td id="T_4f591_row2_col0" class="data row2 col0" >Number of Observations</td>
#       <td id="T_4f591_row2_col1" class="data row2 col1" >196592</td>
#       <td id="T_4f591_row2_col2" class="data row2 col2" >196592</td>
#       <td id="T_4f591_row2_col3" class="data row2 col3" >216123</td>
#       <td id="T_4f591_row2_col4" class="data row2 col4" >246449</td>
#       <td id="T_4f591_row2_col5" class="data row2 col5" >246456</td>
#     </tr>
#     <tr>
#       <td id="T_4f591_row3_col0" class="data row3 col0" >DOI</td>
#       <td id="T_4f591_row3_col1" class="data row3 col1" > <a href="https://doi.org/10.71760/ukllc-dataset-00439-05" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-05</a></td>
#       <td id="T_4f591_row3_col2" class="data row3 col2" > <a href="https://doi.org/10.71760/ukllc-dataset-00439-06" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-06</a></td>
#       <td id="T_4f591_row3_col3" class="data row3 col3" > <a href="https://doi.org/10.71760/ukllc-dataset-00439-07" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-07</a></td>
#       <td id="T_4f591_row3_col4" class="data row3 col4" > <a href="https://doi.org/10.71760/ukllc-dataset-00439-08" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-08</a></td>
#       <td id="T_4f591_row3_col5" class="data row3 col5" > <a href="https://doi.org/10.71760/ukllc-dataset-00439-09" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-09</a></td>
#     </tr>
#     <tr>
#       <td id="T_4f591_row4_col0" class="data row4 col0" >Change Log</td>
#       <td id="T_4f591_row4_col1" class="data row4 col1" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00439-05/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-05/activities</a></td>
#       <td id="T_4f591_row4_col2" class="data row4 col2" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00439-06/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-06/activities</a></td>
#       <td id="T_4f591_row4_col3" class="data row4 col3" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00439-07/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-07/activities</a></td>
#       <td id="T_4f591_row4_col4" class="data row4 col4" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00439-08/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-08/activities</a></td>
#       <td id="T_4f591_row4_col5" class="data row4 col5" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00439-09/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00439-09/activities</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
