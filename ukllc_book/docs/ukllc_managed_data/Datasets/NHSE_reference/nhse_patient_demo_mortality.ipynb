# %% [markdown]
# # NHS England Patient Demo Mortality Dataset

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import UKLLCDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("nhse_patient_demo_mortality")
last_modified()
# Out:
# >Last modified: 14 Nov 2025

# %% [markdown]
# <div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC has created a demographic and mortality dataset dervived from NHS England data.</strong></div>

# %% [markdown]
# ## 1. Summary

# %% [markdown]
# The **NHS England patient demo mortality** dataset, formerly known as the **indicator** dataset contains the most recent and reliable record for certain key demographic variables sourced from NHS England datasets for each participant. Each project in the TRE is automatically provisioned a file named 'UKLLC_nhse_patient_demo_mortality_v0000_YYYYMMDD' (formerly known as 'CORE_derived_indicator_v0000_YYYYMMDD').
#
# The dataset includes all **NHS England** linked participants who have permissions from the LPS selected and approved as part of your project. Sex, ethnicity (ethnic: NHS England ethncity coding system - see values table for coding lookup) and date of birth (dob_year_month: year and month of birth) are obtained from the following five datasets in the order presented (i.e. if the information isn't available in the Demographics dataset, the GDPPR dataset is then searched etc.):
# 1. Demographics.
# 2. General Practice Extraction Service (GPES) Data for Pandemic Planning and Research (GDPPR).
# 3. HES Admitted Patient Care (HESAPC).
# 4. HES Outpatients (HESOP).
# 5. HES Accident & Emergency (HESAE).
#
# The following variables are then added:
# * Deceased: from the Mortality dataset
# * Date of death: from the Mortality dataset
# * last_seen_date: last date recorded in any NHS England dataset (patient_service_usage).
#
# The dataset **enables researchers to**:
# * ascertain whether a participant is alive or dead and, if applicable, see their recorded date of death
# * quickly retrieve basic demographic information such as sex, ethnicity and age (via date of birth)
# * see the date when a participant last used an NHS England service
# * easily filter/group demographic data to be integrated into analytical pipelines.

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_b4eec th {
#   text-align: left;
# }
# #T_b4eec_row0_col0, #T_b4eec_row0_col1, #T_b4eec_row1_col0, #T_b4eec_row1_col1, #T_b4eec_row2_col0, #T_b4eec_row2_col1, #T_b4eec_row3_col0, #T_b4eec_row3_col1, #T_b4eec_row4_col0, #T_b4eec_row4_col1, #T_b4eec_row5_col0, #T_b4eec_row5_col1, #T_b4eec_row6_col0, #T_b4eec_row6_col1, #T_b4eec_row7_col0, #T_b4eec_row7_col1, #T_b4eec_row8_col0, #T_b4eec_row8_col1, #T_b4eec_row9_col0, #T_b4eec_row9_col1, #T_b4eec_row10_col0, #T_b4eec_row10_col1, #T_b4eec_row11_col0, #T_b4eec_row11_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b4eec" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_b4eec_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_b4eec_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b4eec_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_b4eec_row0_col1" class="data row0 col1" >UKLLC_nhse_patient_demo_mortality</td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_b4eec_row1_col1" class="data row1 col1" >UK Longitudinal Linkage Collaboration. (2025). <i>UK LLC Managed: NHSE Patient Demo Mortality Dataset.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00440-08" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00440-08</a></td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_b4eec_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00440-08" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00440-08" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00440-08" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row3_col0" class="data row3 col0" >Series</td>
#       <td id="T_b4eec_row3_col1" class="data row3 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/ukllc_managed_data/ukllc_data">UK LLC Managed</a></td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row4_col0" class="data row4 col0" >Owner</td>
#       <td id="T_b4eec_row4_col1" class="data row4 col1" >UK Longitudinal Linkage Collaboration, NHS England</td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_b4eec_row5_col1" class="data row5 col1" >Unknown - Unknown</td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row6_col0" class="data row6 col0" >Keywords</td>
#       <td id="T_b4eec_row6_col1" class="data row6 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_b4eec_row7_col1" class="data row7 col1" >250892</td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row8_col0" class="data row8 col0" >Number of variables</td>
#       <td id="T_b4eec_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row9_col0" class="data row9 col0" >Number of observations</td>
#       <td id="T_b4eec_row9_col1" class="data row9 col1" >250892</td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row10_col0" class="data row10 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_b4eec_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_b4eec_row11_col0" class="data row11 col0" >Build a Data Request</td>
#       <td id="T_b4eec_row11_col1" class="data row11 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Variables

# %%
ds.variable_table()
# Out:
# <style type="text/css">
# #T_3f4a8 th {
#   text-align: left;
# }
# #T_3f4a8_row0_col0, #T_3f4a8_row0_col1, #T_3f4a8_row1_col0, #T_3f4a8_row1_col1, #T_3f4a8_row2_col0, #T_3f4a8_row2_col1, #T_3f4a8_row3_col0, #T_3f4a8_row3_col1, #T_3f4a8_row4_col0, #T_3f4a8_row4_col1, #T_3f4a8_row5_col0, #T_3f4a8_row5_col1, #T_3f4a8_row6_col0, #T_3f4a8_row6_col1, #T_3f4a8_row7_col0, #T_3f4a8_row7_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_3f4a8" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_3f4a8_level0_col0" class="col_heading level0 col0" >Variable</th>
#       <th id="T_3f4a8_level0_col1" class="col_heading level0 col1" >Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3f4a8_row0_col0" class="data row0 col0" >cohortkey_e</td>
#       <td id="T_3f4a8_row0_col1" class="data row0 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_3f4a8_row1_col0" class="data row1 col0" >sex</td>
#       <td id="T_3f4a8_row1_col1" class="data row1 col1" >sex</td>
#     </tr>
#     <tr>
#       <td id="T_3f4a8_row2_col0" class="data row2 col0" >deceased</td>
#       <td id="T_3f4a8_row2_col1" class="data row2 col1" >deceased</td>
#     </tr>
#     <tr>
#       <td id="T_3f4a8_row3_col0" class="data row3 col0" >reg_date_of_death</td>
#       <td id="T_3f4a8_row3_col1" class="data row3 col1" >If deceased, date of death</td>
#     </tr>
#     <tr>
#       <td id="T_3f4a8_row4_col0" class="data row4 col0" >ethnic</td>
#       <td id="T_3f4a8_row4_col1" class="data row4 col1" >ethnicity</td>
#     </tr>
#     <tr>
#       <td id="T_3f4a8_row5_col0" class="data row5 col0" >dob_year_month</td>
#       <td id="T_3f4a8_row5_col1" class="data row5 col1" >date of birth year and month</td>
#     </tr>
#     <tr>
#       <td id="T_3f4a8_row6_col0" class="data row6 col0" >last_seen_date</td>
#       <td id="T_3f4a8_row6_col1" class="data row6 col1" >most recent appearance in nhs data</td>
#     </tr>
#     <tr>
#       <td id="T_3f4a8_row7_col0" class="data row7 col0" >avail_from_dt</td>
#       <td id="T_3f4a8_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_35e3a th {
#   text-align: left;
# }
# #T_35e3a_row0_col0, #T_35e3a_row0_col1, #T_35e3a_row0_col2, #T_35e3a_row0_col3, #T_35e3a_row0_col4, #T_35e3a_row0_col5, #T_35e3a_row1_col0, #T_35e3a_row1_col1, #T_35e3a_row1_col2, #T_35e3a_row1_col3, #T_35e3a_row1_col4, #T_35e3a_row1_col5, #T_35e3a_row2_col0, #T_35e3a_row2_col1, #T_35e3a_row2_col2, #T_35e3a_row2_col3, #T_35e3a_row2_col4, #T_35e3a_row2_col5, #T_35e3a_row3_col0, #T_35e3a_row3_col1, #T_35e3a_row3_col2, #T_35e3a_row3_col3, #T_35e3a_row3_col4, #T_35e3a_row3_col5, #T_35e3a_row4_col0, #T_35e3a_row4_col1, #T_35e3a_row4_col2, #T_35e3a_row4_col3, #T_35e3a_row4_col4, #T_35e3a_row4_col5 {
#   text-align: left;
# }
# </style>
# <table id="T_35e3a" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_35e3a_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_35e3a_level0_col1" class="col_heading level0 col1" >4</th>
#       <th id="T_35e3a_level0_col2" class="col_heading level0 col2" >5</th>
#       <th id="T_35e3a_level0_col3" class="col_heading level0 col3" >6</th>
#       <th id="T_35e3a_level0_col4" class="col_heading level0 col4" >7</th>
#       <th id="T_35e3a_level0_col5" class="col_heading level0 col5" >8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_35e3a_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_35e3a_row0_col1" class="data row0 col1" >01 Nov 2022</td>
#       <td id="T_35e3a_row0_col2" class="data row0 col2" >17 Dec 2022</td>
#       <td id="T_35e3a_row0_col3" class="data row0 col3" >13 Dec 2023</td>
#       <td id="T_35e3a_row0_col4" class="data row0 col4" >01 Aug 2024</td>
#       <td id="T_35e3a_row0_col5" class="data row0 col5" >07 Aug 2025</td>
#     </tr>
#     <tr>
#       <td id="T_35e3a_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_35e3a_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_35e3a_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_35e3a_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_35e3a_row1_col4" class="data row1 col4" >8</td>
#       <td id="T_35e3a_row1_col5" class="data row1 col5" >8</td>
#     </tr>
#     <tr>
#       <td id="T_35e3a_row2_col0" class="data row2 col0" >Number of Observations</td>
#       <td id="T_35e3a_row2_col1" class="data row2 col1" >194544</td>
#       <td id="T_35e3a_row2_col2" class="data row2 col2" >194544</td>
#       <td id="T_35e3a_row2_col3" class="data row2 col3" >207205</td>
#       <td id="T_35e3a_row2_col4" class="data row2 col4" >250892</td>
#       <td id="T_35e3a_row2_col5" class="data row2 col5" >250892</td>
#     </tr>
#     <tr>
#       <td id="T_35e3a_row3_col0" class="data row3 col0" >DOI</td>
#       <td id="T_35e3a_row3_col1" class="data row3 col1" > <a href="https://doi.org/10.71760/ukllc-dataset-00440-04" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-04</a></td>
#       <td id="T_35e3a_row3_col2" class="data row3 col2" > <a href="https://doi.org/10.71760/ukllc-dataset-00440-05" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-05</a></td>
#       <td id="T_35e3a_row3_col3" class="data row3 col3" > <a href="https://doi.org/10.71760/ukllc-dataset-00440-06" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-06</a></td>
#       <td id="T_35e3a_row3_col4" class="data row3 col4" > <a href="https://doi.org/10.71760/ukllc-dataset-00440-07" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-07</a></td>
#       <td id="T_35e3a_row3_col5" class="data row3 col5" > <a href="https://doi.org/10.71760/ukllc-dataset-00440-08" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-08</a></td>
#     </tr>
#     <tr>
#       <td id="T_35e3a_row4_col0" class="data row4 col0" >Change Log</td>
#       <td id="T_35e3a_row4_col1" class="data row4 col1" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00440-04/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-04/activities</a></td>
#       <td id="T_35e3a_row4_col2" class="data row4 col2" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00440-05/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-05/activities</a></td>
#       <td id="T_35e3a_row4_col3" class="data row4 col3" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00440-06/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-06/activities</a></td>
#       <td id="T_35e3a_row4_col4" class="data row4 col4" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00440-07/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-07/activities</a></td>
#       <td id="T_35e3a_row4_col5" class="data row4 col5" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00440-08/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00440-08/activities</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
