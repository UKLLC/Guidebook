# %% [markdown]
# # HES Critical Care (HESCC) Dataset

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import NHSEDataSet as DS, last_modified
ds = DS("HESCC")
last_modified()
# Out:
# >Last modified: 15 Dec 2025

# %%
ds.three_sec_summary()
# Out:
# <div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>People admitted  into an Intensive Care Unit (ICU) or High Dependency Unit (HDU) in  NHS hospitals in England. </strong></div>

# %%
from IPython.display import display, Markdown
display(Markdown('<div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="Understanding_HESCC.html" target="_blank">here.</a></strong></div>'))
# Out:
# <div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="Understanding_HESCC.html" target="_blank">here.</a></strong></div>

# %% [markdown]
# ## 1. Summary

# %%
ds.summary()
# Out:
# This dataset is a subset of the HES Admitted Patient Care (APC) dataset and replaced the HESAPC_ACP dataset in 2008. It includes information about patients admitted to intensive care settings. The Adult Critical Care Minimum Data Set was collected from 01/04/2008 onwards and the Neonatal and Paediatric Minimum Data Sets were collected from 01/04/2017 onwards.

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_99405 th {
#   text-align: left;
# }
# #T_99405_row0_col0, #T_99405_row0_col1, #T_99405_row1_col0, #T_99405_row1_col1, #T_99405_row2_col0, #T_99405_row2_col1, #T_99405_row3_col0, #T_99405_row3_col1, #T_99405_row4_col0, #T_99405_row4_col1, #T_99405_row5_col0, #T_99405_row5_col1, #T_99405_row6_col0, #T_99405_row6_col1, #T_99405_row7_col0, #T_99405_row7_col1, #T_99405_row8_col0, #T_99405_row8_col1, #T_99405_row9_col0, #T_99405_row9_col1, #T_99405_row10_col0, #T_99405_row10_col1, #T_99405_row11_col0, #T_99405_row11_col1, #T_99405_row12_col0, #T_99405_row12_col1, #T_99405_row13_col0, #T_99405_row13_col1, #T_99405_row14_col0, #T_99405_row14_col1, #T_99405_row15_col0, #T_99405_row15_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_99405" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_99405_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
# ...

# %% [markdown]
# ## 2. Metrics

# %%
ds.metrics()
# Out:
# Click on the plus sign to see the number of participants represented in each dataset.
# **Table 2:** Participants from each LPS represented in the HESCC dataset in the UK LLC TRE. **Note:** Individual cohort counts of less than 10 are suppressed to <10 and excluded from total participant counts for datasets.
#   <div id="e6e2a77f-8ded-4383-8296-63a17d083f0a" data-root-id="p1024" style="display: contents;"></div>

# %% [markdown]
# ## 3. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_466f1 th {
#   text-align: left;
# }
# #T_466f1_row0_col0, #T_466f1_row0_col1, #T_466f1_row0_col2, #T_466f1_row0_col3, #T_466f1_row1_col0, #T_466f1_row1_col1, #T_466f1_row1_col2, #T_466f1_row1_col3, #T_466f1_row2_col0, #T_466f1_row2_col1, #T_466f1_row2_col2, #T_466f1_row2_col3, #T_466f1_row3_col0, #T_466f1_row3_col1, #T_466f1_row3_col2, #T_466f1_row3_col3, #T_466f1_row4_col0, #T_466f1_row4_col1, #T_466f1_row4_col2, #T_466f1_row4_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_466f1" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_466f1_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_466f1_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_466f1_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_466f1_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## 4. Documentation

# %%
ds.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 5. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to the [UK LLC GitHub](https://github.com/UKLLC) repository where you can find the full scripts.
