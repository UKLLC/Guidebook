# %% [markdown]
# # Air pollution NOx, NO2 and O3

# %%
from IPython.display import display, Markdown
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import PlaceDataSet as DS, last_modified
last_modified()
# Out:
# >Last modified: 23 Jul 2025

# %%
display(Markdown('<div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC provides high-resolution national exposure surfaces for NO₂ and O₃ in England and Wales.</strong></div>'))
# Out:
# <div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC provides high-resolution national exposure surfaces for NO₂ and O₃ in England and Wales.</strong></div>

# %%
display(Markdown('<div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="Understanding_air_pollution_o3.html" target="_blank">here.</a></strong></div>'))
# Out:
# <div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="Understanding_air_pollution_o3.html" target="_blank">here.</a></strong></div>

# %% [markdown]
# ## Hybrid Air Dispersion Exposure System (HADES)
#
# The exposure surfaces were created using the HADES: Hybrid Air Dispersion Exposure System modelling framework, which combines dispersion modelling with satellite-derived estimates of background concentrations, land cover, and a 3-D representation of buildings, in a statistical calibration framework.
#
# These datasets contain national-scale outdoor nitrogen dioxide (NO2) and ozone (O3) exposure surfaces for England and Wales in 2018, 2019, and 2020 at very high spatial resolutions (10m and 100m). Participants residential addresses or postcodes are linked to one of the 10m x 10m cells. These exposures are also summarised for the 2021 UK Census communities in England and Wales using area-weighted sampling (i.e., zonal average). These values represent community background exposures for Census Output Area (COA), Lower Layer Super Output Area (LSOA) and Middle Layer Super Output Area (MSOA).
#
# Modelling explained 77-79% for NO2 and 87-89% for O3 of the variability in hourly-annual average concentrations and was robust to changes in NOx emissions during the COVID pandemic.
#
# ## 1. Summary

# %%
display(Markdown('### HADES_estimates_england_wales_hh'))
# Out:
# ### HADES_estimates_england_wales_hh

# %%
DS("HADES_estimates_england_wales_hh").info_table()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 DS("HADES_estimates_england_wales_hh").info_table()
#
# File c:\Users\sn9395\GitHub\Guidebook---KE-edits\ukllc_book\docs\scripts\data_doc_helper.py:1703, in PlaceDataSet.__init__(self, dataset)
#    1701 # define std input variables
#    1702 self.dataset = dataset
# -> 1703 self.df_ds = get_place_ds(self.dataset)
#    1704 self.doi = ds_doi(self.df_ds.iloc[0]["table"])
#    1705 self.apa_cite, self.dl_cites = cites(self.doi)
#
# File c:\Users\sn9395\GitHub\Guidebook---KE-edits\ukllc_book\docs\scripts\data_doc_helper.py:1614, in PlaceDataSet.__init__.<locals>.get_place_ds(x)
#    1611 if x.startswith("air_pollution"):
#    1612     df_ds = ds[(ds["source"] == "GEO") & (ds["table"] == "air_pollution")]
# -> 1614 df_ds["source_table"] = df_ds["source"] + "_" + df_ds["table"]
#    1615 ss = md.get_md_api_ss()[["Owner", "source"]]
#    1616 df_ds = df_ds.merge(ss, on="source")
#
# UnboundLocalError: cannot access local variable 'df_ds' where it is not associated with a value

# %%
display(Markdown('### air_pollution_pc'))
# Out:
# ### air_pollution_pc

# %%
DS("air_pollution_pc").info_table()
# Out:
# <style type="text/css">
# #T_28571 th {
#   text-align: left;
# }
# #T_28571_row0_col0, #T_28571_row0_col1, #T_28571_row1_col0, #T_28571_row1_col1, #T_28571_row2_col0, #T_28571_row2_col1, #T_28571_row3_col0, #T_28571_row3_col1, #T_28571_row4_col0, #T_28571_row4_col1, #T_28571_row5_col0, #T_28571_row5_col1, #T_28571_row6_col0, #T_28571_row6_col1, #T_28571_row7_col0, #T_28571_row7_col1, #T_28571_row8_col0, #T_28571_row8_col1, #T_28571_row9_col0, #T_28571_row9_col1, #T_28571_row10_col0, #T_28571_row10_col1, #T_28571_row11_col0, #T_28571_row11_col1, #T_28571_row12_col0, #T_28571_row12_col1, #T_28571_row13_col0, #T_28571_row13_col1, #T_28571_row14_col0, #T_28571_row14_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_28571" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_28571_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_28571_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_28571_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_28571_row0_col1" class="data row0 col1" >GEO_air_pollution</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_28571_row1_col1" class="data row1 col1" >DOI and Citation TBC</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_28571_row2_col1" class="data row2 col1" >DOI and Citation Downloads TBC</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row3_col0" class="data row3 col0" >Owner</td>
#       <td id="T_28571_row3_col1" class="data row3 col1" >University of Leicester and St George's, University of London</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row4_col0" class="data row4 col0" >Authors</td>
#       <td id="T_28571_row4_col1" class="data row4 col1" >Calvin Jephcote & Kathryn Adams (University of Leicester) </td>
#     </tr>
#     <tr>
#       <td id="T_28571_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_28571_row5_col1" class="data row5 col1" >01/2010 - 12/2019</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row6_col0" class="data row6 col0" >Geographical Coverage</td>
#       <td id="T_28571_row6_col1" class="data row6 col1" >Great Britain</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_28571_row7_col1" class="data row7 col1" >77594</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row8_col0" class="data row8 col0" >Number of Variables</td>
#       <td id="T_28571_row8_col1" class="data row8 col1" >30</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row9_col0" class="data row9 col0" >Number of Observations</td>
#       <td id="T_28571_row9_col1" class="data row9 col1" >39097</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row10_col0" class="data row10 col0" >Key Link</td>
#       <td id="T_28571_row10_col1" class="data row10 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/linked_geo_data/place_based_intro" rel="noopener noreferrer" target="_blank">https://guidebook.ukllc.ac.uk/docs/linked_geo_data/place_based_intro</a></td>
#     </tr>
#     <tr>
#       <td id="T_28571_row11_col0" class="data row11 col0" >Keywords</td>
#       <td id="T_28571_row11_col1" class="data row11 col1" >PM2.5,NO2,air pollution,geospatial,environmental</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row12_col0" class="data row12 col0" >Latest Extract Date</td>
#       <td id="T_28571_row12_col1" class="data row12 col1" >TBC</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row13_col0" class="data row13 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_28571_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_28571_row14_col0" class="data row14 col0" >Build a Data Request</td>
#       <td id="T_28571_row14_col1" class="data row14 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Variables

# %%
display(Markdown('### air_pollution_hh'))
# Out:
# ### air_pollution_hh

# %%
DS("air_pollution_hh").variable_table()
# Out:
# <style type="text/css">
# #T_be310 th {
#   text-align: left;
# }
# #T_be310_row0_col0, #T_be310_row0_col1, #T_be310_row0_col2, #T_be310_row0_col3, #T_be310_row0_col4, #T_be310_row1_col0, #T_be310_row1_col1, #T_be310_row1_col2, #T_be310_row1_col3, #T_be310_row1_col4, #T_be310_row2_col0, #T_be310_row2_col1, #T_be310_row2_col2, #T_be310_row2_col3, #T_be310_row2_col4, #T_be310_row3_col0, #T_be310_row3_col1, #T_be310_row3_col2, #T_be310_row3_col3, #T_be310_row3_col4, #T_be310_row4_col0, #T_be310_row4_col1, #T_be310_row4_col2, #T_be310_row4_col3, #T_be310_row4_col4, #T_be310_row5_col0, #T_be310_row5_col1, #T_be310_row5_col2, #T_be310_row5_col3, #T_be310_row5_col4, #T_be310_row6_col0, #T_be310_row6_col1, #T_be310_row6_col2, #T_be310_row6_col3, #T_be310_row6_col4, #T_be310_row7_col0, #T_be310_row7_col1, #T_be310_row7_col2, #T_be310_row7_col3, #T_be310_row7_col4, #T_be310_row8_col0, #T_be310_row8_col1, #T_be310_row8_col2, #T_be310_row8_col3, #T_be310_row8_col4, #T_be310_row9_col0, #T_be310_row9_col1, #T_be310_row9_col2, #T_be310_row9_col3, #T_be310_row9_col4, #T_be310_row10_col0, #T_be310_row10_col1, #T_be310_row10_col2, #T_be310_row10_col3, #T_be310_row10_col4, #T_be310_row11_col0, #T_be310_row11_col1, #T_be310_row11_col2, #T_be310_row11_col3, #T_be310_row11_col4, #T_be310_row12_col0, #T_be310_row12_col1, #T_be310_row12_col2, #T_be310_row12_col3, #T_be310_row12_col4, #T_be310_row13_col0, #T_be310_row13_col1, #T_be310_row13_col2, #T_be310_row13_col3, #T_be310_row13_col4, #T_be310_row14_col0, #T_be310_row14_col1, #T_be310_row14_col2, #T_be310_row14_col3, #T_be310_row14_col4, #T_be310_row15_col0, #T_be310_row15_col1, #T_be310_row15_col2, #T_be310_row15_col3, #T_be310_row15_col4, #T_be310_row16_col0, #T_be310_row16_col1, #T_be310_row16_col2, #T_be310_row16_col3, #T_be310_row16_col4, #T_be310_row17_col0, #T_be310_row17_col1, #T_be310_row17_col2, #T_be310_row17_col3, #T_be310_row17_col4, #T_be310_row18_col0, #T_be310_row18_col1, #T_be310_row18_col2, #T_be310_row18_col3, #T_be310_row18_col4, #T_be310_row19_col0, #T_be310_row19_col1, #T_be310_row19_col2, #T_be310_row19_col3, #T_be310_row19_col4, #T_be310_row20_col0, #T_be310_row20_col1, #T_be310_row20_col2, #T_be310_row20_col3, #T_be310_row20_col4, #T_be310_row21_col0, #T_be310_row21_col1, #T_be310_row21_col2, #T_be310_row21_col3, #T_be310_row21_col4, #T_be310_row22_col0, #T_be310_row22_col1, #T_be310_row22_col2, #T_be310_row22_col3, #T_be310_row22_col4, #T_be310_row23_col0, #T_be310_row23_col1, #T_be310_row23_col2, #T_be310_row23_col3, #T_be310_row23_col4, #T_be310_row24_col0, #T_be310_row24_col1, #T_be310_row24_col2, #T_be310_row24_col3, #T_be310_row24_col4, #T_be310_row25_col0, #T_be310_row25_col1, #T_be310_row25_col2, #T_be310_row25_col3, #T_be310_row25_col4, #T_be310_row26_col0, #T_be310_row26_col1, #T_be310_row26_col2, #T_be310_row26_col3, #T_be310_row26_col4, #T_be310_row27_col0, #T_be310_row27_col1, #T_be310_row27_col2, #T_be310_row27_col3, #T_be310_row27_col4, #T_be310_row28_col0, #T_be310_row28_col1, #T_be310_row28_col2, #T_be310_row28_col3, #T_be310_row28_col4, #T_be310_row29_col0, #T_be310_row29_col1, #T_be310_row29_col2, #T_be310_row29_col3, #T_be310_row29_col4, #T_be310_row30_col0, #T_be310_row30_col1, #T_be310_row30_col2, #T_be310_row30_col3, #T_be310_row30_col4, #T_be310_row31_col0, #T_be310_row31_col1, #T_be310_row31_col2, #T_be310_row31_col3, #T_be310_row31_col4, #T_be310_row32_col0, #T_be310_row32_col1, #T_be310_row32_col2, #T_be310_row32_col3, #T_be310_row32_col4, #T_be310_row33_col0, #T_be310_row33_col1, #T_be310_row33_col2, #T_be310_row33_col3, #T_be310_row33_col4, #T_be310_row34_col0, #T_be310_row34_col1, #T_be310_row34_col2, #T_be310_row34_col3, #T_be310_row34_col4, #T_be310_row35_col0, #T_be310_row35_col1, #T_be310_row35_col2, #T_be310_row35_col3, #T_be310_row35_col4, #T_be310_row36_col0, #T_be310_row36_col1, #T_be310_row36_col2, #T_be310_row36_col3, #T_be310_row36_col4, #T_be310_row37_col0, #T_be310_row37_col1, #T_be310_row37_col2, #T_be310_row37_col3, #T_be310_row37_col4, #T_be310_row38_col0, #T_be310_row38_col1, #T_be310_row38_col ...

# %%
display(Markdown('### air_pollution_pc'))
# Out:
# ### air_pollution_pc

# %%
DS("air_pollution_pc").variable_table()
# Out:
# <style type="text/css">
# #T_37025 th {
#   text-align: left;
# }
# #T_37025_row0_col0, #T_37025_row0_col1, #T_37025_row0_col2, #T_37025_row0_col3, #T_37025_row0_col4, #T_37025_row1_col0, #T_37025_row1_col1, #T_37025_row1_col2, #T_37025_row1_col3, #T_37025_row1_col4, #T_37025_row2_col0, #T_37025_row2_col1, #T_37025_row2_col2, #T_37025_row2_col3, #T_37025_row2_col4, #T_37025_row3_col0, #T_37025_row3_col1, #T_37025_row3_col2, #T_37025_row3_col3, #T_37025_row3_col4, #T_37025_row4_col0, #T_37025_row4_col1, #T_37025_row4_col2, #T_37025_row4_col3, #T_37025_row4_col4, #T_37025_row5_col0, #T_37025_row5_col1, #T_37025_row5_col2, #T_37025_row5_col3, #T_37025_row5_col4, #T_37025_row6_col0, #T_37025_row6_col1, #T_37025_row6_col2, #T_37025_row6_col3, #T_37025_row6_col4, #T_37025_row7_col0, #T_37025_row7_col1, #T_37025_row7_col2, #T_37025_row7_col3, #T_37025_row7_col4, #T_37025_row8_col0, #T_37025_row8_col1, #T_37025_row8_col2, #T_37025_row8_col3, #T_37025_row8_col4, #T_37025_row9_col0, #T_37025_row9_col1, #T_37025_row9_col2, #T_37025_row9_col3, #T_37025_row9_col4, #T_37025_row10_col0, #T_37025_row10_col1, #T_37025_row10_col2, #T_37025_row10_col3, #T_37025_row10_col4, #T_37025_row11_col0, #T_37025_row11_col1, #T_37025_row11_col2, #T_37025_row11_col3, #T_37025_row11_col4, #T_37025_row12_col0, #T_37025_row12_col1, #T_37025_row12_col2, #T_37025_row12_col3, #T_37025_row12_col4, #T_37025_row13_col0, #T_37025_row13_col1, #T_37025_row13_col2, #T_37025_row13_col3, #T_37025_row13_col4, #T_37025_row14_col0, #T_37025_row14_col1, #T_37025_row14_col2, #T_37025_row14_col3, #T_37025_row14_col4, #T_37025_row15_col0, #T_37025_row15_col1, #T_37025_row15_col2, #T_37025_row15_col3, #T_37025_row15_col4, #T_37025_row16_col0, #T_37025_row16_col1, #T_37025_row16_col2, #T_37025_row16_col3, #T_37025_row16_col4, #T_37025_row17_col0, #T_37025_row17_col1, #T_37025_row17_col2, #T_37025_row17_col3, #T_37025_row17_col4, #T_37025_row18_col0, #T_37025_row18_col1, #T_37025_row18_col2, #T_37025_row18_col3, #T_37025_row18_col4, #T_37025_row19_col0, #T_37025_row19_col1, #T_37025_row19_col2, #T_37025_row19_col3, #T_37025_row19_col4, #T_37025_row20_col0, #T_37025_row20_col1, #T_37025_row20_col2, #T_37025_row20_col3, #T_37025_row20_col4, #T_37025_row21_col0, #T_37025_row21_col1, #T_37025_row21_col2, #T_37025_row21_col3, #T_37025_row21_col4, #T_37025_row22_col0, #T_37025_row22_col1, #T_37025_row22_col2, #T_37025_row22_col3, #T_37025_row22_col4, #T_37025_row23_col0, #T_37025_row23_col1, #T_37025_row23_col2, #T_37025_row23_col3, #T_37025_row23_col4, #T_37025_row24_col0, #T_37025_row24_col1, #T_37025_row24_col2, #T_37025_row24_col3, #T_37025_row24_col4, #T_37025_row25_col0, #T_37025_row25_col1, #T_37025_row25_col2, #T_37025_row25_col3, #T_37025_row25_col4, #T_37025_row26_col0, #T_37025_row26_col1, #T_37025_row26_col2, #T_37025_row26_col3, #T_37025_row26_col4, #T_37025_row27_col0, #T_37025_row27_col1, #T_37025_row27_col2, #T_37025_row27_col3, #T_37025_row27_col4, #T_37025_row28_col0, #T_37025_row28_col1, #T_37025_row28_col2, #T_37025_row28_col3, #T_37025_row28_col4, #T_37025_row29_col0, #T_37025_row29_col1, #T_37025_row29_col2, #T_37025_row29_col3, #T_37025_row29_col4, #T_37025_row30_col0, #T_37025_row30_col1, #T_37025_row30_col2, #T_37025_row30_col3, #T_37025_row30_col4, #T_37025_row31_col0, #T_37025_row31_col1, #T_37025_row31_col2, #T_37025_row31_col3, #T_37025_row31_col4, #T_37025_row32_col0, #T_37025_row32_col1, #T_37025_row32_col2, #T_37025_row32_col3, #T_37025_row32_col4, #T_37025_row33_col0, #T_37025_row33_col1, #T_37025_row33_col2, #T_37025_row33_col3, #T_37025_row33_col4, #T_37025_row34_col0, #T_37025_row34_col1, #T_37025_row34_col2, #T_37025_row34_col3, #T_37025_row34_col4, #T_37025_row35_col0, #T_37025_row35_col1, #T_37025_row35_col2, #T_37025_row35_col3, #T_37025_row35_col4, #T_37025_row36_col0, #T_37025_row36_col1, #T_37025_row36_col2, #T_37025_row36_col3, #T_37025_row36_col4, #T_37025_row37_col0, #T_37025_row37_col1, #T_37025_row37_col2, #T_37025_row37_col3, #T_37025_row37_col4, #T_37025_row38_col0, #T_37025_row38_col1, #T_37025_row38_col ...

# %% [markdown]
# ## 3. Metrics

# %%
display(Markdown('TBC'))
# Out:
# TBC

# %% [markdown]
# ## 4. Version History

# %%
display(Markdown('TBC'))
# Out:
# TBC

# %% [markdown]
# ## 5. Documentation

# %%
DS("air_pollution_pc").documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 5. Useful Syntax

# %%
DS("air_pollution_pc").useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to the [UK LLC GitHub](https://github.com/UKLLC) repository where you can find the full scripts.
