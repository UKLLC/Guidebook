# %% [markdown]
# # Air pollution NOx, NO2 and O3

# %%
from IPython.display import display, Markdown
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import PlaceDataSet as DS, last_modified
last_modified()
# Out:
# >Last modified: 14 Aug 2025

# %%
display(Markdown('<div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC provides high-resolution national exposure surfaces for NO₂ and O₃ in England and Wales.</strong></div>'))
# Out:
# <div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC provides high-resolution national exposure surfaces for NO₂ and O₃ in England and Wales.</strong></div>

# %%
display(Markdown('<div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="Understanding_air_pollution_o3.html" target="_blank">here.</a></strong></div>'))
# Out:
# <div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="Understanding_air_pollution_o3.html" target="_blank">here.</a></strong></div>

# %% [markdown]
# ## Hybrid Air Dispersion Exposure System (HADES)
#
# The exposure surfaces were created using the HADES: Hybrid Air Dispersion Exposure System modelling framework, which combines dispersion modelling with satellite-derived estimates of background concentrations, land cover, and a 3-D representation of buildings, in a statistical calibration framework.
#
# These datasets contain national-scale outdoor nitrogen dioxide (NO2) and ozone (O3) exposure surfaces for England and Wales in 2018, 2019, and 2020 at very high spatial resolutions (10m and 100m). Participants residential addresses or postcodes are linked to one of the 10m x 10m cells. These exposures are also summarised for the 2021 UK Census communities in England and Wales using area-weighted sampling (i.e., zonal average). These values represent community background exposures for Census Output Area (COA), Lower Layer Super Output Area (LSOA) and Middle Layer Super Output Area (MSOA).
#
# Modelling explained 77-79% for NO2 and 87-89% for O3 of the variability in hourly-annual average concentrations and was robust to changes in NOx emissions during the COVID pandemic.
#
#
# ## 1. Summary

# %%
display(Markdown('### hades_air_pollution_england_wales_hh'))
# Out:
# ### hades_air_pollution_england_wales_hh

# %%
DS("hades_air_pollution_england_wales_hh").info_table()
# Out:
# <style type="text/css">
# #T_e0c57 th {
#   text-align: left;
# }
# #T_e0c57_row0_col0, #T_e0c57_row0_col1, #T_e0c57_row1_col0, #T_e0c57_row1_col1, #T_e0c57_row2_col0, #T_e0c57_row2_col1, #T_e0c57_row3_col0, #T_e0c57_row3_col1, #T_e0c57_row4_col0, #T_e0c57_row4_col1, #T_e0c57_row5_col0, #T_e0c57_row5_col1, #T_e0c57_row6_col0, #T_e0c57_row6_col1, #T_e0c57_row7_col0, #T_e0c57_row7_col1, #T_e0c57_row8_col0, #T_e0c57_row8_col1, #T_e0c57_row9_col0, #T_e0c57_row9_col1, #T_e0c57_row10_col0, #T_e0c57_row10_col1, #T_e0c57_row11_col0, #T_e0c57_row11_col1, #T_e0c57_row12_col0, #T_e0c57_row12_col1, #T_e0c57_row13_col0, #T_e0c57_row13_col1, #T_e0c57_row14_col0, #T_e0c57_row14_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_e0c57" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_e0c57_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_e0c57_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e0c57_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_e0c57_row0_col1" class="data row0 col1" >PLACE_hades_air_pollution_england_wales_hh</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_e0c57_row1_col1" class="data row1 col1" >University of Leicester, Centre for Environmental Health and Sustainability and City St George's, University of London, Population Health Research Institute. (2025). <i>Place based data: HADES Air Pollution England Wales Household.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00422-01" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00422-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_e0c57_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00422-01" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00422-01" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00422-01" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row3_col0" class="data row3 col0" >Owner</td>
#       <td id="T_e0c57_row3_col1" class="data row3 col1" >University of Leicester and St George's, University of London</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row4_col0" class="data row4 col0" >Authors</td>
#       <td id="T_e0c57_row4_col1" class="data row4 col1" >Calvin Jephcote (University of Leicester) and John Gulliver (City St George's, University of London)</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_e0c57_row5_col1" class="data row5 col1" >01/2018 - 12/2020</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row6_col0" class="data row6 col0" >Geographical Coverage</td>
#       <td id="T_e0c57_row6_col1" class="data row6 col1" >England and Wales</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_e0c57_row7_col1" class="data row7 col1" >30470</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row8_col0" class="data row8 col0" >Number of Variables</td>
#       <td id="T_e0c57_row8_col1" class="data row8 col1" >235</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row9_col0" class="data row9 col0" >Number of Observations</td>
#       <td id="T_e0c57_row9_col1" class="data row9 col1" >89103</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row10_col0" class="data row10 col0" >Key Link</td>
#       <td id="T_e0c57_row10_col1" class="data row10 col1" > <a href=" https://doi.org/10.1016/j.envint.2025.109304 " rel="noopener noreferrer" target="_blank"> https://doi.org/10.1016/j.envint.2025.109304 </a></td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row11_col0" class="data row11 col0" >Keywords</td>
#       <td id="T_e0c57_row11_col1" class="data row11 col1" >O3,NO2,air pollution,geospatial,environmental</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row12_col0" class="data row12 col0" >Latest Extract Date</td>
#       <td id="T_e0c57_row12_col1" class="data row12 col1" >TBC</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row13_col0" class="data row13 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_e0c57_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_e0c57_row14_col0" class="data row14 col0" >Build a Data Request</td>
#       <td id="T_e0c57_row14_col1" class="data row14 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
display(Markdown('### hades_air_pollution_england_wales_pc'))
# Out:
# ### hades_air_pollution_england_wales_pc

# %%
DS("hades_air_pollution_england_wales_pc").info_table()
# Out:
# <style type="text/css">
# #T_217ef th {
#   text-align: left;
# }
# #T_217ef_row0_col0, #T_217ef_row0_col1, #T_217ef_row1_col0, #T_217ef_row1_col1, #T_217ef_row2_col0, #T_217ef_row2_col1, #T_217ef_row3_col0, #T_217ef_row3_col1, #T_217ef_row4_col0, #T_217ef_row4_col1, #T_217ef_row5_col0, #T_217ef_row5_col1, #T_217ef_row6_col0, #T_217ef_row6_col1, #T_217ef_row7_col0, #T_217ef_row7_col1, #T_217ef_row8_col0, #T_217ef_row8_col1, #T_217ef_row9_col0, #T_217ef_row9_col1, #T_217ef_row10_col0, #T_217ef_row10_col1, #T_217ef_row11_col0, #T_217ef_row11_col1, #T_217ef_row12_col0, #T_217ef_row12_col1, #T_217ef_row13_col0, #T_217ef_row13_col1, #T_217ef_row14_col0, #T_217ef_row14_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_217ef" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_217ef_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_217ef_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_217ef_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_217ef_row0_col1" class="data row0 col1" >PLACE_hades_air_pollution_england_wales_pc</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_217ef_row1_col1" class="data row1 col1" >University of Leicester, Centre for Environmental Health and Sustainability and City St George's, University of London, Population Health Research Institute. (2025). <i>Place based data: HADES Air Pollution England Wales Postcode.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00423-01" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00423-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_217ef_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00423-01" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00423-01" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00423-01" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row3_col0" class="data row3 col0" >Owner</td>
#       <td id="T_217ef_row3_col1" class="data row3 col1" >University of Leicester and St George's, University of London</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row4_col0" class="data row4 col0" >Authors</td>
#       <td id="T_217ef_row4_col1" class="data row4 col1" >Calvin Jephcote (University of Leicester) and John Gulliver (City St George's, University of London)</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_217ef_row5_col1" class="data row5 col1" >01/2018 - 12/2020</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row6_col0" class="data row6 col0" >Geographical Coverage</td>
#       <td id="T_217ef_row6_col1" class="data row6 col1" >England and Wales</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_217ef_row7_col1" class="data row7 col1" >24036</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row8_col0" class="data row8 col0" >Number of Variables</td>
#       <td id="T_217ef_row8_col1" class="data row8 col1" >235</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row9_col0" class="data row9 col0" >Number of Observations</td>
#       <td id="T_217ef_row9_col1" class="data row9 col1" >38079</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row10_col0" class="data row10 col0" >Key Link</td>
#       <td id="T_217ef_row10_col1" class="data row10 col1" > <a href=" https://doi.org/10.1016/j.envint.2025.109304 " rel="noopener noreferrer" target="_blank"> https://doi.org/10.1016/j.envint.2025.109304 </a></td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row11_col0" class="data row11 col0" >Keywords</td>
#       <td id="T_217ef_row11_col1" class="data row11 col1" >O3,NO2,air pollution,geospatial,environmental</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row12_col0" class="data row12 col0" >Latest Extract Date</td>
#       <td id="T_217ef_row12_col1" class="data row12 col1" >TBC</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row13_col0" class="data row13 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_217ef_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_217ef_row14_col0" class="data row14 col0" >Build a Data Request</td>
#       <td id="T_217ef_row14_col1" class="data row14 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Variables

# %%
display(Markdown('### hades_air_pollution_england_wales_hh'))
# Out:
# ### hades_air_pollution_england_wales_hh

# %%
DS("hades_air_pollution_england_wales_hh").variable_table()
# Out:
# <style type="text/css">
# #T_f1b9f th {
#   text-align: left;
# }
# #T_f1b9f_row0_col0, #T_f1b9f_row0_col1, #T_f1b9f_row0_col2, #T_f1b9f_row0_col3, #T_f1b9f_row0_col4, #T_f1b9f_row1_col0, #T_f1b9f_row1_col1, #T_f1b9f_row1_col2, #T_f1b9f_row1_col3, #T_f1b9f_row1_col4, #T_f1b9f_row2_col0, #T_f1b9f_row2_col1, #T_f1b9f_row2_col2, #T_f1b9f_row2_col3, #T_f1b9f_row2_col4, #T_f1b9f_row3_col0, #T_f1b9f_row3_col1, #T_f1b9f_row3_col2, #T_f1b9f_row3_col3, #T_f1b9f_row3_col4, #T_f1b9f_row4_col0, #T_f1b9f_row4_col1, #T_f1b9f_row4_col2, #T_f1b9f_row4_col3, #T_f1b9f_row4_col4, #T_f1b9f_row5_col0, #T_f1b9f_row5_col1, #T_f1b9f_row5_col2, #T_f1b9f_row5_col3, #T_f1b9f_row5_col4, #T_f1b9f_row6_col0, #T_f1b9f_row6_col1, #T_f1b9f_row6_col2, #T_f1b9f_row6_col3, #T_f1b9f_row6_col4, #T_f1b9f_row7_col0, #T_f1b9f_row7_col1, #T_f1b9f_row7_col2, #T_f1b9f_row7_col3, #T_f1b9f_row7_col4, #T_f1b9f_row8_col0, #T_f1b9f_row8_col1, #T_f1b9f_row8_col2, #T_f1b9f_row8_col3, #T_f1b9f_row8_col4, #T_f1b9f_row9_col0, #T_f1b9f_row9_col1, #T_f1b9f_row9_col2, #T_f1b9f_row9_col3, #T_f1b9f_row9_col4, #T_f1b9f_row10_col0, #T_f1b9f_row10_col1, #T_f1b9f_row10_col2, #T_f1b9f_row10_col3, #T_f1b9f_row10_col4, #T_f1b9f_row11_col0, #T_f1b9f_row11_col1, #T_f1b9f_row11_col2, #T_f1b9f_row11_col3, #T_f1b9f_row11_col4, #T_f1b9f_row12_col0, #T_f1b9f_row12_col1, #T_f1b9f_row12_col2, #T_f1b9f_row12_col3, #T_f1b9f_row12_col4, #T_f1b9f_row13_col0, #T_f1b9f_row13_col1, #T_f1b9f_row13_col2, #T_f1b9f_row13_col3, #T_f1b9f_row13_col4, #T_f1b9f_row14_col0, #T_f1b9f_row14_col1, #T_f1b9f_row14_col2, #T_f1b9f_row14_col3, #T_f1b9f_row14_col4, #T_f1b9f_row15_col0, #T_f1b9f_row15_col1, #T_f1b9f_row15_col2, #T_f1b9f_row15_col3, #T_f1b9f_row15_col4, #T_f1b9f_row16_col0, #T_f1b9f_row16_col1, #T_f1b9f_row16_col2, #T_f1b9f_row16_col3, #T_f1b9f_row16_col4, #T_f1b9f_row17_col0, #T_f1b9f_row17_col1, #T_f1b9f_row17_col2, #T_f1b9f_row17_col3, #T_f1b9f_row17_col4, #T_f1b9f_row18_col0, #T_f1b9f_row18_col1, #T_f1b9f_row18_col2, #T_f1b9f_row18_col3, #T_f1b9f_row18_col4, #T_f1b9f_row19_col0, #T_f1b9f_row19_col1, #T_f1b9f_row19_col2, #T_f1b9f_row19_col3, #T_f1b9f_row19_col4, #T_f1b9f_row20_col0, #T_f1b9f_row20_col1, #T_f1b9f_row20_col2, #T_f1b9f_row20_col3, #T_f1b9f_row20_col4, #T_f1b9f_row21_col0, #T_f1b9f_row21_col1, #T_f1b9f_row21_col2, #T_f1b9f_row21_col3, #T_f1b9f_row21_col4, #T_f1b9f_row22_col0, #T_f1b9f_row22_col1, #T_f1b9f_row22_col2, #T_f1b9f_row22_col3, #T_f1b9f_row22_col4, #T_f1b9f_row23_col0, #T_f1b9f_row23_col1, #T_f1b9f_row23_col2, #T_f1b9f_row23_col3, #T_f1b9f_row23_col4, #T_f1b9f_row24_col0, #T_f1b9f_row24_col1, #T_f1b9f_row24_col2, #T_f1b9f_row24_col3, #T_f1b9f_row24_col4, #T_f1b9f_row25_col0, #T_f1b9f_row25_col1, #T_f1b9f_row25_col2, #T_f1b9f_row25_col3, #T_f1b9f_row25_col4, #T_f1b9f_row26_col0, #T_f1b9f_row26_col1, #T_f1b9f_row26_col2, #T_f1b9f_row26_col3, #T_f1b9f_row26_col4, #T_f1b9f_row27_col0, #T_f1b9f_row27_col1, #T_f1b9f_row27_col2, #T_f1b9f_row27_col3, #T_f1b9f_row27_col4, #T_f1b9f_row28_col0, #T_f1b9f_row28_col1, #T_f1b9f_row28_col2, #T_f1b9f_row28_col3, #T_f1b9f_row28_col4, #T_f1b9f_row29_col0, #T_f1b9f_row29_col1, #T_f1b9f_row29_col2, #T_f1b9f_row29_col3, #T_f1b9f_row29_col4, #T_f1b9f_row30_col0, #T_f1b9f_row30_col1, #T_f1b9f_row30_col2, #T_f1b9f_row30_col3, #T_f1b9f_row30_col4, #T_f1b9f_row31_col0, #T_f1b9f_row31_col1, #T_f1b9f_row31_col2, #T_f1b9f_row31_col3, #T_f1b9f_row31_col4, #T_f1b9f_row32_col0, #T_f1b9f_row32_col1, #T_f1b9f_row32_col2, #T_f1b9f_row32_col3, #T_f1b9f_row32_col4, #T_f1b9f_row33_col0, #T_f1b9f_row33_col1, #T_f1b9f_row33_col2, #T_f1b9f_row33_col3, #T_f1b9f_row33_col4, #T_f1b9f_row34_col0, #T_f1b9f_row34_col1, #T_f1b9f_row34_col2, #T_f1b9f_row34_col3, #T_f1b9f_row34_col4, #T_f1b9f_row35_col0, #T_f1b9f_row35_col1, #T_f1b9f_row35_col2, #T_f1b9f_row35_col3, #T_f1b9f_row35_col4, #T_f1b9f_row36_col0, #T_f1b9f_row36_col1, #T_f1b9f_row36_col2, #T_f1b9f_row36_col3, #T_f1b9f_row36_col4, #T_f1b9f_row37_col0, #T_f1b9f_row37_col1, #T_f1b9f_row37_col2, #T_f1b9f_row37_col3, #T_f1b9f_row37_col4, #T_f1b9f_row38_col0, #T_f1b9f_row38_col1, #T_f1b9f_row38_col ...

# %%
display(Markdown('### hades_air_pollution_england_wales_pc'))
# Out:
# ### hades_air_pollution_england_wales_pc

# %%
DS("hades_air_pollution_england_wales_pc").variable_table()
# Out:
# <style type="text/css">
# #T_559e9 th {
#   text-align: left;
# }
# #T_559e9_row0_col0, #T_559e9_row0_col1, #T_559e9_row0_col2, #T_559e9_row0_col3, #T_559e9_row0_col4, #T_559e9_row1_col0, #T_559e9_row1_col1, #T_559e9_row1_col2, #T_559e9_row1_col3, #T_559e9_row1_col4, #T_559e9_row2_col0, #T_559e9_row2_col1, #T_559e9_row2_col2, #T_559e9_row2_col3, #T_559e9_row2_col4, #T_559e9_row3_col0, #T_559e9_row3_col1, #T_559e9_row3_col2, #T_559e9_row3_col3, #T_559e9_row3_col4, #T_559e9_row4_col0, #T_559e9_row4_col1, #T_559e9_row4_col2, #T_559e9_row4_col3, #T_559e9_row4_col4, #T_559e9_row5_col0, #T_559e9_row5_col1, #T_559e9_row5_col2, #T_559e9_row5_col3, #T_559e9_row5_col4, #T_559e9_row6_col0, #T_559e9_row6_col1, #T_559e9_row6_col2, #T_559e9_row6_col3, #T_559e9_row6_col4, #T_559e9_row7_col0, #T_559e9_row7_col1, #T_559e9_row7_col2, #T_559e9_row7_col3, #T_559e9_row7_col4, #T_559e9_row8_col0, #T_559e9_row8_col1, #T_559e9_row8_col2, #T_559e9_row8_col3, #T_559e9_row8_col4, #T_559e9_row9_col0, #T_559e9_row9_col1, #T_559e9_row9_col2, #T_559e9_row9_col3, #T_559e9_row9_col4, #T_559e9_row10_col0, #T_559e9_row10_col1, #T_559e9_row10_col2, #T_559e9_row10_col3, #T_559e9_row10_col4, #T_559e9_row11_col0, #T_559e9_row11_col1, #T_559e9_row11_col2, #T_559e9_row11_col3, #T_559e9_row11_col4, #T_559e9_row12_col0, #T_559e9_row12_col1, #T_559e9_row12_col2, #T_559e9_row12_col3, #T_559e9_row12_col4, #T_559e9_row13_col0, #T_559e9_row13_col1, #T_559e9_row13_col2, #T_559e9_row13_col3, #T_559e9_row13_col4, #T_559e9_row14_col0, #T_559e9_row14_col1, #T_559e9_row14_col2, #T_559e9_row14_col3, #T_559e9_row14_col4, #T_559e9_row15_col0, #T_559e9_row15_col1, #T_559e9_row15_col2, #T_559e9_row15_col3, #T_559e9_row15_col4, #T_559e9_row16_col0, #T_559e9_row16_col1, #T_559e9_row16_col2, #T_559e9_row16_col3, #T_559e9_row16_col4, #T_559e9_row17_col0, #T_559e9_row17_col1, #T_559e9_row17_col2, #T_559e9_row17_col3, #T_559e9_row17_col4, #T_559e9_row18_col0, #T_559e9_row18_col1, #T_559e9_row18_col2, #T_559e9_row18_col3, #T_559e9_row18_col4, #T_559e9_row19_col0, #T_559e9_row19_col1, #T_559e9_row19_col2, #T_559e9_row19_col3, #T_559e9_row19_col4, #T_559e9_row20_col0, #T_559e9_row20_col1, #T_559e9_row20_col2, #T_559e9_row20_col3, #T_559e9_row20_col4, #T_559e9_row21_col0, #T_559e9_row21_col1, #T_559e9_row21_col2, #T_559e9_row21_col3, #T_559e9_row21_col4, #T_559e9_row22_col0, #T_559e9_row22_col1, #T_559e9_row22_col2, #T_559e9_row22_col3, #T_559e9_row22_col4, #T_559e9_row23_col0, #T_559e9_row23_col1, #T_559e9_row23_col2, #T_559e9_row23_col3, #T_559e9_row23_col4, #T_559e9_row24_col0, #T_559e9_row24_col1, #T_559e9_row24_col2, #T_559e9_row24_col3, #T_559e9_row24_col4, #T_559e9_row25_col0, #T_559e9_row25_col1, #T_559e9_row25_col2, #T_559e9_row25_col3, #T_559e9_row25_col4, #T_559e9_row26_col0, #T_559e9_row26_col1, #T_559e9_row26_col2, #T_559e9_row26_col3, #T_559e9_row26_col4, #T_559e9_row27_col0, #T_559e9_row27_col1, #T_559e9_row27_col2, #T_559e9_row27_col3, #T_559e9_row27_col4, #T_559e9_row28_col0, #T_559e9_row28_col1, #T_559e9_row28_col2, #T_559e9_row28_col3, #T_559e9_row28_col4, #T_559e9_row29_col0, #T_559e9_row29_col1, #T_559e9_row29_col2, #T_559e9_row29_col3, #T_559e9_row29_col4, #T_559e9_row30_col0, #T_559e9_row30_col1, #T_559e9_row30_col2, #T_559e9_row30_col3, #T_559e9_row30_col4, #T_559e9_row31_col0, #T_559e9_row31_col1, #T_559e9_row31_col2, #T_559e9_row31_col3, #T_559e9_row31_col4, #T_559e9_row32_col0, #T_559e9_row32_col1, #T_559e9_row32_col2, #T_559e9_row32_col3, #T_559e9_row32_col4, #T_559e9_row33_col0, #T_559e9_row33_col1, #T_559e9_row33_col2, #T_559e9_row33_col3, #T_559e9_row33_col4, #T_559e9_row34_col0, #T_559e9_row34_col1, #T_559e9_row34_col2, #T_559e9_row34_col3, #T_559e9_row34_col4, #T_559e9_row35_col0, #T_559e9_row35_col1, #T_559e9_row35_col2, #T_559e9_row35_col3, #T_559e9_row35_col4, #T_559e9_row36_col0, #T_559e9_row36_col1, #T_559e9_row36_col2, #T_559e9_row36_col3, #T_559e9_row36_col4, #T_559e9_row37_col0, #T_559e9_row37_col1, #T_559e9_row37_col2, #T_559e9_row37_col3, #T_559e9_row37_col4, #T_559e9_row38_col0, #T_559e9_row38_col1, #T_559e9_row38_col ...

# %% [markdown]
# ## 3. Metrics

# %%
display(Markdown('TBC'))
# Out:
# TBC

# %% [markdown]
# ## 4. Version History

# %%
display(Markdown('TBC'))
# Out:
# TBC

# %% [markdown]
# ## 5. Documentation

# %%
DS("hades_air_pollution_england_wales_pc").documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 5. Useful Syntax

# %%
DS("hades_air_pollution_england_wales_pc").useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to the [UK LLC GitHub](https://github.com/UKLLC) repository where you can find the full scripts.
