# %% [markdown]
# # Index of Multiple Deprivation (IMD)

# %%
from IPython.display import display, Markdown
import sys
import os
sys.path.append(os.path.abspath('../../../scripts/'))
from data_doc_helper import PlaceDataSet as DS, last_modified
last_modified()
# Out:
# >Last modified: 01 Jun 2026

# %%
display(Markdown('<div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC provides a dataset containing UK-wide harmonised measures of indices of multiple deprivation, an urban-rural indicator and population density.</strong></div>'))
# Out:
# <div style="background-color: rgba(0, 178, 169, 0.3); padding: 5px; border-radius: 5px;"><strong>UK LLC provides a dataset containing UK-wide harmonised measures of indices of multiple deprivation, an urban-rural indicator and population density.</strong></div>

# %%
display(Markdown('<div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="understanding_imd.html" target="_blank">here.</a></strong></div>'))
# Out:
# <div style="background-color: rgb(229, 106, 84, 0.3); padding: 5px; border-radius: 5px;"><strong>More information about this dataset is available <a href="understanding_imd.html" target="_blank">here.</a></strong></div>

# %% [markdown]
# ## IMD, urban/rural classification and population estimates
#
# This dataset is made up of the following three sources of data: Index of Multiple Deprivation, an Urban-Rural Indicator and Population Estimates.
#
# The Index of Deprivation datasets differ across the four UK nations, but each provide small area measures of relative deprivation. Each national index ranks areas from most deprived to least deprived, based on measures of deprivation such as income, education, health and employment.
#
# Urban-Rural classifications also differ across the four nations but overall provide an indicator of which areas rural and which are urban based on characteristics such as dwelling densities and distance to major towns and cities.
#
# The National Records of Scotland (NRS), Northern Ireland Statistics and Research Agency (NISRA) and the Office of National Statistics (ONS) produce national mid-year population estimates.
#
# This dataset also includes harmonised variables for the [Indices of Multiple Deprivation](https://data.geods.ac.uk/dataset/index-of-multiple-deprivation-imd) and [Urban-Rural classification](https://pages.mysociety.org/uk_ruc/analysis/background_and_analysis.html) across the UK.
#
#
# ## 1. Summary

# %%
display(Markdown('### imd_england'))
# Out:
# ### imd_england

# %%
DS("imd_england").info_table()
# Out:
# <style type="text/css">
# #T_04f18_row0_col0, #T_04f18_row0_col1, #T_04f18_row1_col0, #T_04f18_row1_col1, #T_04f18_row2_col0, #T_04f18_row2_col1, #T_04f18_row3_col0, #T_04f18_row3_col1, #T_04f18_row4_col0, #T_04f18_row4_col1, #T_04f18_row5_col0, #T_04f18_row5_col1, #T_04f18_row6_col0, #T_04f18_row6_col1, #T_04f18_row7_col0, #T_04f18_row7_col1, #T_04f18_row8_col0, #T_04f18_row8_col1, #T_04f18_row9_col0, #T_04f18_row9_col1, #T_04f18_row10_col0, #T_04f18_row10_col1, #T_04f18_row11_col0, #T_04f18_row11_col1, #T_04f18_row12_col0, #T_04f18_row12_col1, #T_04f18_row13_col0, #T_04f18_row13_col1, #T_04f18_row14_col0, #T_04f18_row14_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_04f18" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_04f18_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_04f18_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_04f18_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_04f18_row0_col1" class="data row0 col1" >PLACE_imd_england</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_04f18_row1_col1" class="data row1 col1" >UK Longitudinal Linkage Collaboration. (2025). <i>Place based data: IMD England.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00424-01" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00424-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_04f18_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00424-01" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00424-01" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00424-01" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row3_col0" class="data row3 col0" >Owner</td>
#       <td id="T_04f18_row3_col1" class="data row3 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row4_col0" class="data row4 col0" >Authors</td>
#       <td id="T_04f18_row4_col1" class="data row4 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_04f18_row5_col1" class="data row5 col1" >01/2011 - 12/2020</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row6_col0" class="data row6 col0" >Geographical Coverage</td>
#       <td id="T_04f18_row6_col1" class="data row6 col1" >England</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_04f18_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row8_col0" class="data row8 col0" >Number of Variables</td>
#       <td id="T_04f18_row8_col1" class="data row8 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row9_col0" class="data row9 col0" >Number of Observations</td>
#       <td id="T_04f18_row9_col1" class="data row9 col1" >32844</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row10_col0" class="data row10 col0" >Key Link</td>
#       <td id="T_04f18_row10_col1" class="data row10 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd" rel="noopener noreferrer" target="_blank">https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd</a></td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row11_col0" class="data row11 col0" >Keywords</td>
#       <td id="T_04f18_row11_col1" class="data row11 col1" >IMD,deprivation,population,urban-rural</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row12_col0" class="data row12 col0" >Latest Extract Date</td>
#       <td id="T_04f18_row12_col1" class="data row12 col1" >TBC</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row13_col0" class="data row13 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_04f18_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_04f18_row14_col0" class="data row14 col0" >Build a Data Request</td>
#       <td id="T_04f18_row14_col1" class="data row14 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
display(Markdown('### imd_northern_ireland'))
# Out:
# ### imd_northern_ireland

# %%
DS("imd_northern_ireland").info_table()
# Out:
# <style type="text/css">
# #T_baeb9_row0_col0, #T_baeb9_row0_col1, #T_baeb9_row1_col0, #T_baeb9_row1_col1, #T_baeb9_row2_col0, #T_baeb9_row2_col1, #T_baeb9_row3_col0, #T_baeb9_row3_col1, #T_baeb9_row4_col0, #T_baeb9_row4_col1, #T_baeb9_row5_col0, #T_baeb9_row5_col1, #T_baeb9_row6_col0, #T_baeb9_row6_col1, #T_baeb9_row7_col0, #T_baeb9_row7_col1, #T_baeb9_row8_col0, #T_baeb9_row8_col1, #T_baeb9_row9_col0, #T_baeb9_row9_col1, #T_baeb9_row10_col0, #T_baeb9_row10_col1, #T_baeb9_row11_col0, #T_baeb9_row11_col1, #T_baeb9_row12_col0, #T_baeb9_row12_col1, #T_baeb9_row13_col0, #T_baeb9_row13_col1, #T_baeb9_row14_col0, #T_baeb9_row14_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_baeb9" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_baeb9_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_baeb9_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_baeb9_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_baeb9_row0_col1" class="data row0 col1" >PLACE_imd_northern_ireland</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_baeb9_row1_col1" class="data row1 col1" >UK Longitudinal Linkage Collaboration. (2025). <i>Place based data: IMD Northern Ireland.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00425-01" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00425-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_baeb9_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00425-01" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00425-01" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00425-01" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row3_col0" class="data row3 col0" >Owner</td>
#       <td id="T_baeb9_row3_col1" class="data row3 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row4_col0" class="data row4 col0" >Authors</td>
#       <td id="T_baeb9_row4_col1" class="data row4 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_baeb9_row5_col1" class="data row5 col1" >01/2011 - 12/2020</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row6_col0" class="data row6 col0" >Geographical Coverage</td>
#       <td id="T_baeb9_row6_col1" class="data row6 col1" >Northern Ireland</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_baeb9_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row8_col0" class="data row8 col0" >Number of Variables</td>
#       <td id="T_baeb9_row8_col1" class="data row8 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row9_col0" class="data row9 col0" >Number of Observations</td>
#       <td id="T_baeb9_row9_col1" class="data row9 col1" >890</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row10_col0" class="data row10 col0" >Key Link</td>
#       <td id="T_baeb9_row10_col1" class="data row10 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd" rel="noopener noreferrer" target="_blank">https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd</a></td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row11_col0" class="data row11 col0" >Keywords</td>
#       <td id="T_baeb9_row11_col1" class="data row11 col1" >IMD,deprivation,population,urban-rural</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row12_col0" class="data row12 col0" >Latest Extract Date</td>
#       <td id="T_baeb9_row12_col1" class="data row12 col1" >TBC</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row13_col0" class="data row13 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_baeb9_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_baeb9_row14_col0" class="data row14 col0" >Build a Data Request</td>
#       <td id="T_baeb9_row14_col1" class="data row14 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
display(Markdown('### imd_scotland'))
# Out:
# ### imd_scotland

# %%
DS("imd_scotland").info_table()
# Out:
# <style type="text/css">
# #T_bebce_row0_col0, #T_bebce_row0_col1, #T_bebce_row1_col0, #T_bebce_row1_col1, #T_bebce_row2_col0, #T_bebce_row2_col1, #T_bebce_row3_col0, #T_bebce_row3_col1, #T_bebce_row4_col0, #T_bebce_row4_col1, #T_bebce_row5_col0, #T_bebce_row5_col1, #T_bebce_row6_col0, #T_bebce_row6_col1, #T_bebce_row7_col0, #T_bebce_row7_col1, #T_bebce_row8_col0, #T_bebce_row8_col1, #T_bebce_row9_col0, #T_bebce_row9_col1, #T_bebce_row10_col0, #T_bebce_row10_col1, #T_bebce_row11_col0, #T_bebce_row11_col1, #T_bebce_row12_col0, #T_bebce_row12_col1, #T_bebce_row13_col0, #T_bebce_row13_col1, #T_bebce_row14_col0, #T_bebce_row14_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_bebce" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_bebce_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_bebce_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bebce_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_bebce_row0_col1" class="data row0 col1" >PLACE_imd_scotland</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_bebce_row1_col1" class="data row1 col1" >UK Longitudinal Linkage Collaboration. (2025). <i>Place based data: IMD Scotland.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00426-01" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00426-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_bebce_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00426-01" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00426-01" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00426-01" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row3_col0" class="data row3 col0" >Owner</td>
#       <td id="T_bebce_row3_col1" class="data row3 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row4_col0" class="data row4 col0" >Authors</td>
#       <td id="T_bebce_row4_col1" class="data row4 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_bebce_row5_col1" class="data row5 col1" >01/2011 - 12/2020</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row6_col0" class="data row6 col0" >Geographical Coverage</td>
#       <td id="T_bebce_row6_col1" class="data row6 col1" >Scotland</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_bebce_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row8_col0" class="data row8 col0" >Number of Variables</td>
#       <td id="T_bebce_row8_col1" class="data row8 col1" >15</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row9_col0" class="data row9 col0" >Number of Observations</td>
#       <td id="T_bebce_row9_col1" class="data row9 col1" >6976</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row10_col0" class="data row10 col0" >Key Link</td>
#       <td id="T_bebce_row10_col1" class="data row10 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd" rel="noopener noreferrer" target="_blank">https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd</a></td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row11_col0" class="data row11 col0" >Keywords</td>
#       <td id="T_bebce_row11_col1" class="data row11 col1" >IMD,deprivation,population,urban-rural</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row12_col0" class="data row12 col0" >Latest Extract Date</td>
#       <td id="T_bebce_row12_col1" class="data row12 col1" >TBC</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row13_col0" class="data row13 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_bebce_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_bebce_row14_col0" class="data row14 col0" >Build a Data Request</td>
#       <td id="T_bebce_row14_col1" class="data row14 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
display(Markdown('### imd_wales'))
# Out:
# ### imd_wales

# %%
DS("imd_wales").info_table()
# Out:
# <style type="text/css">
# #T_20955_row0_col0, #T_20955_row0_col1, #T_20955_row1_col0, #T_20955_row1_col1, #T_20955_row2_col0, #T_20955_row2_col1, #T_20955_row3_col0, #T_20955_row3_col1, #T_20955_row4_col0, #T_20955_row4_col1, #T_20955_row5_col0, #T_20955_row5_col1, #T_20955_row6_col0, #T_20955_row6_col1, #T_20955_row7_col0, #T_20955_row7_col1, #T_20955_row8_col0, #T_20955_row8_col1, #T_20955_row9_col0, #T_20955_row9_col1, #T_20955_row10_col0, #T_20955_row10_col1, #T_20955_row11_col0, #T_20955_row11_col1, #T_20955_row12_col0, #T_20955_row12_col1, #T_20955_row13_col0, #T_20955_row13_col1, #T_20955_row14_col0, #T_20955_row14_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_20955" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_20955_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_20955_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_20955_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_20955_row0_col1" class="data row0 col1" >PLACE_imd_wales</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_20955_row1_col1" class="data row1 col1" >UK Longitudinal Linkage Collaboration. (2025). <i>Place based data: IMD Wales.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00427-01" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00427-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_20955_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_20955_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00427-01" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00427-01" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00427-01" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_20955_row3_col0" class="data row3 col0" >Owner</td>
#       <td id="T_20955_row3_col1" class="data row3 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row4_col0" class="data row4 col0" >Authors</td>
#       <td id="T_20955_row4_col1" class="data row4 col1" >UK Longitudinal Linkage Collaboration</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_20955_row5_col1" class="data row5 col1" >01/2011 - 12/2020</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row6_col0" class="data row6 col0" >Geographical Coverage</td>
#       <td id="T_20955_row6_col1" class="data row6 col1" >Wales</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row7_col0" class="data row7 col0" >Participant Count</td>
#       <td id="T_20955_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row8_col0" class="data row8 col0" >Number of Variables</td>
#       <td id="T_20955_row8_col1" class="data row8 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row9_col0" class="data row9 col0" >Number of Observations</td>
#       <td id="T_20955_row9_col1" class="data row9 col1" >1909</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row10_col0" class="data row10 col0" >Key Link</td>
#       <td id="T_20955_row10_col1" class="data row10 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd" rel="noopener noreferrer" target="_blank">https://guidebook.ukllc.ac.uk/docs/linked_geo_data/population_datasets/imd/imd</a></td>
#     </tr>
#     <tr>
#       <td id="T_20955_row11_col0" class="data row11 col0" >Keywords</td>
#       <td id="T_20955_row11_col1" class="data row11 col1" >IMD,deprivation,population,urban-rural</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row12_col0" class="data row12 col0" >Latest Extract Date</td>
#       <td id="T_20955_row12_col1" class="data row12 col1" >TBC</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row13_col0" class="data row13 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_20955_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_20955_row14_col0" class="data row14 col0" >Build a Data Request</td>
#       <td id="T_20955_row14_col1" class="data row14 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Variables

# %%
display(Markdown('### imd_england'))
# Out:
# ### imd_england

# %%
DS("imd_england").variable_table()
# Out:
# <style type="text/css">
# #T_5a74b_row0_col0, #T_5a74b_row0_col1, #T_5a74b_row0_col2, #T_5a74b_row0_col3, #T_5a74b_row0_col4, #T_5a74b_row1_col0, #T_5a74b_row1_col1, #T_5a74b_row1_col2, #T_5a74b_row1_col3, #T_5a74b_row1_col4, #T_5a74b_row2_col0, #T_5a74b_row2_col1, #T_5a74b_row2_col2, #T_5a74b_row2_col3, #T_5a74b_row2_col4, #T_5a74b_row3_col0, #T_5a74b_row3_col1, #T_5a74b_row3_col2, #T_5a74b_row3_col3, #T_5a74b_row3_col4, #T_5a74b_row4_col0, #T_5a74b_row4_col1, #T_5a74b_row4_col2, #T_5a74b_row4_col3, #T_5a74b_row4_col4, #T_5a74b_row5_col0, #T_5a74b_row5_col1, #T_5a74b_row5_col2, #T_5a74b_row5_col3, #T_5a74b_row5_col4, #T_5a74b_row6_col0, #T_5a74b_row6_col1, #T_5a74b_row6_col2, #T_5a74b_row6_col3, #T_5a74b_row6_col4, #T_5a74b_row7_col0, #T_5a74b_row7_col1, #T_5a74b_row7_col2, #T_5a74b_row7_col3, #T_5a74b_row7_col4, #T_5a74b_row8_col0, #T_5a74b_row8_col1, #T_5a74b_row8_col2, #T_5a74b_row8_col3, #T_5a74b_row8_col4, #T_5a74b_row9_col0, #T_5a74b_row9_col1, #T_5a74b_row9_col2, #T_5a74b_row9_col3, #T_5a74b_row9_col4, #T_5a74b_row10_col0, #T_5a74b_row10_col1, #T_5a74b_row10_col2, #T_5a74b_row10_col3, #T_5a74b_row10_col4, #T_5a74b_row11_col0, #T_5a74b_row11_col1, #T_5a74b_row11_col2, #T_5a74b_row11_col3, #T_5a74b_row11_col4, #T_5a74b_row12_col0, #T_5a74b_row12_col1, #T_5a74b_row12_col2, #T_5a74b_row12_col3, #T_5a74b_row12_col4, #T_5a74b_row13_col0, #T_5a74b_row13_col1, #T_5a74b_row13_col2, #T_5a74b_row13_col3, #T_5a74b_row13_col4, #T_5a74b_row14_col0, #T_5a74b_row14_col1, #T_5a74b_row14_col2, #T_5a74b_row14_col3, #T_5a74b_row14_col4, #T_5a74b_row15_col0, #T_5a74b_row15_col1, #T_5a74b_row15_col2, #T_5a74b_row15_col3, #T_5a74b_row15_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_5a74b" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_5a74b_level0_col0" class="col_heading level0 col0" >Variable Group</th>
#       <th id="T_5a74b_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_5a74b_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_5a74b_level0_col3" class="col_heading level0 col3" >Source</th>
#       <th id="T_5a74b_level0_col4" class="col_heading level0 col4" >Date range of data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5a74b_row0_col0" class="data row0 col0" >UK LLC</td>
#       <td id="T_5a74b_row0_col1" class="data row0 col1" >avail_from_dt</td>
#       <td id="T_5a74b_row0_col2" class="data row0 col2" >label not available</td>
#       <td id="T_5a74b_row0_col3" class="data row0 col3" >UK Longitudinal Linkage Collaboration</td>
#       <td id="T_5a74b_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row1_col0" class="data row1 col0" >Geography</td>
#       <td id="T_5a74b_row1_col1" class="data row1 col1" >country</td>
#       <td id="T_5a74b_row1_col2" class="data row1 col2" >Country within the United Kingdom</td>
#       <td id="T_5a74b_row1_col3" class="data row1 col3" >Office for National Statistics</td>
#       <td id="T_5a74b_row1_col4" class="data row1 col4" >2011</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row2_col0" class="data row2 col0" >Deprivation</td>
#       <td id="T_5a74b_row2_col1" class="data row2 col1" >imd2019eng</td>
#       <td id="T_5a74b_row2_col2" class="data row2 col2" >English indices of deprivation 2019, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_5a74b_row2_col3" class="data row2 col3" >gov.uk</td>
#       <td id="T_5a74b_row2_col4" class="data row2 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row3_col0" class="data row3 col0" >Deprivation</td>
#       <td id="T_5a74b_row3_col1" class="data row3 col1" >imd2019eng_barriers</td>
#       <td id="T_5a74b_row3_col2" class="data row3 col2" >English indices of deprivation 2019, Barriers to Housing and Services, presented as quintiles. 1= high barriers, 5= low barriers.</td>
#       <td id="T_5a74b_row3_col3" class="data row3 col3" >gov.uk</td>
#       <td id="T_5a74b_row3_col4" class="data row3 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row4_col0" class="data row4 col0" >Deprivation</td>
#       <td id="T_5a74b_row4_col1" class="data row4 col1" >imd2019eng_crime</td>
#       <td id="T_5a74b_row4_col2" class="data row4 col2" >English indices of deprivation 2019, Crime, presented as quintiles. 1= high crime rates, 5= low crime rates.</td>
#       <td id="T_5a74b_row4_col3" class="data row4 col3" >gov.uk</td>
#       <td id="T_5a74b_row4_col4" class="data row4 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row5_col0" class="data row5 col0" >Deprivation</td>
#       <td id="T_5a74b_row5_col1" class="data row5 col1" >imd2019eng_education</td>
#       <td id="T_5a74b_row5_col2" class="data row5 col2" >English indices of deprivation 2019, Education, presented as quintiles. 1= lowest education and skills, 5= highest education and skills.</td>
#       <td id="T_5a74b_row5_col3" class="data row5 col3" >gov.uk</td>
#       <td id="T_5a74b_row5_col4" class="data row5 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row6_col0" class="data row6 col0" >Deprivation</td>
#       <td id="T_5a74b_row6_col1" class="data row6 col1" >imd2019eng_employment</td>
#       <td id="T_5a74b_row6_col2" class="data row6 col2" >English indices of deprivation 2019, Employment, presented as quintiles. 1=highest unemployment, 5= lowest unemployment.</td>
#       <td id="T_5a74b_row6_col3" class="data row6 col3" >gov.uk</td>
#       <td id="T_5a74b_row6_col4" class="data row6 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row7_col0" class="data row7 col0" >Deprivation</td>
#       <td id="T_5a74b_row7_col1" class="data row7 col1" >imd2019eng_environment</td>
#       <td id="T_5a74b_row7_col2" class="data row7 col2" >English indices of deprivation 2019, Environment, presented as quintiles. 1= low quality environment, 5= high quality environment.</td>
#       <td id="T_5a74b_row7_col3" class="data row7 col3" >gov.uk</td>
#       <td id="T_5a74b_row7_col4" class="data row7 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row8_col0" class="data row8 col0" >Deprivation</td>
#       <td id="T_5a74b_row8_col1" class="data row8 col1" >imd2019eng_health</td>
#       <td id="T_5a74b_row8_col2" class="data row8 col2" >English indices of deprivation 2019, Health, presented as quintiles. 1= high health deprivation, 5= low health deprivation.</td>
#       <td id="T_5a74b_row8_col3" class="data row8 col3" >gov.uk</td>
#       <td id="T_5a74b_row8_col4" class="data row8 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row9_col0" class="data row9 col0" >Deprivation</td>
#       <td id="T_5a74b_row9_col1" class="data row9 col1" >imd2019eng_income</td>
#       <td id="T_5a74b_row9_col2" class="data row9 col2" >English indices of deprivation 2019, Income, presented as quintiles. 1= lowest income, 5= highest income.</td>
#       <td id="T_5a74b_row9_col3" class="data row9 col3" >gov.uk</td>
#       <td id="T_5a74b_row9_col4" class="data row9 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row10_col0" class="data row10 col0" >Deprivation</td>
#       <td id="T_5a74b_row10_col1" class="data row10 col1" >imd2019har</td>
#       <td id="T_5a74b_row10_col2" class="data row10 col2" >Consumer Data Research Centre's Harmonised Index of Multiple Deprivation 2019, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_5a74b_row10_col3" class="data row10 col3" >Geographic Data Service, Smart Data Research UK</td>
#       <td id="T_5a74b_row10_col4" class="data row10 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row11_col0" class="data row11 col0" >Geography</td>
#       <td id="T_5a74b_row11_col1" class="data row11 col1" >lsoa11cd_e</td>
#       <td id="T_5a74b_row11_col2" class="data row11 col2" >Lower Super Output Area code (2011)</td>
#       <td id="T_5a74b_row11_col3" class="data row11 col3" >Office for National Statistics</td>
#       <td id="T_5a74b_row11_col4" class="data row11 col4" >2011</td>
#     </tr>
#     <tr>
#       <td id="T_5a74b_row12_col0" cla

# %%
display(Markdown('### imd_northern_ireland'))
# Out:
# ### imd_northern_ireland

# %%
DS("imd_northern_ireland").variable_table()
# Out:
# <style type="text/css">
# #T_f3683_row0_col0, #T_f3683_row0_col1, #T_f3683_row0_col2, #T_f3683_row0_col3, #T_f3683_row0_col4, #T_f3683_row1_col0, #T_f3683_row1_col1, #T_f3683_row1_col2, #T_f3683_row1_col3, #T_f3683_row1_col4, #T_f3683_row2_col0, #T_f3683_row2_col1, #T_f3683_row2_col2, #T_f3683_row2_col3, #T_f3683_row2_col4, #T_f3683_row3_col0, #T_f3683_row3_col1, #T_f3683_row3_col2, #T_f3683_row3_col3, #T_f3683_row3_col4, #T_f3683_row4_col0, #T_f3683_row4_col1, #T_f3683_row4_col2, #T_f3683_row4_col3, #T_f3683_row4_col4, #T_f3683_row5_col0, #T_f3683_row5_col1, #T_f3683_row5_col2, #T_f3683_row5_col3, #T_f3683_row5_col4, #T_f3683_row6_col0, #T_f3683_row6_col1, #T_f3683_row6_col2, #T_f3683_row6_col3, #T_f3683_row6_col4, #T_f3683_row7_col0, #T_f3683_row7_col1, #T_f3683_row7_col2, #T_f3683_row7_col3, #T_f3683_row7_col4, #T_f3683_row8_col0, #T_f3683_row8_col1, #T_f3683_row8_col2, #T_f3683_row8_col3, #T_f3683_row8_col4, #T_f3683_row9_col0, #T_f3683_row9_col1, #T_f3683_row9_col2, #T_f3683_row9_col3, #T_f3683_row9_col4, #T_f3683_row10_col0, #T_f3683_row10_col1, #T_f3683_row10_col2, #T_f3683_row10_col3, #T_f3683_row10_col4, #T_f3683_row11_col0, #T_f3683_row11_col1, #T_f3683_row11_col2, #T_f3683_row11_col3, #T_f3683_row11_col4, #T_f3683_row12_col0, #T_f3683_row12_col1, #T_f3683_row12_col2, #T_f3683_row12_col3, #T_f3683_row12_col4, #T_f3683_row13_col0, #T_f3683_row13_col1, #T_f3683_row13_col2, #T_f3683_row13_col3, #T_f3683_row13_col4, #T_f3683_row14_col0, #T_f3683_row14_col1, #T_f3683_row14_col2, #T_f3683_row14_col3, #T_f3683_row14_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_f3683" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_f3683_level0_col0" class="col_heading level0 col0" >Variable Group</th>
#       <th id="T_f3683_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_f3683_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_f3683_level0_col3" class="col_heading level0 col3" >Source</th>
#       <th id="T_f3683_level0_col4" class="col_heading level0 col4" >Date range of data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3683_row0_col0" class="data row0 col0" >UK LLC</td>
#       <td id="T_f3683_row0_col1" class="data row0 col1" >avail_from_dt</td>
#       <td id="T_f3683_row0_col2" class="data row0 col2" >label not available</td>
#       <td id="T_f3683_row0_col3" class="data row0 col3" >UK Longitudinal Linkage Collaboration</td>
#       <td id="T_f3683_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row1_col0" class="data row1 col0" >Geography</td>
#       <td id="T_f3683_row1_col1" class="data row1 col1" >country</td>
#       <td id="T_f3683_row1_col2" class="data row1 col2" >Country within the United Kingdom</td>
#       <td id="T_f3683_row1_col3" class="data row1 col3" >Office for National Statistics</td>
#       <td id="T_f3683_row1_col4" class="data row1 col4" >2011</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row2_col0" class="data row2 col0" >Deprivation</td>
#       <td id="T_f3683_row2_col1" class="data row2 col1" >imd2017ir</td>
#       <td id="T_f3683_row2_col2" class="data row2 col2" >Northern Ireland Multiple Deprivation Measure 2017, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_f3683_row2_col3" class="data row2 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row2_col4" class="data row2 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row3_col0" class="data row3 col0" >Deprivation</td>
#       <td id="T_f3683_row3_col1" class="data row3 col1" >imd2017ir_access</td>
#       <td id="T_f3683_row3_col2" class="data row3 col2" >Northern Ireland Multiple Deprivation Measure 2017, Access to Services, presented as quintiles. 1= strong access, 5= weak access.</td>
#       <td id="T_f3683_row3_col3" class="data row3 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row3_col4" class="data row3 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row4_col0" class="data row4 col0" >Deprivation</td>
#       <td id="T_f3683_row4_col1" class="data row4 col1" >imd2017ir_crime</td>
#       <td id="T_f3683_row4_col2" class="data row4 col2" >Northern Ireland Multiple Deprivation Measure 2017, presented as quintiles. 1= high crime rates, 5= low crime rates.</td>
#       <td id="T_f3683_row4_col3" class="data row4 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row4_col4" class="data row4 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row5_col0" class="data row5 col0" >Deprivation</td>
#       <td id="T_f3683_row5_col1" class="data row5 col1" >imd2017ir_education</td>
#       <td id="T_f3683_row5_col2" class="data row5 col2" >Northern Ireland Multiple Deprivation Measure 2017, Education, presented as quintiles. 1= lowest education, 5= highest education.</td>
#       <td id="T_f3683_row5_col3" class="data row5 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row5_col4" class="data row5 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row6_col0" class="data row6 col0" >Deprivation</td>
#       <td id="T_f3683_row6_col1" class="data row6 col1" >imd2017ir_employment</td>
#       <td id="T_f3683_row6_col2" class="data row6 col2" >Northern Ireland Multiple Deprivation Measure 2017, Employment, presented as quintiles. 1= highest unemployment, 5= lowest unemployment.</td>
#       <td id="T_f3683_row6_col3" class="data row6 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row6_col4" class="data row6 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row7_col0" class="data row7 col0" >Deprivation</td>
#       <td id="T_f3683_row7_col1" class="data row7 col1" >imd2017ir_environment</td>
#       <td id="T_f3683_row7_col2" class="data row7 col2" >Northern Ireland Multiple Deprivation Measure 2017, presented as quintiles. 1= low quality environment, 5= high quality environment.</td>
#       <td id="T_f3683_row7_col3" class="data row7 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row7_col4" class="data row7 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row8_col0" class="data row8 col0" >Deprivation</td>
#       <td id="T_f3683_row8_col1" class="data row8 col1" >imd2017ir_health</td>
#       <td id="T_f3683_row8_col2" class="data row8 col2" >label not available</td>
#       <td id="T_f3683_row8_col3" class="data row8 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row8_col4" class="data row8 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row9_col0" class="data row9 col0" >Deprivation</td>
#       <td id="T_f3683_row9_col1" class="data row9 col1" >imd2017ir_income</td>
#       <td id="T_f3683_row9_col2" class="data row9 col2" >Northern Ireland Multiple Deprivation Measure 2017, Income, presented as quintiles. 1= lowest income, 5= highest income.</td>
#       <td id="T_f3683_row9_col3" class="data row9 col3" >Northern Ireland Statistics and Research Agency</td>
#       <td id="T_f3683_row9_col4" class="data row9 col4" >2017</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row10_col0" class="data row10 col0" >Deprivation</td>
#       <td id="T_f3683_row10_col1" class="data row10 col1" >imd2019har</td>
#       <td id="T_f3683_row10_col2" class="data row10 col2" >Consumer Data Research Centre's Harmonised Index of Multiple Deprivation 2019, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_f3683_row10_col3" class="data row10 col3" >Geographic Data Service, Smart Data Research UK</td>
#       <td id="T_f3683_row10_col4" class="data row10 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_f3683_row11_col0" class="data row11 col0" >Deprivation</td>
#       <td id="T_f3683_row11_col1" class="data row11 col1" >mpe_ire_2020</td>
#       <td id="T_f3683_row11_col2" class="data row11 col2" >Mid-year (30 June) estimates of the usual resident population for Super Output Areas (2011) in Nort

# %%
display(Markdown('### imd_scotland'))
# Out:
# ### imd_scotland

# %%
DS("imd_scotland").variable_table()
# Out:
# <style type="text/css">
# #T_75ca1_row0_col0, #T_75ca1_row0_col1, #T_75ca1_row0_col2, #T_75ca1_row0_col3, #T_75ca1_row0_col4, #T_75ca1_row1_col0, #T_75ca1_row1_col1, #T_75ca1_row1_col2, #T_75ca1_row1_col3, #T_75ca1_row1_col4, #T_75ca1_row2_col0, #T_75ca1_row2_col1, #T_75ca1_row2_col2, #T_75ca1_row2_col3, #T_75ca1_row2_col4, #T_75ca1_row3_col0, #T_75ca1_row3_col1, #T_75ca1_row3_col2, #T_75ca1_row3_col3, #T_75ca1_row3_col4, #T_75ca1_row4_col0, #T_75ca1_row4_col1, #T_75ca1_row4_col2, #T_75ca1_row4_col3, #T_75ca1_row4_col4, #T_75ca1_row5_col0, #T_75ca1_row5_col1, #T_75ca1_row5_col2, #T_75ca1_row5_col3, #T_75ca1_row5_col4, #T_75ca1_row6_col0, #T_75ca1_row6_col1, #T_75ca1_row6_col2, #T_75ca1_row6_col3, #T_75ca1_row6_col4, #T_75ca1_row7_col0, #T_75ca1_row7_col1, #T_75ca1_row7_col2, #T_75ca1_row7_col3, #T_75ca1_row7_col4, #T_75ca1_row8_col0, #T_75ca1_row8_col1, #T_75ca1_row8_col2, #T_75ca1_row8_col3, #T_75ca1_row8_col4, #T_75ca1_row9_col0, #T_75ca1_row9_col1, #T_75ca1_row9_col2, #T_75ca1_row9_col3, #T_75ca1_row9_col4, #T_75ca1_row10_col0, #T_75ca1_row10_col1, #T_75ca1_row10_col2, #T_75ca1_row10_col3, #T_75ca1_row10_col4, #T_75ca1_row11_col0, #T_75ca1_row11_col1, #T_75ca1_row11_col2, #T_75ca1_row11_col3, #T_75ca1_row11_col4, #T_75ca1_row12_col0, #T_75ca1_row12_col1, #T_75ca1_row12_col2, #T_75ca1_row12_col3, #T_75ca1_row12_col4, #T_75ca1_row13_col0, #T_75ca1_row13_col1, #T_75ca1_row13_col2, #T_75ca1_row13_col3, #T_75ca1_row13_col4, #T_75ca1_row14_col0, #T_75ca1_row14_col1, #T_75ca1_row14_col2, #T_75ca1_row14_col3, #T_75ca1_row14_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_75ca1" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_75ca1_level0_col0" class="col_heading level0 col0" >Variable Group</th>
#       <th id="T_75ca1_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_75ca1_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_75ca1_level0_col3" class="col_heading level0 col3" >Source</th>
#       <th id="T_75ca1_level0_col4" class="col_heading level0 col4" >Date range of data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_75ca1_row0_col0" class="data row0 col0" >UK LLC</td>
#       <td id="T_75ca1_row0_col1" class="data row0 col1" >avail_from_dt</td>
#       <td id="T_75ca1_row0_col2" class="data row0 col2" >label not available</td>
#       <td id="T_75ca1_row0_col3" class="data row0 col3" >UK Longitudinal Linkage Collaboration</td>
#       <td id="T_75ca1_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row1_col0" class="data row1 col0" >Geography</td>
#       <td id="T_75ca1_row1_col1" class="data row1 col1" >country</td>
#       <td id="T_75ca1_row1_col2" class="data row1 col2" >Country within the United Kingdom</td>
#       <td id="T_75ca1_row1_col3" class="data row1 col3" >Office for National Statistics</td>
#       <td id="T_75ca1_row1_col4" class="data row1 col4" >2011</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row2_col0" class="data row2 col0" >Geography</td>
#       <td id="T_75ca1_row2_col1" class="data row2 col1" >dz11cd_e</td>
#       <td id="T_75ca1_row2_col2" class="data row2 col2" >Data Zones (2011)</td>
#       <td id="T_75ca1_row2_col3" class="data row2 col3" >gov.uk</td>
#       <td id="T_75ca1_row2_col4" class="data row2 col4" >2011</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row3_col0" class="data row3 col0" >Deprivation</td>
#       <td id="T_75ca1_row3_col1" class="data row3 col1" >imd2019har</td>
#       <td id="T_75ca1_row3_col2" class="data row3 col2" >Consumer Data Research Centre's Harmonised Index of Multiple Deprivation 2019, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_75ca1_row3_col3" class="data row3 col3" >Geographic Data Service, Smart Data Research UK</td>
#       <td id="T_75ca1_row3_col4" class="data row3 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row4_col0" class="data row4 col0" >Deprivation</td>
#       <td id="T_75ca1_row4_col1" class="data row4 col1" >imd2020scot</td>
#       <td id="T_75ca1_row4_col2" class="data row4 col2" >Scottish Index of Multiple Deprivation 2019, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_75ca1_row4_col3" class="data row4 col3" >gov.scot</td>
#       <td id="T_75ca1_row4_col4" class="data row4 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row5_col0" class="data row5 col0" >Deprivation</td>
#       <td id="T_75ca1_row5_col1" class="data row5 col1" >imd2020scot_access</td>
#       <td id="T_75ca1_row5_col2" class="data row5 col2" >Scottish Index of Multiple Deprivation 2019, Access to Services, presented as quintiles. 1= strong access, 5= weak access.</td>
#       <td id="T_75ca1_row5_col3" class="data row5 col3" >gov.scot</td>
#       <td id="T_75ca1_row5_col4" class="data row5 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row6_col0" class="data row6 col0" >Deprivation</td>
#       <td id="T_75ca1_row6_col1" class="data row6 col1" >imd2020scot_crime</td>
#       <td id="T_75ca1_row6_col2" class="data row6 col2" >Scottish Index of Multiple Deprivation 2019, Crime, presented as quintiles. 1= high crime rates, 5= low crime rates.</td>
#       <td id="T_75ca1_row6_col3" class="data row6 col3" >gov.scot</td>
#       <td id="T_75ca1_row6_col4" class="data row6 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row7_col0" class="data row7 col0" >Deprivation</td>
#       <td id="T_75ca1_row7_col1" class="data row7 col1" >imd2020scot_education</td>
#       <td id="T_75ca1_row7_col2" class="data row7 col2" >Scottish Index of Multiple Deprivation 2019, Education, presented as quintiles. 1= lowest education, 5= highest education.</td>
#       <td id="T_75ca1_row7_col3" class="data row7 col3" >gov.scot</td>
#       <td id="T_75ca1_row7_col4" class="data row7 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row8_col0" class="data row8 col0" >Deprivation</td>
#       <td id="T_75ca1_row8_col1" class="data row8 col1" >imd2020scot_employment</td>
#       <td id="T_75ca1_row8_col2" class="data row8 col2" >Scottish Index of Multiple Deprivation 2019, Employment, presented as quintiles. 1= highest unemployment, 5= lowest unemployment.</td>
#       <td id="T_75ca1_row8_col3" class="data row8 col3" >gov.scot</td>
#       <td id="T_75ca1_row8_col4" class="data row8 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row9_col0" class="data row9 col0" >Deprivation</td>
#       <td id="T_75ca1_row9_col1" class="data row9 col1" >imd2020scot_health</td>
#       <td id="T_75ca1_row9_col2" class="data row9 col2" >Scottish Index of Multiple Deprivation 2019, Health, presented as quintiles. 1= high health deprivation, 5= low health deprivation.</td>
#       <td id="T_75ca1_row9_col3" class="data row9 col3" >gov.scot</td>
#       <td id="T_75ca1_row9_col4" class="data row9 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row10_col0" class="data row10 col0" >Deprivation</td>
#       <td id="T_75ca1_row10_col1" class="data row10 col1" >imd2020scot_housing</td>
#       <td id="T_75ca1_row10_col2" class="data row10 col2" >Scottish Index of Multiple Deprivation 2019, Housing, presented as quintiles. 1= low quality housing, 5= high quality.</td>
#       <td id="T_75ca1_row10_col3" class="data row10 col3" >gov.scot</td>
#       <td id="T_75ca1_row10_col4" class="data row10 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row11_col0" class="data row11 col0" >Deprivation</td>
#       <td id="T_75ca1_row11_col1" class="data row11 col1" >imd2020scot_income</td>
#       <td id="T_75ca1_row11_col2" class="data row11 col2" >Scottish Index of Multiple Deprivation 2019, Income, presented as quintiles. 1= lowest income, 5= highest income.</td>
#       <td id="T_75ca1_row11_col3" class="data row11 col3" >gov.scot</td>
#       <td id="T_75ca1_row11_col4" class="data row11 col4" >2020</td>
#     </tr>
#     <tr>
#       <td id="T_75ca1_row12_col0" class="data row12 col0" >Deprivation</td>
#       <td id="T_75ca1_row12_col1" class="data row12 col1" >mpe_scot_2021</td>

# %%
display(Markdown('### imd_wales'))
# Out:
# ### imd_wales

# %%
DS("imd_wales").variable_table()
# Out:
# <style type="text/css">
# #T_a1ce4_row0_col0, #T_a1ce4_row0_col1, #T_a1ce4_row0_col2, #T_a1ce4_row0_col3, #T_a1ce4_row0_col4, #T_a1ce4_row1_col0, #T_a1ce4_row1_col1, #T_a1ce4_row1_col2, #T_a1ce4_row1_col3, #T_a1ce4_row1_col4, #T_a1ce4_row2_col0, #T_a1ce4_row2_col1, #T_a1ce4_row2_col2, #T_a1ce4_row2_col3, #T_a1ce4_row2_col4, #T_a1ce4_row3_col0, #T_a1ce4_row3_col1, #T_a1ce4_row3_col2, #T_a1ce4_row3_col3, #T_a1ce4_row3_col4, #T_a1ce4_row4_col0, #T_a1ce4_row4_col1, #T_a1ce4_row4_col2, #T_a1ce4_row4_col3, #T_a1ce4_row4_col4, #T_a1ce4_row5_col0, #T_a1ce4_row5_col1, #T_a1ce4_row5_col2, #T_a1ce4_row5_col3, #T_a1ce4_row5_col4, #T_a1ce4_row6_col0, #T_a1ce4_row6_col1, #T_a1ce4_row6_col2, #T_a1ce4_row6_col3, #T_a1ce4_row6_col4, #T_a1ce4_row7_col0, #T_a1ce4_row7_col1, #T_a1ce4_row7_col2, #T_a1ce4_row7_col3, #T_a1ce4_row7_col4, #T_a1ce4_row8_col0, #T_a1ce4_row8_col1, #T_a1ce4_row8_col2, #T_a1ce4_row8_col3, #T_a1ce4_row8_col4, #T_a1ce4_row9_col0, #T_a1ce4_row9_col1, #T_a1ce4_row9_col2, #T_a1ce4_row9_col3, #T_a1ce4_row9_col4, #T_a1ce4_row10_col0, #T_a1ce4_row10_col1, #T_a1ce4_row10_col2, #T_a1ce4_row10_col3, #T_a1ce4_row10_col4, #T_a1ce4_row11_col0, #T_a1ce4_row11_col1, #T_a1ce4_row11_col2, #T_a1ce4_row11_col3, #T_a1ce4_row11_col4, #T_a1ce4_row12_col0, #T_a1ce4_row12_col1, #T_a1ce4_row12_col2, #T_a1ce4_row12_col3, #T_a1ce4_row12_col4, #T_a1ce4_row13_col0, #T_a1ce4_row13_col1, #T_a1ce4_row13_col2, #T_a1ce4_row13_col3, #T_a1ce4_row13_col4, #T_a1ce4_row14_col0, #T_a1ce4_row14_col1, #T_a1ce4_row14_col2, #T_a1ce4_row14_col3, #T_a1ce4_row14_col4, #T_a1ce4_row15_col0, #T_a1ce4_row15_col1, #T_a1ce4_row15_col2, #T_a1ce4_row15_col3, #T_a1ce4_row15_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_a1ce4" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_a1ce4_level0_col0" class="col_heading level0 col0" >Variable Group</th>
#       <th id="T_a1ce4_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_a1ce4_level0_col2" class="col_heading level0 col2" >Description</th>
#       <th id="T_a1ce4_level0_col3" class="col_heading level0 col3" >Source</th>
#       <th id="T_a1ce4_level0_col4" class="col_heading level0 col4" >Date range of data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a1ce4_row0_col0" class="data row0 col0" >UK LLC</td>
#       <td id="T_a1ce4_row0_col1" class="data row0 col1" >avail_from_dt</td>
#       <td id="T_a1ce4_row0_col2" class="data row0 col2" >label not available</td>
#       <td id="T_a1ce4_row0_col3" class="data row0 col3" >UK Longitudinal Linkage Collaboration</td>
#       <td id="T_a1ce4_row0_col4" class="data row0 col4" >None</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row1_col0" class="data row1 col0" >Geography</td>
#       <td id="T_a1ce4_row1_col1" class="data row1 col1" >country</td>
#       <td id="T_a1ce4_row1_col2" class="data row1 col2" >Country within the United Kingdom</td>
#       <td id="T_a1ce4_row1_col3" class="data row1 col3" >Office for National Statistics</td>
#       <td id="T_a1ce4_row1_col4" class="data row1 col4" >2011</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row2_col0" class="data row2 col0" >Deprivation</td>
#       <td id="T_a1ce4_row2_col1" class="data row2 col1" >imd2019har</td>
#       <td id="T_a1ce4_row2_col2" class="data row2 col2" >Consumer Data Research Centre's Harmonised Index of Multiple Deprivation 2019, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_a1ce4_row2_col3" class="data row2 col3" >Geographic Data Service, Smart Data Research UK</td>
#       <td id="T_a1ce4_row2_col4" class="data row2 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row3_col0" class="data row3 col0" >Deprivation</td>
#       <td id="T_a1ce4_row3_col1" class="data row3 col1" >imd2019wal</td>
#       <td id="T_a1ce4_row3_col2" class="data row3 col2" >Welsh Index of Multiple Deprivation 2019, presented as quintiles. 1= most deprived, 5= least deprived.</td>
#       <td id="T_a1ce4_row3_col3" class="data row3 col3" >gov.wales</td>
#       <td id="T_a1ce4_row3_col4" class="data row3 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row4_col0" class="data row4 col0" >Deprivation</td>
#       <td id="T_a1ce4_row4_col1" class="data row4 col1" >imd2019wal_education</td>
#       <td id="T_a1ce4_row4_col2" class="data row4 col2" >Welsh Index of Multiple Deprivation 2019, Education, presented as quintiles. 1= lowest education, 5= highest education.</td>
#       <td id="T_a1ce4_row4_col3" class="data row4 col3" >gov.wales</td>
#       <td id="T_a1ce4_row4_col4" class="data row4 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row5_col0" class="data row5 col0" >Deprivation</td>
#       <td id="T_a1ce4_row5_col1" class="data row5 col1" >imd2019wal_employment</td>
#       <td id="T_a1ce4_row5_col2" class="data row5 col2" >Welsh Index of Multiple Deprivation 2019, Employment, presented as quintiles. 1= highest unemployment, 5= lowest unemployment.</td>
#       <td id="T_a1ce4_row5_col3" class="data row5 col3" >gov.wales</td>
#       <td id="T_a1ce4_row5_col4" class="data row5 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row6_col0" class="data row6 col0" >Deprivation</td>
#       <td id="T_a1ce4_row6_col1" class="data row6 col1" >imd2019wal_environment</td>
#       <td id="T_a1ce4_row6_col2" class="data row6 col2" >Welsh Index of Multiple Deprivation 2019, Physical Environment, presented as quintiles. 1= low quality environment, 5= high quality environment.</td>
#       <td id="T_a1ce4_row6_col3" class="data row6 col3" >gov.wales</td>
#       <td id="T_a1ce4_row6_col4" class="data row6 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row7_col0" class="data row7 col0" >Deprivation</td>
#       <td id="T_a1ce4_row7_col1" class="data row7 col1" >imd2019wal_health</td>
#       <td id="T_a1ce4_row7_col2" class="data row7 col2" >Welsh Index of Multiple Deprivation 2019, Health, presented as quintiles. 1= high health deprivation, 5= low health deprivation.</td>
#       <td id="T_a1ce4_row7_col3" class="data row7 col3" >gov.wales</td>
#       <td id="T_a1ce4_row7_col4" class="data row7 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row8_col0" class="data row8 col0" >Deprivation</td>
#       <td id="T_a1ce4_row8_col1" class="data row8 col1" >imd2019wal_housing</td>
#       <td id="T_a1ce4_row8_col2" class="data row8 col2" >Welsh Index of Multiple Deprivation 2019, Housing, presented as quintiles. 1= low quality housing, 5= high quality.</td>
#       <td id="T_a1ce4_row8_col3" class="data row8 col3" >gov.wales</td>
#       <td id="T_a1ce4_row8_col4" class="data row8 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row9_col0" class="data row9 col0" >Deprivation</td>
#       <td id="T_a1ce4_row9_col1" class="data row9 col1" >imd2019wal_income</td>
#       <td id="T_a1ce4_row9_col2" class="data row9 col2" >Welsh Index of Multiple Deprivation 2019, Income, presented as quintiles. 1= lowest income, 5= highest income.</td>
#       <td id="T_a1ce4_row9_col3" class="data row9 col3" >gov.wales</td>
#       <td id="T_a1ce4_row9_col4" class="data row9 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row10_col0" class="data row10 col0" >Deprivation</td>
#       <td id="T_a1ce4_row10_col1" class="data row10 col1" >imd2019wal_safety</td>
#       <td id="T_a1ce4_row10_col2" class="data row10 col2" >Welsh Index of Multiple Deprivation 2019, Community Safety, presented as quintiles. 1= low community safety, 5= high community safety.</td>
#       <td id="T_a1ce4_row10_col3" class="data row10 col3" >gov.wales</td>
#       <td id="T_a1ce4_row10_col4" class="data row10 col4" >2019</td>
#     </tr>
#     <tr>
#       <td id="T_a1ce4_row11_col0" class="data row11 col0" >Deprivation</td>
#       <td id="T_a1ce4_row11_col1" class="data row11 col1" >imd2019wal_services</td>
#       <td id="T_a1ce4_row11_col2" class="data row11 col2" >Welsh Index of Multiple Deprivation 2019, Access to Services, presented as quintiles. 1= Strong access, 5= Weak access.</td>
#       <td id="T_a1ce4_row11_col3" class="data row11 col3" >gov.wales</t

# %% [markdown]
# ## 3. Metrics

# %%
display(Markdown('TBC'))
# Out:
# TBC

# %% [markdown]
# ## 4. Version History

# %%
display(Markdown('TBC'))
# Out:
# TBC

# %% [markdown]
# ## 5. Documentation

# %%
DS("imd_england").documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 6. Useful Syntax

# %%
DS("imd_england").useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to the [UK LLC GitHub](https://github.com/UKLLC) repository where you can find the full scripts.
