# %% [markdown]
# # ELSA Wave 9 Data (EUL) Income And Assets 1 (ELSA)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("ELSA", "wave_9_elsa_data_eul_ia1")
last_modified()
# Out:
# >Last modified: 06 May 2026

# %% [markdown]
# ## 1. Summary

# %%
ds.summary()
# Out:
# Participants from the ELSA sample were invited to take part in a face-to-face interview in 2018-2019. Respondents took part in a interview on a nmber of topics but this block contains only variables from the ia (income and assests) module

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_cd51c_row0_col0, #T_cd51c_row0_col1, #T_cd51c_row1_col0, #T_cd51c_row1_col1, #T_cd51c_row2_col0, #T_cd51c_row2_col1, #T_cd51c_row3_col0, #T_cd51c_row3_col1, #T_cd51c_row4_col0, #T_cd51c_row4_col1, #T_cd51c_row5_col0, #T_cd51c_row5_col1, #T_cd51c_row6_col0, #T_cd51c_row6_col1, #T_cd51c_row7_col0, #T_cd51c_row7_col1, #T_cd51c_row8_col0, #T_cd51c_row8_col1, #T_cd51c_row9_col0, #T_cd51c_row9_col1, #T_cd51c_row10_col0, #T_cd51c_row10_col1, #T_cd51c_row11_col0, #T_cd51c_row11_col1, #T_cd51c_row12_col0, #T_cd51c_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_cd51c" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_cd51c_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_cd51c_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cd51c_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_cd51c_row0_col1" class="data row0 col1" >ELSA_wave_9_elsa_data_eul_ia1</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_cd51c_row1_col1" class="data row1 col1" >University College London, National Centre for Social Research, The Institute for Fiscal Studies, The University of East Anglia, and The University of Manchester. (2021). <i>English Longitudinal Study of Ageing (ELSA): ELSA Wave 9 Data (EUL) Income And Assets 1.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00097-01" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00097-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_cd51c_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00097-01" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00097-01" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00097-01" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row3_col0" class="data row3 col0" >Series</td>
#       <td id="T_cd51c_row3_col1" class="data row3 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/lps_data/lps_profiles/elsa">English Longitudinal Study of Ageing (ELSA)</a></td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row4_col0" class="data row4 col0" >Owner</td>
#       <td id="T_cd51c_row4_col1" class="data row4 col1" >UCL</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_cd51c_row5_col1" class="data row5 col1" >06/2018 - 07/2019</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row6_col0" class="data row6 col0" >Keywords</td>
#       <td id="T_cd51c_row6_col1" class="data row6 col1" >income,wealth,finances,state benefits,private pension income,assets,debt.</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row7_col0" class="data row7 col0" >Participants Invited</td>
#       <td id="T_cd51c_row7_col1" class="data row7 col1" >8736</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row8_col0" class="data row8 col0" >Participant Count</td>
#       <td id="T_cd51c_row8_col1" class="data row8 col1" >8736</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row9_col0" class="data row9 col0" >Number of variables</td>
#       <td id="T_cd51c_row9_col1" class="data row9 col1" >647</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row10_col0" class="data row10 col0" >Number of observations</td>
#       <td id="T_cd51c_row10_col1" class="data row10 col1" >8736</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row11_col0" class="data row11 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_cd51c_row11_col1" class="data row11 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_cd51c_row12_col0" class="data row12 col0" >Build a Data Request</td>
#       <td id="T_cd51c_row12_col1" class="data row12 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_27d80_row0_col0, #T_27d80_row0_col1, #T_27d80_row1_col0, #T_27d80_row1_col1, #T_27d80_row2_col0, #T_27d80_row2_col1, #T_27d80_row3_col0, #T_27d80_row3_col1, #T_27d80_row4_col0, #T_27d80_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_27d80" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_27d80_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_27d80_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_27d80_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_27d80_row0_col1" class="data row0 col1" >01 Nov 2021</td>
#     </tr>
#     <tr>
#       <td id="T_27d80_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_27d80_row1_col1" class="data row1 col1" >647</td>
#     </tr>
#     <tr>
#       <td id="T_27d80_row2_col0" class="data row2 col0" >Number of Observations</td>
#       <td id="T_27d80_row2_col1" class="data row2 col1" >8736</td>
#     </tr>
#     <tr>
#       <td id="T_27d80_row3_col0" class="data row3 col0" >DOI</td>
#       <td id="T_27d80_row3_col1" class="data row3 col1" > <a href="https://doi.org/10.71760/ukllc-dataset-00097-01" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00097-01</a></td>
#     </tr>
#     <tr>
#       <td id="T_27d80_row4_col0" class="data row4 col0" >Change Log</td>
#       <td id="T_27d80_row4_col1" class="data row4 col1" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00097-01/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00097-01/activities</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Documentation

# %%
ds.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
