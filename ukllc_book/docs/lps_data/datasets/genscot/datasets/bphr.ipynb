# %% [markdown]
# # Blood Pressure and Heart Rate (BPHR) (GENSCOT)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("GENSCOT", "BPHR")
last_modified()
# Out:
# >Last modified: 06 May 2026

# %% [markdown]
# ## 1. Summary

# %%
ds.summary()
# Out:
# Socio-demographic and clinical data were obtained from around 24,000 volunteers across Scotland. Volunteers were aged between 18-98 and were assessed via clinic visits and questionnaires.

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_a3ea0_row0_col0, #T_a3ea0_row0_col1, #T_a3ea0_row1_col0, #T_a3ea0_row1_col1, #T_a3ea0_row2_col0, #T_a3ea0_row2_col1, #T_a3ea0_row3_col0, #T_a3ea0_row3_col1, #T_a3ea0_row4_col0, #T_a3ea0_row4_col1, #T_a3ea0_row5_col0, #T_a3ea0_row5_col1, #T_a3ea0_row6_col0, #T_a3ea0_row6_col1, #T_a3ea0_row7_col0, #T_a3ea0_row7_col1, #T_a3ea0_row8_col0, #T_a3ea0_row8_col1, #T_a3ea0_row9_col0, #T_a3ea0_row9_col1, #T_a3ea0_row10_col0, #T_a3ea0_row10_col1, #T_a3ea0_row11_col0, #T_a3ea0_row11_col1, #T_a3ea0_row12_col0, #T_a3ea0_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_a3ea0" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_a3ea0_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_a3ea0_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a3ea0_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_a3ea0_row0_col1" class="data row0 col1" >GENSCOT_BPHR</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_a3ea0_row1_col1" class="data row1 col1" >Centre for Medical Informatics, Usher Institute, University of Edinburgh. (2022). <i>Generation Scotland (GENSCOT): Blood Pressure and Heart Rate (BPHR).</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00124-02" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00124-02</a></td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_a3ea0_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00124-02" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00124-02" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00124-02" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row3_col0" class="data row3 col0" >Series</td>
#       <td id="T_a3ea0_row3_col1" class="data row3 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/lps_data/lps_profiles/genscot">Generation Scotland (GENSCOT)</a></td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row4_col0" class="data row4 col0" >Owner</td>
#       <td id="T_a3ea0_row4_col1" class="data row4 col1" >University of Edinburgh</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_a3ea0_row5_col1" class="data row5 col1" >01/2006 - 05/2011</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row6_col0" class="data row6 col0" >Keywords</td>
#       <td id="T_a3ea0_row6_col1" class="data row6 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row7_col0" class="data row7 col0" >Participants Invited</td>
#       <td id="T_a3ea0_row7_col1" class="data row7 col1" >20770</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row8_col0" class="data row8 col0" >Participant Count</td>
#       <td id="T_a3ea0_row8_col1" class="data row8 col1" >20220</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row9_col0" class="data row9 col0" >Number of variables</td>
#       <td id="T_a3ea0_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row10_col0" class="data row10 col0" >Number of observations</td>
#       <td id="T_a3ea0_row10_col1" class="data row10 col1" >20770</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row11_col0" class="data row11 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_a3ea0_row11_col1" class="data row11 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_a3ea0_row12_col0" class="data row12 col0" >Build a Data Request</td>
#       <td id="T_a3ea0_row12_col1" class="data row12 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_960e7_row0_col0, #T_960e7_row0_col1, #T_960e7_row0_col2, #T_960e7_row1_col0, #T_960e7_row1_col1, #T_960e7_row1_col2, #T_960e7_row2_col0, #T_960e7_row2_col1, #T_960e7_row2_col2, #T_960e7_row3_col0, #T_960e7_row3_col1, #T_960e7_row3_col2, #T_960e7_row4_col0, #T_960e7_row4_col1, #T_960e7_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_960e7" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_960e7_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_960e7_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_960e7_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_960e7_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_960e7_row0_col1" class="data row0 col1" >01 Nov 2021</td>
#       <td id="T_960e7_row0_col2" class="data row0 col2" >02 Mar 2022</td>
#     </tr>
#     <tr>
#       <td id="T_960e7_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_960e7_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_960e7_row1_col2" class="data row1 col2" >13</td>
#     </tr>
#     <tr>
#       <td id="T_960e7_row2_col0" class="data row2 col0" >Number of Observations</td>
#       <td id="T_960e7_row2_col1" class="data row2 col1" >20770</td>
#       <td id="T_960e7_row2_col2" class="data row2 col2" >20770</td>
#     </tr>
#     <tr>
#       <td id="T_960e7_row3_col0" class="data row3 col0" >DOI</td>
#       <td id="T_960e7_row3_col1" class="data row3 col1" > <a href="https://doi.org/10.71760/ukllc-dataset-00124-01" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00124-01</a></td>
#       <td id="T_960e7_row3_col2" class="data row3 col2" > <a href="https://doi.org/10.71760/ukllc-dataset-00124-02" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00124-02</a></td>
#     </tr>
#     <tr>
#       <td id="T_960e7_row4_col0" class="data row4 col0" >Change Log</td>
#       <td id="T_960e7_row4_col1" class="data row4 col1" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00124-01/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00124-01/activities</a></td>
#       <td id="T_960e7_row4_col2" class="data row4 col2" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00124-02/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00124-02/activities</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Documentation

# %%
ds.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
