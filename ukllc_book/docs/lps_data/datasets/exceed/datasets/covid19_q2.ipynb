# %% [markdown]
# # COVID-19 Questionnaire 2 (EXCEED)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("EXCEED", "covid19_q2")
last_modified()
# Out:
# >Last modified: 06 May 2026

# %% [markdown]
# ## 1. Summary

# %%
ds.summary()
# Out:
# Only a subset of the original study collection items are provided (any question answers which may contain personal information have been removed along with those given by participants who withdrew).

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_492d5_row0_col0, #T_492d5_row0_col1, #T_492d5_row1_col0, #T_492d5_row1_col1, #T_492d5_row2_col0, #T_492d5_row2_col1, #T_492d5_row3_col0, #T_492d5_row3_col1, #T_492d5_row4_col0, #T_492d5_row4_col1, #T_492d5_row5_col0, #T_492d5_row5_col1, #T_492d5_row6_col0, #T_492d5_row6_col1, #T_492d5_row7_col0, #T_492d5_row7_col1, #T_492d5_row8_col0, #T_492d5_row8_col1, #T_492d5_row9_col0, #T_492d5_row9_col1, #T_492d5_row10_col0, #T_492d5_row10_col1, #T_492d5_row11_col0, #T_492d5_row11_col1, #T_492d5_row12_col0, #T_492d5_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_492d5" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_492d5_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_492d5_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_492d5_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
#       <td id="T_492d5_row0_col1" class="data row0 col1" >EXCEED_covid19_q2</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row1_col0" class="data row1 col0" >Citation (APA)</td>
#       <td id="T_492d5_row1_col1" class="data row1 col1" >University of Leicester Genetic Epidemiology Group. (2023). <i>Extended Cohort for E-health, Environment and DNA (EXCEED): COVID-19 Questionnaire 2.</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-dataset-00114-02" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-dataset-00114-02</a></td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row2_col0" class="data row2 col0" >Download Citation</td>
#       <td id="T_492d5_row2_col1" class="data row2 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-dataset-00114-02" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-dataset-00114-02" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-dataset-00114-02" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row3_col0" class="data row3 col0" >Series</td>
#       <td id="T_492d5_row3_col1" class="data row3 col1" > <a href="https://guidebook.ukllc.ac.uk/docs/lps_data/lps_profiles/exceed">Extended Cohort for E-health, Environment and DNA (EXCEED)</a></td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row4_col0" class="data row4 col0" >Owner</td>
#       <td id="T_492d5_row4_col1" class="data row4 col1" >University of Leicester</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row5_col0" class="data row5 col0" >Temporal Coverage</td>
#       <td id="T_492d5_row5_col1" class="data row5 col1" >07/2021 - 06/2022</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row6_col0" class="data row6 col0" >Keywords</td>
#       <td id="T_492d5_row6_col1" class="data row6 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row7_col0" class="data row7 col0" >Participants Invited</td>
#       <td id="T_492d5_row7_col1" class="data row7 col1" >11047</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row8_col0" class="data row8 col0" >Participant Count</td>
#       <td id="T_492d5_row8_col1" class="data row8 col1" >2782</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row9_col0" class="data row9 col0" >Number of variables</td>
#       <td id="T_492d5_row9_col1" class="data row9 col1" >327</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row10_col0" class="data row10 col0" >Number of observations</td>
#       <td id="T_492d5_row10_col1" class="data row10 col1" >2784</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row11_col0" class="data row11 col0" >Specific Restrictions to Data Use</td>
#       <td id="T_492d5_row11_col1" class="data row11 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_492d5_row12_col0" class="data row12 col0" >Build a Data Request</td>
#       <td id="T_492d5_row12_col1" class="data row12 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_04097_row0_col0, #T_04097_row0_col1, #T_04097_row0_col2, #T_04097_row1_col0, #T_04097_row1_col1, #T_04097_row1_col2, #T_04097_row2_col0, #T_04097_row2_col1, #T_04097_row2_col2, #T_04097_row3_col0, #T_04097_row3_col1, #T_04097_row3_col2, #T_04097_row4_col0, #T_04097_row4_col1, #T_04097_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_04097" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_04097_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_04097_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_04097_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_04097_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_04097_row0_col1" class="data row0 col1" >10 Aug 2022</td>
#       <td id="T_04097_row0_col2" class="data row0 col2" >24 Oct 2023</td>
#     </tr>
#     <tr>
#       <td id="T_04097_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_04097_row1_col1" class="data row1 col1" >654</td>
#       <td id="T_04097_row1_col2" class="data row1 col2" >327</td>
#     </tr>
#     <tr>
#       <td id="T_04097_row2_col0" class="data row2 col0" >Number of Observations</td>
#       <td id="T_04097_row2_col1" class="data row2 col1" >2782</td>
#       <td id="T_04097_row2_col2" class="data row2 col2" >2784</td>
#     </tr>
#     <tr>
#       <td id="T_04097_row3_col0" class="data row3 col0" >DOI</td>
#       <td id="T_04097_row3_col1" class="data row3 col1" > <a href="https://doi.org/10.71760/ukllc-dataset-00114-01" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00114-01</a></td>
#       <td id="T_04097_row3_col2" class="data row3 col2" > <a href="https://doi.org/10.71760/ukllc-dataset-00114-02" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00114-02</a></td>
#     </tr>
#     <tr>
#       <td id="T_04097_row4_col0" class="data row4 col0" >Change Log</td>
#       <td id="T_04097_row4_col1" class="data row4 col1" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00114-01/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00114-01/activities</a></td>
#       <td id="T_04097_row4_col2" class="data row4 col2" > <a href="https://api.datacite.org/dois/10.71760/ukllc-dataset-00114-02/activities" rel="noopener noreferrer" target="_blank">10.71760/ukllc-dataset-00114-02/activities</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. Documentation

# %%
ds.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
