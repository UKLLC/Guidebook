# %% [markdown]
# # Age 42 Housing Data (BCS70)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("BCS70", "bcs9_housing")
last_modified()
# Out:
# >Last modified: 27 May 2026

# %% [markdown]
# ## 1. Summary

# %%
ds.summary()
# Out:
# Housing histories covering each separate living arrangement since last sweep / 2000 (whichever is more recent). Includes tenure, move in and out dates

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_7c722_row0_col0, #T_7c722_row0_col1, #T_7c722_row1_col0, #T_7c722_row1_col1, #T_7c722_row2_col0, #T_7c722_row2_col1, #T_7c722_row3_col0, #T_7c722_row3_col1, #T_7c722_row4_col0, #T_7c722_row4_col1, #T_7c722_row5_col0, #T_7c722_row5_col1, #T_7c722_row6_col0, #T_7c722_row6_col1, #T_7c722_row7_col0, #T_7c722_row7_col1, #T_7c722_row8_col0, #T_7c722_row8_col1, #T_7c722_row9_col0, #T_7c722_row9_col1, #T_7c722_row10_col0, #T_7c722_row10_col1, #T_7c722_row11_col0, #T_7c722_row11_col1, #T_7c722_row12_col0, #T_7c722_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_7c722" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_7c722_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_7c722_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7c722_row0_col0" class="data row0 col0" >Name of Dataset in TRE</td>
# ...

# %% [markdown]
# ## 2. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_ba11d_row0_col0, #T_ba11d_row0_col1, #T_ba11d_row1_col0, #T_ba11d_row1_col1, #T_ba11d_row2_col0, #T_ba11d_row2_col1, #T_ba11d_row3_col0, #T_ba11d_row3_col1, #T_ba11d_row4_col0, #T_ba11d_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_ba11d" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_ba11d_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_ba11d_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ba11d_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_ba11d_row0_col1" class="data row0 col1" >01 Nov 2021</td>
#     </tr>
#     <tr>
#       <td id="T_ba11d_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_ba11d_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_ba11d_row2_col0" class="data row2 col0" >Number of Observations</td>
# ...

# %% [markdown]
# ## 3. Documentation

# %%
ds.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
