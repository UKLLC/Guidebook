# %% [markdown]
# # European Prospective Investigation into Cancer and Nutrition - Norfolk (EPIC-N) Datasets

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ss = SS("EPICN")
last_modified()
# Out:
# >Last modified: 06 May 2026

# %% [markdown]
# ## 1. Datasets

# %%
ss.table_caption_ds()
# Out:
# **Table 1:** Datasets and metrics in the UK LLC belonging to EPICN.

# %%
ss.datasets()
# Out:
# <style type="text/css">
# #T_f8b7d_row0_col0, #T_f8b7d_row0_col1, #T_f8b7d_row0_col2, #T_f8b7d_row0_col3, #T_f8b7d_row0_col4, #T_f8b7d_row1_col0, #T_f8b7d_row1_col1, #T_f8b7d_row1_col2, #T_f8b7d_row1_col3, #T_f8b7d_row1_col4, #T_f8b7d_row2_col0, #T_f8b7d_row2_col1, #T_f8b7d_row2_col2, #T_f8b7d_row2_col3, #T_f8b7d_row2_col4, #T_f8b7d_row3_col0, #T_f8b7d_row3_col1, #T_f8b7d_row3_col2, #T_f8b7d_row3_col3, #T_f8b7d_row3_col4, #T_f8b7d_row4_col0, #T_f8b7d_row4_col1, #T_f8b7d_row4_col2, #T_f8b7d_row4_col3, #T_f8b7d_row4_col4, #T_f8b7d_row5_col0, #T_f8b7d_row5_col1, #T_f8b7d_row5_col2, #T_f8b7d_row5_col3, #T_f8b7d_row5_col4, #T_f8b7d_row6_col0, #T_f8b7d_row6_col1, #T_f8b7d_row6_col2, #T_f8b7d_row6_col3, #T_f8b7d_row6_col4, #T_f8b7d_row7_col0, #T_f8b7d_row7_col1, #T_f8b7d_row7_col2, #T_f8b7d_row7_col3, #T_f8b7d_row7_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_f8b7d" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_f8b7d_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_f8b7d_level0_col1" class="col_heading level0 col1" >Dataset Name</th>
#       <th id="T_f8b7d_level0_col2" class="col_heading level0 col2" ># Participants</th>
#       <th id="T_f8b7d_level0_col3" class="col_heading level0 col3" ># Observations</th>
#       <th id="T_f8b7d_level0_col4" class="col_heading level0 col4" ># Variables</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f8b7d_row0_col0" class="data row0 col0" > <a href="FU1.html">FU1</a></td>
#       <td id="T_f8b7d_row0_col1" class="data row0 col1" >Follow up 1</td>
#       <td id="T_f8b7d_row0_col2" class="data row0 col2" >8199</td>
#       <td id="T_f8b7d_row0_col3" class="data row0 col3" >9421</td>
#       <td id="T_f8b7d_row0_col4" class="data row0 col4" >8</td>
#     </tr>
#     <tr>
#       <td id="T_f8b7d_row1_col0" class="data row1 col0" > <a href="FU5.html">FU5</a></td>
#       <td id="T_f8b7d_row1_col1" class="data row1 col1" >Follow up 5</td>
#       <td id="T_f8b7d_row1_col2" class="data row1 col2" >4966</td>
#       <td id="T_f8b7d_row1_col3" class="data row1 col3" >5304</td>
#       <td id="T_f8b7d_row1_col4" class="data row1 col4" >8</td>
#     </tr>
#     <tr>
#       <td id="T_f8b7d_row2_col0" class="data row2 col0" > <a href="FU7.html">FU7</a></td>
#       <td id="T_f8b7d_row2_col1" class="data row2 col1" >Follow up 7</td>
#       <td id="T_f8b7d_row2_col2" class="data row2 col2" >2390</td>
#       <td id="T_f8b7d_row2_col3" class="data row2 col3" >2539</td>
#       <td id="T_f8b7d_row2_col4" class="data row2 col4" >8</td>
#     </tr>
#     <tr>
#       <td id="T_f8b7d_row3_col0" class="data row3 col0" > <a href="HLEQ1.html">HLEQ1</a></td>
#       <td id="T_f8b7d_row3_col1" class="data row3 col1" >HLEQ1</td>
#       <td id="T_f8b7d_row3_col2" class="data row3 col2" >11424</td>
#       <td id="T_f8b7d_row3_col3" class="data row3 col3" >12897</td>
#       <td id="T_f8b7d_row3_col4" class="data row3 col4" >10</td>
#     </tr>
#     <tr>
#       <td id="T_f8b7d_row4_col0" class="data row4 col0" > <a href="HLQ.html">HLQ</a></td>
#       <td id="T_f8b7d_row4_col1" class="data row4 col1" >Baseline HLQ</td>
#       <td id="T_f8b7d_row4_col2" class="data row4 col2" >15748</td>
#       <td id="T_f8b7d_row4_col3" class="data row4 col3" >18248</td>
#       <td id="T_f8b7d_row4_col4" class="data row4 col4" >12</td>
#     </tr>
#     <tr>
#       <td id="T_f8b7d_row5_col0" class="data row5 col0" > <a href="FU2.html">FU2</a></td>
#       <td id="T_f8b7d_row5_col1" class="data row5 col1" >Follow up 2</td>
#       <td id="T_f8b7d_row5_col2" class="data row5 col2" >10853</td>
#       <td id="T_f8b7d_row5_col3" class="data row5 col3" >12074</td>
#       <td id="T_f8b7d_row5_col4" class="data row5 col4" >8</td>
#     </tr>
#     <tr>
#       <td id="T_f8b7d_row6_col0" class="data row6 col0" > <a href="FU3.html">FU3</a></td>
#       <td id="T_f8b7d_row6_col1" class="data row6 col1" >Follow up 3</td>
#       <td id="T_f8b7d_row6_col2" class="data row6 col2" >10913</td>
#       <td id="T_f8b7d_row6_col3" class="data row6 col3" >12186</td>
#       <td id="T_f8b7d_row6_col4" class="data row6 col4" >9</td>
#     </tr>
#     <tr>
#       <td id="T_f8b7d_row7_col0" class="data row7 col0" > <a href="FU4.html">FU4</a></td>
#       <td id="T_f8b7d_row7_col1" class="data row7 col1" >Follow up 4</td>
#       <td id="T_f8b7d_row7_col2" class="data row7 col2" >7824</td>
#       <td id="T_f8b7d_row7_col3" class="data row7 col3" >8619</td>
#       <td id="T_f8b7d_row7_col4" class="data row7 col4" >8</td>
#     </tr>
#   </tbody>
# </table>
