# %% [markdown]
# # Fenland Study Datasets

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ss = SS("FENLAND")
last_modified()
# Out:
# >Last modified: 27 May 2026

# %% [markdown]
# ## 1. Datasets

# %%
ss.table_caption_ds()
# Out:
# **Table 1:** Datasets and metrics in the UK LLC belonging to FENLAND.

# %%
ss.datasets()
# Out:
# <style type="text/css">
# #T_80e9a_row0_col0, #T_80e9a_row0_col1, #T_80e9a_row0_col2, #T_80e9a_row0_col3, #T_80e9a_row0_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_80e9a" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_80e9a_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_80e9a_level0_col1" class="col_heading level0 col1" >Dataset Name</th>
#       <th id="T_80e9a_level0_col2" class="col_heading level0 col2" ># Participants</th>
#       <th id="T_80e9a_level0_col3" class="col_heading level0 col3" ># Observations</th>
#       <th id="T_80e9a_level0_col4" class="col_heading level0 col4" ># Variables</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_80e9a_row0_col0" class="data row0 col0" > <a href="P1.html">P1</a></td>
#       <td id="T_80e9a_row0_col1" class="data row0 col1" >Phase 1 </td>
#       <td id="T_80e9a_row0_col2" class="data row0 col2" >12072</td>
#       <td id="T_80e9a_row0_col3" class="data row0 col3" >12072</td>
#       <td id="T_80e9a_row0_col4" class="data row0 col4" >52</td>
#     </tr>
#   </tbody>
# </table>
