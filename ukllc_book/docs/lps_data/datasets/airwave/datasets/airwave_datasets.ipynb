# %% [markdown]
# # Airwave Study Tissue Bank (AIRWAVE) Datasets

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ss = SS("AIRWAVE")
last_modified()
# Out:
# >Last modified: 21 May 2026

# %% [markdown]
# ## 1. Datasets

# %%
ss.table_caption_ds()
# Out:
# **Table 1:** Datasets and metrics in the UK LLC belonging to AIRWAVE.

# %%
ss.datasets()
# Out:
# <style type="text/css">
# #T_82d32_row0_col0, #T_82d32_row0_col1, #T_82d32_row0_col2, #T_82d32_row0_col3, #T_82d32_row0_col4, #T_82d32_row1_col0, #T_82d32_row1_col1, #T_82d32_row1_col2, #T_82d32_row1_col3, #T_82d32_row1_col4, #T_82d32_row2_col0, #T_82d32_row2_col1, #T_82d32_row2_col2, #T_82d32_row2_col3, #T_82d32_row2_col4, #T_82d32_row3_col0, #T_82d32_row3_col1, #T_82d32_row3_col2, #T_82d32_row3_col3, #T_82d32_row3_col4, #T_82d32_row4_col0, #T_82d32_row4_col1, #T_82d32_row4_col2, #T_82d32_row4_col3, #T_82d32_row4_col4, #T_82d32_row5_col0, #T_82d32_row5_col1, #T_82d32_row5_col2, #T_82d32_row5_col3, #T_82d32_row5_col4, #T_82d32_row6_col0, #T_82d32_row6_col1, #T_82d32_row6_col2, #T_82d32_row6_col3, #T_82d32_row6_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_82d32" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_82d32_level0_col0" class="col_heading level0 col0" >Dataset</th>
# ...
