# %% [markdown]
# # Clinic & assay follow-up (AIRWAVE)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("AIRWAVE", "clinic_followup")
last_modified()
# Out:
# >Last modified: 20 Nov 2025

# %% [markdown]
# ## 1. Summary

# %%
ds.summary()
# Out:
# Follow-up to the baseline health-screening clinic. Most of the measurements made at baseline are repeated here. Plus there are some new participants in this dataset who never had a baseline visit but were included anyway.

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_f794a th {
#   text-align: left;
# }
# #T_f794a_row0_col0, #T_f794a_row0_col1, #T_f794a_row1_col0, #T_f794a_row1_col1, #T_f794a_row2_col0, #T_f794a_row2_col1, #T_f794a_row3_col0, #T_f794a_row3_col1, #T_f794a_row4_col0, #T_f794a_row4_col1, #T_f794a_row5_col0, #T_f794a_row5_col1, #T_f794a_row6_col0, #T_f794a_row6_col1, #T_f794a_row7_col0, #T_f794a_row7_col1, #T_f794a_row8_col0, #T_f794a_row8_col1, #T_f794a_row9_col0, #T_f794a_row9_col1, #T_f794a_row10_col0, #T_f794a_row10_col1, #T_f794a_row11_col0, #T_f794a_row11_col1, #T_f794a_row12_col0, #T_f794a_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_f794a" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_f794a_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_f794a_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## 2. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_dda89 th {
#   text-align: left;
# }
# #T_dda89_row0_col0, #T_dda89_row0_col1, #T_dda89_row1_col0, #T_dda89_row1_col1, #T_dda89_row2_col0, #T_dda89_row2_col1, #T_dda89_row3_col0, #T_dda89_row3_col1, #T_dda89_row4_col0, #T_dda89_row4_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_dda89" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_dda89_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_dda89_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dda89_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_dda89_row0_col1" class="data row0 col1" >22 Sep 2025</td>
#     </tr>
#     <tr>
#       <td id="T_dda89_row1_col0" class="data row1 col0" >Number of Variables</td>
#       <td id="T_dda89_row1_col1" class="data row1 col1" >110</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## 3. Documentation

# %%
ds.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
