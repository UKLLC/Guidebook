# %% [markdown]
# # UK-REACH (UKREACH) Datasets

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ss = SS("UKREACH")
last_modified()
# Out:
# >Last modified: 23 Jun 2026

# %% [markdown]
# ## 1. Datasets

# %%
ss.table_caption_ds()
# Out:
# **Table 1:** Datasets and metrics in the UK LLC belonging to UKREACH.

# %%
ss.datasets()
# Out:
# <style type="text/css">
# </style>
# <table id="T_0b8ab" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_0b8ab_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_0b8ab_level0_col1" class="col_heading level0 col1" >Dataset Name</th>
#       <th id="T_0b8ab_level0_col2" class="col_heading level0 col2" ># Participants</th>
#       <th id="T_0b8ab_level0_col3" class="col_heading level0 col3" ># Observations</th>
#       <th id="T_0b8ab_level0_col4" class="col_heading level0 col4" ># Variables</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
