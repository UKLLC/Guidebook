# %% [markdown]
# # Born in Bradford (BiB) Datasets

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ss = SS("BIB")
last_modified()
# Out:
# >Last modified: 06 Jul 2026

# %% [markdown]
# ## 1. Datasets

# %%
ss.table_caption_ds()
# Out:
# **Table 1:** Datasets and metrics in the UK LLC belonging to BIB.

# %%
ss.datasets()
# Out:
# <style type="text/css">
# #T_0eff2_row0_col0, #T_0eff2_row0_col1, #T_0eff2_row0_col2, #T_0eff2_row0_col3, #T_0eff2_row0_col4, #T_0eff2_row1_col0, #T_0eff2_row1_col1, #T_0eff2_row1_col2, #T_0eff2_row1_col3, #T_0eff2_row1_col4, #T_0eff2_row2_col0, #T_0eff2_row2_col1, #T_0eff2_row2_col2, #T_0eff2_row2_col3, #T_0eff2_row2_col4, #T_0eff2_row3_col0, #T_0eff2_row3_col1, #T_0eff2_row3_col2, #T_0eff2_row3_col3, #T_0eff2_row3_col4, #T_0eff2_row4_col0, #T_0eff2_row4_col1, #T_0eff2_row4_col2, #T_0eff2_row4_col3, #T_0eff2_row4_col4, #T_0eff2_row5_col0, #T_0eff2_row5_col1, #T_0eff2_row5_col2, #T_0eff2_row5_col3, #T_0eff2_row5_col4, #T_0eff2_row6_col0, #T_0eff2_row6_col1, #T_0eff2_row6_col2, #T_0eff2_row6_col3, #T_0eff2_row6_col4, #T_0eff2_row7_col0, #T_0eff2_row7_col1, #T_0eff2_row7_col2, #T_0eff2_row7_col3, #T_0eff2_row7_col4, #T_0eff2_row8_col0, #T_0eff2_row8_col1, #T_0eff2_row8_col2, #T_0eff2_row8_col3, #T_0eff2_row8_col4, #T_0eff2_row9_col0, #T_0eff2_row9_col1, #T_0eff2_row9_col2, #T_0eff2_row9_col3, #T_0eff2_row9_col4, #T_0eff2_row10_col0, #T_0eff2_row10_col1, #T_0eff2_row10_col2, #T_0eff2_row10_col3, #T_0eff2_row10_col4, #T_0eff2_row11_col0, #T_0eff2_row11_col1, #T_0eff2_row11_col2, #T_0eff2_row11_col3, #T_0eff2_row11_col4, #T_0eff2_row12_col0, #T_0eff2_row12_col1, #T_0eff2_row12_col2, #T_0eff2_row12_col3, #T_0eff2_row12_col4, #T_0eff2_row13_col0, #T_0eff2_row13_col1, #T_0eff2_row13_col2, #T_0eff2_row13_col3, #T_0eff2_row13_col4, #T_0eff2_row14_col0, #T_0eff2_row14_col1, #T_0eff2_row14_col2, #T_0eff2_row14_col3, #T_0eff2_row14_col4, #T_0eff2_row15_col0, #T_0eff2_row15_col1, #T_0eff2_row15_col2, #T_0eff2_row15_col3, #T_0eff2_row15_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_0eff2" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_0eff2_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_0eff2_level0_col1" class="col_heading level0 col1" >Dataset Name</th>
#       <th id="T_0eff2_level0_col2" class="col_heading level0 col2" ># Participants</th>
#       <th id="T_0eff2_level0_col3" class="col_heading level0 col3" ># Observations</th>
#       <th id="T_0eff2_level0_col4" class="col_heading level0 col4" ># Variables</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0eff2_row0_col0" class="data row0 col0" > <a href="cv19child_p3survey.html">CV19child_P3survey</a></td>
#       <td id="T_0eff2_row0_col1" class="data row0 col1" >COVID-19 Child Phase 3 Survey</td>
#       <td id="T_0eff2_row0_col2" class="data row0 col2" >586</td>
#       <td id="T_0eff2_row0_col3" class="data row0 col3" >28591</td>
#       <td id="T_0eff2_row0_col4" class="data row0 col4" >60</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row1_col0" class="data row1 col0" > <a href="cv_w1.html">CV_W1</a></td>
#       <td id="T_0eff2_row1_col1" class="data row1 col1" >COVID-19 Wave 1</td>
#       <td id="T_0eff2_row1_col2" class="data row1 col2" >1560</td>
#       <td id="T_0eff2_row1_col3" class="data row1 col3" >28591</td>
#       <td id="T_0eff2_row1_col4" class="data row1 col4" >176</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row2_col0" class="data row2 col0" > <a href="cv_w2.html">CV_W2</a></td>
#       <td id="T_0eff2_row2_col1" class="data row2 col1" >COVID-19 Wave 2</td>
#       <td id="T_0eff2_row2_col2" class="data row2 col2" >631</td>
#       <td id="T_0eff2_row2_col3" class="data row2 col3" >28591</td>
#       <td id="T_0eff2_row2_col4" class="data row2 col4" >449</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row3_col0" class="data row3 col0" > <a href="nmrmetabolomics_mother.html">nmrmetabolomics_mother</a></td>
#       <td id="T_0eff2_row3_col1" class="data row3 col1" >NMR Metabolomics Mother</td>
#       <td id="T_0eff2_row3_col2" class="data row3 col2" >10160</td>
#       <td id="T_0eff2_row3_col3" class="data row3 col3" >29469</td>
#       <td id="T_0eff2_row3_col4" class="data row3 col4" >245</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row4_col0" class="data row4 col0" > <a href="cv19adult_p1.html">CV19adult_P1</a></td>
#       <td id="T_0eff2_row4_col1" class="data row4 col1" >COVID-19 Adult Phase 1 </td>
#       <td id="T_0eff2_row4_col2" class="data row4 col2" >1557</td>
#       <td id="T_0eff2_row4_col3" class="data row4 col3" >28591</td>
#       <td id="T_0eff2_row4_col4" class="data row4 col4" >178</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row5_col0" class="data row5 col0" > <a href="cv19adult_p3.html">CV19adult_P3</a></td>
#       <td id="T_0eff2_row5_col1" class="data row5 col1" >COVID-19 Adult Phase 3 </td>
#       <td id="T_0eff2_row5_col2" class="data row5 col2" >1158</td>
#       <td id="T_0eff2_row5_col3" class="data row5 col3" >1184</td>
#       <td id="T_0eff2_row5_col4" class="data row5 col4" >162</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row6_col0" class="data row6 col0" > <a href="cv19child_p1sdq.html">CV19child_P1sdq</a></td>
#       <td id="T_0eff2_row6_col1" class="data row6 col1" >COVID-19 Child Phase 1 Strengths and Difficulties Questionnaire</td>
#       <td id="T_0eff2_row6_col2" class="data row6 col2" >886</td>
#       <td id="T_0eff2_row6_col3" class="data row6 col3" >28591</td>
#       <td id="T_0eff2_row6_col4" class="data row6 col4" >42</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row7_col0" class="data row7 col0" > <a href="cv19child_p1survey.html">CV19child_P1survey</a></td>
#       <td id="T_0eff2_row7_col1" class="data row7 col1" >COVID-19 Child Phase 1 Survey</td>
#       <td id="T_0eff2_row7_col2" class="data row7 col2" >940</td>
#       <td id="T_0eff2_row7_col3" class="data row7 col3" >28591</td>
#       <td id="T_0eff2_row7_col4" class="data row7 col4" >122</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row8_col0" class="data row8 col0" > <a href="cv19child_p2sdq.html">CV19child_P2sdq</a></td>
#       <td id="T_0eff2_row8_col1" class="data row8 col1" >COVID-19 Child Phase 2 Strengths and Difficulties Questionnaire</td>
#       <td id="T_0eff2_row8_col2" class="data row8 col2" >631</td>
#       <td id="T_0eff2_row8_col3" class="data row8 col3" >28591</td>
#       <td id="T_0eff2_row8_col4" class="data row8 col4" >42</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row9_col0" class="data row9 col0" > <a href="cv19child_p2survey.html">CV19child_P2survey</a></td>
#       <td id="T_0eff2_row9_col1" class="data row9 col1" >COVID-19 Child Phase 2 Survey</td>
#       <td id="T_0eff2_row9_col2" class="data row9 col2" >633</td>
#       <td id="T_0eff2_row9_col3" class="data row9 col3" >28591</td>
#       <td id="T_0eff2_row9_col4" class="data row9 col4" >101</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row10_col0" class="data row10 col0" > <a href="cv19child_p3sdq.html">CV19child_P3sdq</a></td>
#       <td id="T_0eff2_row10_col1" class="data row10 col1" >COVID-19 Child Phase 3 Strengths and Difficulties Questionnaire</td>
#       <td id="T_0eff2_row10_col2" class="data row10 col2" >582</td>
#       <td id="T_0eff2_row10_col3" class="data row10 col3" >28591</td>
#       <td id="T_0eff2_row10_col4" class="data row10 col4" >40</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row11_col0" class="data row11 col0" > <a href="nmrmetabolomics_infant12.html">nmrmetabolomics_infant12</a></td>
#       <td id="T_0eff2_row11_col1" class="data row11 col1" >NMR Metabolomics Infant 12</td>
#       <td id="T_0eff2_row11_col2" class="data row11 col2" >1663</td>
#       <td id="T_0eff2_row11_col3" class="data row11 col3" >28591</td>
#       <td id="T_0eff2_row11_col4" class="data row11 col4" >256</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row12_col0" class="data row12 col0" > <a href="nmrmetabolomics_infant24.html">nmrmetabolomics_infant24</a></td>
#       <td id="T_0eff2_row12_col1" class="data row12 col1" >NMR Metabolomics Infant 24</td>
#       <td id="T_0eff2_row12_col2" class="data row12 col2" >1519</td>
#       <td id="T_0eff2_row12_col3" class="data row12 col3" >28591</td>
#       <td id="T_0eff2_row12_col4" class="data row12 col4" >256</td>
#     </tr>
#     <tr>
#       <td id="T_0eff2_row13_col0" class="data row13 col0" > <a href="nmrmetabolomics_baby.html">nmrmetabolomics_baby</a></td>
#       <td id="T_0eff2_row13_col1"
