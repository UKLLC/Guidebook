# %% [markdown]
# # Southall & Brent Revisited (SABRE)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
ss = SS("SABRE")
last_modified()
# Out:
# >Last modified: 28 May 2026

# %% [markdown]
# ## 1. Summary

# %%
ss.summary()
# Out:
# The Southall And Brent REvisited (SABRE) study is the largest tri-ethnic population-based cohort in the UK, involving nearly 5,000 European, Indian Asian and African Caribbean men and women. The study originally focused on the causes of diabetes and disorders of the heart and circulation. It was broadened to include cognitive function in the follow up stages.

# %%
ss.info_table()
# Out:
# <style type="text/css">
# #T_4a90c_row0_col0, #T_4a90c_row0_col1, #T_4a90c_row1_col0, #T_4a90c_row1_col1, #T_4a90c_row2_col0, #T_4a90c_row2_col1, #T_4a90c_row3_col0, #T_4a90c_row3_col1, #T_4a90c_row4_col0, #T_4a90c_row4_col1, #T_4a90c_row5_col0, #T_4a90c_row5_col1, #T_4a90c_row6_col0, #T_4a90c_row6_col1, #T_4a90c_row7_col0, #T_4a90c_row7_col1, #T_4a90c_row8_col0, #T_4a90c_row8_col1, #T_4a90c_row9_col0, #T_4a90c_row9_col1, #T_4a90c_row10_col0, #T_4a90c_row10_col1, #T_4a90c_row11_col0, #T_4a90c_row11_col1, #T_4a90c_row12_col0, #T_4a90c_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_4a90c" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_4a90c_level0_col0" class="col_heading level0 col0" >Series Descriptor</th>
#       <th id="T_4a90c_level0_col1" class="col_heading level0 col1" >Series-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4a90c_row0_col0" class="data row0 col0" >Citation (APA)</td>
#       <td id="T_4a90c_row0_col1" class="data row0 col1" >University College London, Institute of Cardiovascular Science, Unit for Lifelong Health and Ageing. (2021). <i>Southall & Brent Revisited (SABRE).</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-series-00018" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-series-00018</a></td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row1_col0" class="data row1 col0" >Download Citation</td>
#       <td id="T_4a90c_row1_col1" class="data row1 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-series-00018" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-series-00018" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-series-00018" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row2_col0" class="data row2 col0" >Owner</td>
#       <td id="T_4a90c_row2_col1" class="data row2 col1" >University College London</td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row3_col0" class="data row3 col0" >Cohort</td>
#       <td id="T_4a90c_row3_col1" class="data row3 col1" >4858</td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row4_col0" class="data row4 col0" >Age at Recruitment</td>
#       <td id="T_4a90c_row4_col1" class="data row4 col1" >40-69 years</td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row5_col0" class="data row5 col0" >Geographical Coverage - Nations</td>
#       <td id="T_4a90c_row5_col1" class="data row5 col1" >England</td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row6_col0" class="data row6 col0" >Geographical Coverage - Regions</td>
#       <td id="T_4a90c_row6_col1" class="data row6 col1" >London - Southall; Brent</td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row7_col0" class="data row7 col0" >Start Date</td>
#       <td id="T_4a90c_row7_col1" class="data row7 col1" >1988</td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row8_col0" class="data row8 col0" >Permitted Linkages</td>
#       <td id="T_4a90c_row8_col1" class="data row8 col1" >See  <a href="https://guidebook.ukllc.ac.uk/docs/lps_data/linkages/lps_linkages" rel="noopener noreferrer" target="_blank">here</a></td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row9_col0" class="data row9 col0" >Inclusion in Linkages</td>
#       <td id="T_4a90c_row9_col1" class="data row9 col1" >Consent</td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row10_col0" class="data row10 col0" >Cohort Profile</td>
#       <td id="T_4a90c_row10_col1" class="data row10 col1" > <a href="https://doi.org/10.1093/ije/dyaa135" rel="noopener noreferrer" target="_blank">10.1093/ije/dyaa135</a></td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row11_col0" class="data row11 col0" >LPS Homepage</td>
#       <td id="T_4a90c_row11_col1" class="data row11 col1" > <a href="https://mrc.ukri.org/research/facilities-and-resources-for-researchers/cohort-directory/southall-and-brent-revisited-sabre/" rel="noopener noreferrer" target="_blank">https://mrc.ukri.org/research/facilities-and-resources-for-researchers/cohort-directory/southall-and-brent-revisited-sabre/</a></td>
#     </tr>
#     <tr>
#       <td id="T_4a90c_row12_col0" class="data row12 col0" >Build a Data Request</td>
#       <td id="T_4a90c_row12_col1" class="data row12 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Linkage Rates

# %%
ss.linkages_plot()
# Out:
# Linkage rates will be displayed for SABRE in due course.

# %% [markdown]
# ## 3. Documentation

# %%
ss.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.
