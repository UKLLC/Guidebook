# %% [markdown]
# # Generation Scotland: Scottish Family Health Study (GS:SFHS)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
ss = SS("GENSCOT")
last_modified()
# Out:
# >Last modified: 28 May 2026

# %% [markdown]
# ## 1. Summary

# %%
ss.summary()
# Out:
# Generation Scotland (GENSCOT) collects data about participants and their families to improve understanding, prevention and treatment of conditions for current and future generations.

# %%
ss.info_table()
# Out:
# <style type="text/css">
# #T_48db7_row0_col0, #T_48db7_row0_col1, #T_48db7_row1_col0, #T_48db7_row1_col1, #T_48db7_row2_col0, #T_48db7_row2_col1, #T_48db7_row3_col0, #T_48db7_row3_col1, #T_48db7_row4_col0, #T_48db7_row4_col1, #T_48db7_row5_col0, #T_48db7_row5_col1, #T_48db7_row6_col0, #T_48db7_row6_col1, #T_48db7_row7_col0, #T_48db7_row7_col1, #T_48db7_row8_col0, #T_48db7_row8_col1, #T_48db7_row9_col0, #T_48db7_row9_col1, #T_48db7_row10_col0, #T_48db7_row10_col1, #T_48db7_row11_col0, #T_48db7_row11_col1, #T_48db7_row12_col0, #T_48db7_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_48db7" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_48db7_level0_col0" class="col_heading level0 col0" >Series Descriptor</th>
#       <th id="T_48db7_level0_col1" class="col_heading level0 col1" >Series-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_48db7_row0_col0" class="data row0 col0" >Citation (APA)</td>
#       <td id="T_48db7_row0_col1" class="data row0 col1" >Centre for Medical Informatics, Usher Institute, University of Edinburgh. (2021). <i>Generation Scotland (GENSCOT).</i> UK Longitudinal Linkage Collaboration (UK LLC).  <a href="https://doi.org/10.71760/ukllc-series-00009" rel="noopener noreferrer" target="_blank">https://doi.org/10.71760/ukllc-series-00009</a></td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row1_col0" class="data row1 col0" >Download Citation</td>
#       <td id="T_48db7_row1_col1" class="data row1 col1" > <a href="https://api.datacite.org/application/vnd.citationstyles.csl+json/10.71760/ukllc-series-00009" rel="noopener noreferrer" target="_blank">Citeproc JSON</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-bibtex/10.71760/ukllc-series-00009" rel="noopener noreferrer" target="_blank">BibTeX</a>&nbsp;&nbsp;&nbsp;&nbsp; <a href="https://api.datacite.org/application/x-research-info-systems/10.71760/ukllc-series-00009" rel="noopener noreferrer" target="_blank">RIS</a></td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row2_col0" class="data row2 col0" >Owner</td>
#       <td id="T_48db7_row2_col1" class="data row2 col1" >University of Edinburgh</td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row3_col0" class="data row3 col0" >Cohort</td>
#       <td id="T_48db7_row3_col1" class="data row3 col1" >23,960 individuals  5,573 families</td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row4_col0" class="data row4 col0" >Age at Recruitment</td>
#       <td id="T_48db7_row4_col1" class="data row4 col1" >18-100 years</td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row5_col0" class="data row5 col0" >Geographical Coverage - Nations</td>
#       <td id="T_48db7_row5_col1" class="data row5 col1" >Scotland</td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row6_col0" class="data row6 col0" >Geographical Coverage - Regions</td>
#       <td id="T_48db7_row6_col1" class="data row6 col1" >Nationwide</td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row7_col0" class="data row7 col0" >Start Date</td>
#       <td id="T_48db7_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row8_col0" class="data row8 col0" >Permitted Linkages</td>
#       <td id="T_48db7_row8_col1" class="data row8 col1" >See  <a href="https://guidebook.ukllc.ac.uk/docs/lps_data/linkages/lps_linkages" rel="noopener noreferrer" target="_blank">here</a></td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row9_col0" class="data row9 col0" >Inclusion in Linkages</td>
#       <td id="T_48db7_row9_col1" class="data row9 col1" >Consent</td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row10_col0" class="data row10 col0" >Cohort Profile</td>
#       <td id="T_48db7_row10_col1" class="data row10 col1" > <a href="https://doi.org/10.1093/ije/dys084" rel="noopener noreferrer" target="_blank">10.1093/ije/dys084</a></td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row11_col0" class="data row11 col0" >LPS Homepage</td>
#       <td id="T_48db7_row11_col1" class="data row11 col1" > <a href="https://www.ed.ac.uk/generation-scotland" rel="noopener noreferrer" target="_blank">https://www.ed.ac.uk/generation-scotland</a></td>
#     </tr>
#     <tr>
#       <td id="T_48db7_row12_col0" class="data row12 col0" >Build a Data Request</td>
#       <td id="T_48db7_row12_col1" class="data row12 col1" > <a href="https://explore.ukllc.ac.uk/" rel="noopener noreferrer" target="_blank">https://explore.ukllc.ac.uk/</a></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. Linkage Rates

# %%
ss.linkages_plot()
# Out:
# Linkage rates will be displayed for GENSCOT in due course.

# %% [markdown]
# ## 3. Documentation

# %%
ss.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.
