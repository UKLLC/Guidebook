# %% [markdown]
# # Fenland Study

# %%
import sys
import os
sys.path.append(os.path.abspath('../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
ss = SS("FENLAND")
last_modified()
# Out:
# >Last modified: 07 Jul 2026

# %% [markdown]
# ## 1. Summary

# %%
ss.summary()
# Out:
# The Fenland Study investigates the interaction between environmental and genetic factors in determining obesity, type 2 diabetes and related metabolic disorders.

# %%
ss.info_table()
# Out:
# <style type="text/css">
# #T_7f4ea_row0_col0, #T_7f4ea_row0_col1, #T_7f4ea_row1_col0, #T_7f4ea_row1_col1, #T_7f4ea_row2_col0, #T_7f4ea_row2_col1, #T_7f4ea_row3_col0, #T_7f4ea_row3_col1, #T_7f4ea_row4_col0, #T_7f4ea_row4_col1, #T_7f4ea_row5_col0, #T_7f4ea_row5_col1, #T_7f4ea_row6_col0, #T_7f4ea_row6_col1, #T_7f4ea_row7_col0, #T_7f4ea_row7_col1, #T_7f4ea_row8_col0, #T_7f4ea_row8_col1, #T_7f4ea_row9_col0, #T_7f4ea_row9_col1, #T_7f4ea_row10_col0, #T_7f4ea_row10_col1, #T_7f4ea_row11_col0, #T_7f4ea_row11_col1, #T_7f4ea_row12_col0, #T_7f4ea_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_7f4ea" style="font-size:14px">
#   <thead>
#     <tr>
#       <th id="T_7f4ea_level0_col0" class="col_heading level0 col0" >Series Descriptor</th>
#       <th id="T_7f4ea_level0_col1" class="col_heading level0 col1" >Series-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7f4ea_row0_col0" class="data row0 col0" >Citation (APA)</td>
# ...

# %% [markdown]
# ## 2. Linkage Rates

# %%
ss.linkages_plot()
# Out:
# Linkage rates will be displayed for FENLAND in due course.

# %% [markdown]
# ## 3. Documentation

# %%
ss.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.
