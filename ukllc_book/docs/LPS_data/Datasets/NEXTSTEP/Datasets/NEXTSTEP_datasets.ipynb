# %% [markdown]
# # Next Steps Datasets

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ss = SS("NEXTSTEP")
last_modified()
# Out:
# >Last modified: 28 Jul 2025

# %% [markdown]
# ## 1. Datasets

# %%
ss.table_caption_ds()
# Out:
# **Table 1:** Datasets and metrics in the UK LLC belonging to NEXTSTEP.

# %%
ss.datasets()
# Out:
# <style type="text/css">
# #T_6cff0 th {
#   text-align: left;
# }
# #T_6cff0_row0_col0, #T_6cff0_row0_col1, #T_6cff0_row0_col2, #T_6cff0_row0_col3, #T_6cff0_row0_col4, #T_6cff0_row1_col0, #T_6cff0_row1_col1, #T_6cff0_row1_col2, #T_6cff0_row1_col3, #T_6cff0_row1_col4, #T_6cff0_row2_col0, #T_6cff0_row2_col1, #T_6cff0_row2_col2, #T_6cff0_row2_col3, #T_6cff0_row2_col4, #T_6cff0_row3_col0, #T_6cff0_row3_col1, #T_6cff0_row3_col2, #T_6cff0_row3_col3, #T_6cff0_row3_col4, #T_6cff0_row4_col0, #T_6cff0_row4_col1, #T_6cff0_row4_col2, #T_6cff0_row4_col3, #T_6cff0_row4_col4, #T_6cff0_row5_col0, #T_6cff0_row5_col1, #T_6cff0_row5_col2, #T_6cff0_row5_col3, #T_6cff0_row5_col4, #T_6cff0_row6_col0, #T_6cff0_row6_col1, #T_6cff0_row6_col2, #T_6cff0_row6_col3, #T_6cff0_row6_col4, #T_6cff0_row7_col0, #T_6cff0_row7_col1, #T_6cff0_row7_col2, #T_6cff0_row7_col3, #T_6cff0_row7_col4, #T_6cff0_row8_col0, #T_6cff0_row8_col1, #T_6cff0_row8_col2, #T_6cff0_row8_col3, #T_6cff0_row8_col4, #T_6cff0_row9_col0, #T_6cff0_row9_col1, #T_6cff0_row9_col2, #T_6cff0_row9_col3, #T_6cff0_row9_col4, #T_6cff0_row10_col0, #T_6cff0_row10_col1, #T_6cff0_row10_col2, #T_6cff0_row10_col3, #T_6cff0_row10_col4, #T_6cff0_row11_col0, #T_6cff0_row11_col1, #T_6cff0_row11_col2, #T_6cff0_row11_col3, #T_6cff0_row11_col4, #T_6cff0_row12_col0, #T_6cff0_row12_col1, #T_6cff0_row12_col2, #T_6cff0_row12_col3, #T_6cff0_row12_col4, #T_6cff0_row13_col0, #T_6cff0_row13_col1, #T_6cff0_row13_col2, #T_6cff0_row13_col3, #T_6cff0_row13_col4, #T_6cff0_row14_col0, #T_6cff0_row14_col1, #T_6cff0_row14_col2, #T_6cff0_row14_col3, #T_6cff0_row14_col4, #T_6cff0_row15_col0, #T_6cff0_row15_col1, #T_6cff0_row15_col2, #T_6cff0_row15_col3, #T_6cff0_row15_col4, #T_6cff0_row16_col0, #T_6cff0_row16_col1, #T_6cff0_row16_col2, #T_6cff0_row16_col3, #T_6cff0_row16_col4, #T_6cff0_row17_col0, #T_6cff0_row17_col1, #T_6cff0_row17_col2, #T_6cff0_row17_col3, #T_6cff0_row17_col4, #T_6cff0_row18_col0, #T_6cff0_row18_col1, #T_6cff0_row18_col2, #T_6cff0_row18_col3, #T_6cff0_row18_col4, #T_6cff0_row19_col0, #T_6cff0_row19_col1, #T_6cff0_row19_col2, #T_6cff0_row19_col3, #T_6cff0_row19_col4, #T_6cff0_row20_col0, #T_6cff0_row20_col1, #T_6cff0_row20_col2, #T_6cff0_row20_col3, #T_6cff0_row20_col4, #T_6cff0_row21_col0, #T_6cff0_row21_col1, #T_6cff0_row21_col2, #T_6cff0_row21_col3, #T_6cff0_row21_col4, #T_6cff0_row22_col0, #T_6cff0_row22_col1, #T_6cff0_row22_col2, #T_6cff0_row22_col3, #T_6cff0_row22_col4, #T_6cff0_row23_col0, #T_6cff0_row23_col1, #T_6cff0_row23_col2, #T_6cff0_row23_col3, #T_6cff0_row23_col4, #T_6cff0_row24_col0, #T_6cff0_row24_col1, #T_6cff0_row24_col2, #T_6cff0_row24_col3, #T_6cff0_row24_col4, #T_6cff0_row25_col0, #T_6cff0_row25_col1, #T_6cff0_row25_col2, #T_6cff0_row25_col3, #T_6cff0_row25_col4, #T_6cff0_row26_col0, #T_6cff0_row26_col1, #T_6cff0_row26_col2, #T_6cff0_row26_col3, #T_6cff0_row26_col4, #T_6cff0_row27_col0, #T_6cff0_row27_col1, #T_6cff0_row27_col2, #T_6cff0_row27_col3, #T_6cff0_row27_col4, #T_6cff0_row28_col0, #T_6cff0_row28_col1, #T_6cff0_row28_col2, #T_6cff0_row28_col3, #T_6cff0_row28_col4, #T_6cff0_row29_col0, #T_6cff0_row29_col1, #T_6cff0_row29_col2, #T_6cff0_row29_col3, #T_6cff0_row29_col4, #T_6cff0_row30_col0, #T_6cff0_row30_col1, #T_6cff0_row30_col2, #T_6cff0_row30_col3, #T_6cff0_row30_col4, #T_6cff0_row31_col0, #T_6cff0_row31_col1, #T_6cff0_row31_col2, #T_6cff0_row31_col3, #T_6cff0_row31_col4, #T_6cff0_row32_col0, #T_6cff0_row32_col1, #T_6cff0_row32_col2, #T_6cff0_row32_col3, #T_6cff0_row32_col4, #T_6cff0_row33_col0, #T_6cff0_row33_col1, #T_6cff0_row33_col2, #T_6cff0_row33_col3, #T_6cff0_row33_col4, #T_6cff0_row34_col0, #T_6cff0_row34_col1, #T_6cff0_row34_col2, #T_6cff0_row34_col3, #T_6cff0_row34_col4, #T_6cff0_row35_col0, #T_6cff0_row35_col1, #T_6cff0_row35_col2, #T_6cff0_row35_col3, #T_6cff0_row35_col4, #T_6cff0_row36_col0, #T_6cff0_row36_col1, #T_6cff0_row36_col2, #T_6cff0_row36_col3, #T_6cff0_row36_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_6cff0" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_6cff0_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_6cff0_level0_col1" class="col_heading level0 col1" >Dataset Name</th>
#       <th id="T_6cff0_level0_col2" class="col_heading level0 col2" ># Participants</th>
#       <th id="T_6cff0_level0_col3" class="col_heading level0 col3" ># Observations</th>
#       <th id="T_6cff0_level0_col4" class="col_heading level0 col4" ># Variables</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6cff0_row0_col0" class="data row0 col0" > <a href="ns2_parental_attitudes.html">ns2_parental_attitudes</a></td>
#       <td id="T_6cff0_row0_col1" class="data row0 col1" >NS Parental Attitudes Sweep 2</td>
#       <td id="T_6cff0_row0_col2" class="data row0 col2" >5689</td>
#       <td id="T_6cff0_row0_col3" class="data row0 col3" >13147</td>
#       <td id="T_6cff0_row0_col4" class="data row0 col4" >80</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row1_col0" class="data row1 col0" > <a href="ns2_household_grid.html">ns2_household_grid</a></td>
#       <td id="T_6cff0_row1_col1" class="data row1 col1" >NS Household Grid Sweep 2</td>
#       <td id="T_6cff0_row1_col2" class="data row1 col2" >5689</td>
#       <td id="T_6cff0_row1_col3" class="data row1 col3" >60491</td>
#       <td id="T_6cff0_row1_col4" class="data row1 col4" >41</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row2_col0" class="data row2 col0" > <a href="ns2_family_background.html">ns2_family_background</a></td>
#       <td id="T_6cff0_row2_col1" class="data row2 col1" >NS Family Background Sweep 2</td>
#       <td id="T_6cff0_row2_col2" class="data row2 col2" >5689</td>
#       <td id="T_6cff0_row2_col3" class="data row2 col3" >13147</td>
#       <td id="T_6cff0_row2_col4" class="data row2 col4" >1034</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row3_col0" class="data row3 col0" > <a href="ns1.html">ns1</a></td>
#       <td id="T_6cff0_row3_col1" class="data row3 col1" >NS Sweep 1</td>
#       <td id="T_6cff0_row3_col2" class="data row3 col2" >6079</td>
#       <td id="T_6cff0_row3_col3" class="data row3 col3" >15286</td>
#       <td id="T_6cff0_row3_col4" class="data row3 col4" >352</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row4_col0" class="data row4 col0" > <a href="ns1_parental_attitudes.html">ns1_parental_attitudes</a></td>
#       <td id="T_6cff0_row4_col1" class="data row4 col1" >NS Parental Attitudes Sweep 1</td>
#       <td id="T_6cff0_row4_col2" class="data row4 col2" >6079</td>
#       <td id="T_6cff0_row4_col3" class="data row4 col3" >15286</td>
#       <td id="T_6cff0_row4_col4" class="data row4 col4" >305</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row5_col0" class="data row5 col0" > <a href="ns1_household_grid.html">ns1_household_grid</a></td>
#       <td id="T_6cff0_row5_col1" class="data row5 col1" >NS Household Grid Sweep 1</td>
#       <td id="T_6cff0_row5_col2" class="data row5 col2" >6079</td>
#       <td id="T_6cff0_row5_col3" class="data row5 col3" >68473</td>
#       <td id="T_6cff0_row5_col4" class="data row5 col4" >30</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row6_col0" class="data row6 col0" > <a href="ns1_family_background.html">ns1_family_background</a></td>
#       <td id="T_6cff0_row6_col1" class="data row6 col1" >NS Family Background Sweep 1</td>
#       <td id="T_6cff0_row6_col2" class="data row6 col2" >6079</td>
#       <td id="T_6cff0_row6_col3" class="data row6 col3" >15286</td>
#       <td id="T_6cff0_row6_col4" class="data row6 col4" >383</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row7_col0" class="data row7 col0" > <a href="longitudinal_index_file.html">longitudinal_index_file</a></td>
#       <td id="T_6cff0_row7_col1" class="data row7 col1" >Longitudinal  index</td>
#       <td id="T_6cff0_row7_col2" class="data row7 col2" >6180</td>
#       <td id="T_6cff0_row7_col3" class="data row7 col3" >77115</td>
#       <td id="T_6cff0_row7_col4" class="data row7 col4" >73</td>
#     </tr>
#     <tr>
#       <td id="T_6cff0_row8_col0" class="data row8 col0" > <a href="basic_demographic_data.html">basic_demographic_data<
