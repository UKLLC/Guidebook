# %% [markdown]
# # Airwave Study Tissue Bank (AIRWAVE) Datasets

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSSource as SS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ss = SS("AIRWAVE")
last_modified()
# Out:
# >Last modified: 20 Nov 2025

# %% [markdown]
# ## 1. Datasets

# %%
ss.table_caption_ds()
# Out:
# **Table 1:** Datasets and metrics in the UK LLC belonging to AIRWAVE.

# %%
ss.datasets()
# Out:
# <style type="text/css">
# #T_a309d th {
#   text-align: left;
# }
# #T_a309d_row0_col0, #T_a309d_row0_col1, #T_a309d_row0_col2, #T_a309d_row0_col3, #T_a309d_row0_col4, #T_a309d_row1_col0, #T_a309d_row1_col1, #T_a309d_row1_col2, #T_a309d_row1_col3, #T_a309d_row1_col4, #T_a309d_row2_col0, #T_a309d_row2_col1, #T_a309d_row2_col2, #T_a309d_row2_col3, #T_a309d_row2_col4, #T_a309d_row3_col0, #T_a309d_row3_col1, #T_a309d_row3_col2, #T_a309d_row3_col3, #T_a309d_row3_col4, #T_a309d_row4_col0, #T_a309d_row4_col1, #T_a309d_row4_col2, #T_a309d_row4_col3, #T_a309d_row4_col4, #T_a309d_row5_col0, #T_a309d_row5_col1, #T_a309d_row5_col2, #T_a309d_row5_col3, #T_a309d_row5_col4, #T_a309d_row6_col0, #T_a309d_row6_col1, #T_a309d_row6_col2, #T_a309d_row6_col3, #T_a309d_row6_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_a309d" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_a309d_level0_col0" class="col_heading level0 col0" >Dataset</th>
#       <th id="T_a309d_level0_col1" class="col_heading level0 col1" >Dataset Name</th>
#       <th id="T_a309d_level0_col2" class="col_heading level0 col2" ># Participants</th>
#       <th id="T_a309d_level0_col3" class="col_heading level0 col3" ># Observations</th>
#       <th id="T_a309d_level0_col4" class="col_heading level0 col4" ># Variables</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a309d_row0_col0" class="data row0 col0" > <a href="clinic_followup.html">clinic_followup</a></td>
#       <td id="T_a309d_row0_col1" class="data row0 col1" >Clinic & assay follow-up</td>
#       <td id="T_a309d_row0_col2" class="data row0 col2" >18893</td>
#       <td id="T_a309d_row0_col3" class="data row0 col3" >22183</td>
#       <td id="T_a309d_row0_col4" class="data row0 col4" >110</td>
#     </tr>
#     <tr>
#       <td id="T_a309d_row1_col0" class="data row1 col0" > <a href="cogtest_baseline_summary.html">cogtest_baseline_summary</a></td>
#       <td id="T_a309d_row1_col1" class="data row1 col1" >Summary of cognitive tests at baseline</td>
#       <td id="T_a309d_row1_col2" class="data row1 col2" >31459</td>
#       <td id="T_a309d_row1_col3" class="data row1 col3" >31466</td>
#       <td id="T_a309d_row1_col4" class="data row1 col4" >32</td>
#     </tr>
#     <tr>
#       <td id="T_a309d_row2_col0" class="data row2 col0" > <a href="cogtest_post2020_details.html">cogtest_post2020_details</a></td>
#       <td id="T_a309d_row2_col1" class="data row2 col1" >Details of cognitive tests post-COVID</td>
#       <td id="T_a309d_row2_col2" class="data row2 col2" >4087</td>
#       <td id="T_a309d_row2_col3" class="data row2 col3" >1048697</td>
#       <td id="T_a309d_row2_col4" class="data row2 col4" >14</td>
#     </tr>
#     <tr>
#       <td id="T_a309d_row3_col0" class="data row3 col0" > <a href="cogtest_post2020_summary.html">cogtest_post2020_summary</a></td>
#       <td id="T_a309d_row3_col1" class="data row3 col1" >Summary of cognitive tests post-COVID</td>
#       <td id="T_a309d_row3_col2" class="data row3 col2" >4158</td>
#       <td id="T_a309d_row3_col3" class="data row3 col3" >4377</td>
#       <td id="T_a309d_row3_col4" class="data row3 col4" >60</td>
#     </tr>
#     <tr>
#       <td id="T_a309d_row4_col0" class="data row4 col0" > <a href="cogtest_pre2020_details.html">cogtest_pre2020_details</a></td>
#       <td id="T_a309d_row4_col1" class="data row4 col1" >Details of cognitive tests pre-COVID</td>
#       <td id="T_a309d_row4_col2" class="data row4 col2" >14386</td>
#       <td id="T_a309d_row4_col3" class="data row4 col3" >2380187</td>
#       <td id="T_a309d_row4_col4" class="data row4 col4" >14</td>
#     </tr>
#     <tr>
#       <td id="T_a309d_row5_col0" class="data row5 col0" > <a href="cogtest_pre2020_summary.html">cogtest_pre2020_summary</a></td>
#       <td id="T_a309d_row5_col1" class="data row5 col1" >Summary of cognitive tests pre-COVID</td>
#       <td id="T_a309d_row5_col2" class="data row5 col2" >14386</td>
#       <td id="T_a309d_row5_col3" class="data row5 col3" >14866</td>
#       <td id="T_a309d_row5_col4" class="data row5 col4" >50</td>
#     </tr>
#     <tr>
#       <td id="T_a309d_row6_col0" class="data row6 col0" > <a href="clinic_baseline.html">clinic_baseline</a></td>
#       <td id="T_a309d_row6_col1" class="data row6 col1" >Clinic & assay baseline</td>
#       <td id="T_a309d_row6_col2" class="data row6 col2" >45329</td>
#       <td id="T_a309d_row6_col3" class="data row6 col3" >46205</td>
#       <td id="T_a309d_row6_col4" class="data row6 col4" >129</td>
#     </tr>
#   </tbody>
# </table>
