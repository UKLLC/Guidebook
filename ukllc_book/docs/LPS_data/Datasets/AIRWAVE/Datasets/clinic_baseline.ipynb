# %% [markdown]
# # Clinic & assay baseline (AIRWAVE)

# %%
import sys
import os
sys.path.append(os.path.abspath('../../../../scripts/'))
from data_doc_helper import LPSDataSet as DS, last_modified
API_KEY = os.environ['FASTAPI_KEY']
ds = DS("AIRWAVE", "clinic_baseline")
last_modified()
# Out:
# >Last modified: 20 Nov 2025

# %% [markdown]
# ## 1. Summary

# %%
ds.summary()
# Out:
# Participants attended a health-screening clinic where clinic-based measurements were conducted and a blood sample collected. Data includes most clinic measurements and assay results.

# %%
ds.info_table()
# Out:
# <style type="text/css">
# #T_56df5 th {
#   text-align: left;
# }
# #T_56df5_row0_col0, #T_56df5_row0_col1, #T_56df5_row1_col0, #T_56df5_row1_col1, #T_56df5_row2_col0, #T_56df5_row2_col1, #T_56df5_row3_col0, #T_56df5_row3_col1, #T_56df5_row4_col0, #T_56df5_row4_col1, #T_56df5_row5_col0, #T_56df5_row5_col1, #T_56df5_row6_col0, #T_56df5_row6_col1, #T_56df5_row7_col0, #T_56df5_row7_col1, #T_56df5_row8_col0, #T_56df5_row8_col1, #T_56df5_row9_col0, #T_56df5_row9_col1, #T_56df5_row10_col0, #T_56df5_row10_col1, #T_56df5_row11_col0, #T_56df5_row11_col1, #T_56df5_row12_col0, #T_56df5_row12_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_56df5" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_56df5_level0_col0" class="col_heading level0 col0" >Dataset Descriptor</th>
#       <th id="T_56df5_level0_col1" class="col_heading level0 col1" >Dataset-specific Information</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## 2. Version History

# %%
ds.version_history()
# Out:
# <style type="text/css">
# #T_6cb88 th {
#   text-align: left;
# }
# #T_6cb88_row0_col0, #T_6cb88_row0_col1, #T_6cb88_row0_col2, #T_6cb88_row1_col0, #T_6cb88_row1_col1, #T_6cb88_row1_col2, #T_6cb88_row2_col0, #T_6cb88_row2_col1, #T_6cb88_row2_col2, #T_6cb88_row3_col0, #T_6cb88_row3_col1, #T_6cb88_row3_col2, #T_6cb88_row4_col0, #T_6cb88_row4_col1, #T_6cb88_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_6cb88" style="font-size: 14px">
#   <thead>
#     <tr>
#       <th id="T_6cb88_level0_col0" class="col_heading level0 col0" >Version</th>
#       <th id="T_6cb88_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6cb88_level0_col2" class="col_heading level0 col2" >2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6cb88_row0_col0" class="data row0 col0" >Version Date</td>
#       <td id="T_6cb88_row0_col1" class="data row0 col1" >17 Sep 2025</td>
#       <td id="T_6cb88_row0_col2" class="data row0 col2" >22 Sep 2025</td>
# ...

# %% [markdown]
# ## 3. Documentation

# %%
ds.documentation()
# Out:
# We are currently building a documentation storage system which will host useful documents related to datasets and data owners. We will surface these documents on Guidebook.

# %% [markdown]
# ## 4. Useful Syntax

# %%
ds.useful_syntax()
# Out:
# Below we will include syntax that may be helpful to other researchers in the UK LLC TRE. For longer scripts, we will include a snippet of the code plus a link to Git where you can find the full scripts.
